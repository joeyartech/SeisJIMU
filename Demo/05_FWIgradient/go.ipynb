# %% [markdown]
# ## Preamble

# %%
import os
import numpy as np
#from scipy import signal
import matplotlib.pyplot as plt

# %%
nz=201; nx=201; h=10

fpeak=7
dt=0.002
nt=2000

ntr=100

# %%
def read(filename,n=(nx,nz)):
    return np.fromfile(filename,dtype='float32').reshape(n).T

def read_su(filename,n=(ntr,nt)):
    data=read(filename,n=(n[0],int(60+n[1])))
    return data[60:,:]

# def read_snap(filename,n=(nsnap,nxsnap,nzsnap),i=26):
#     tmp=np.fromfile(filename,dtype='float32').reshape(n).T
#     return tmp[:,:,i]

def imshow(data,perc=None,clip=None,clipmin=None,extent=None,cmap='viridis',title=None,grid=True):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],extent=extent,cmap=cmap,aspect='auto')
    plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    #plt.xlabel(labels[0]); plt.ylabel(labels[1])
    if title!=None: plt.title(title)

def run(app='../../exe/FWI',setup='setup',np=1,nthreads=8,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OpenMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"{app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        # !./run.sh
    else:
        # !./run.sh > {out}

# %%
# True
# !makevel nz=100 nx=$nx v000=1000 > c1
# !makevel nz=101 nx=$nx v000=1800 > c2
# !cat c1 c2 > tmp && transp < tmp n1=$nx > true
# !rm c1 c2 tmp

# Background
# !makevel nz=$nz nx=$nx v000=1050 > init

#plot
plt.figure(figsize=(8,3))
true=read('true'); init=read('init')
plt.subplot(1,2,1); imshow(true)
plt.subplot(1,2,2); imshow(init)

# %%
# !cat setup_default
# Out:
# MODEL_SIZE              '201 201 1'
# MODEL_SPACING           '10 10 1'
# FILE_MODEL              true
# MODEL_ATTRIBUTES        vp  #'vp rho'
#
# IS_FREESURFACE          F
#
# ACQUI_GEOMETRY          spread
# FS                      '40 500  0'
# DR                      '0  20   0'
# FR                      '40 0    0'
# NR                      100
#
# SCOMP                   pz
# RCOMP                   'pz px ez ex es'
#
# WAVELET_TYPE            ricker
#
# IF_BLOOM        F
# IF_HICKS        F
#
# IF_USE_RANDOM   F
#
# NT           2000
# DT           0.002
# FPEAK        7
# #RDT			0.006
#
# #SNAPSHOT     'pz px ez ex'
# #NSNAPSHOT    50
#
# ## for FWI ##
# FILE_DATA_PREFIX    'results_obs/Ru_Shot'
#
# WEIGHTING    'aoffset_range:1000:1000'
#
# JOB           gradient
#
#
# IF_USE_CHECKPOINT   F

# %% [markdown]
# ## Obs & Syn data

# %%
# !cp setup_default setup
# !echo "DIR_OUT     results_obs" >> setup
run(app='../../exe/fwd_DAS_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 610056 Nov  8 21:59 ../../exe/fwd_DAS_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 21:59:09
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs
#  Output directory:results_obs/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : pz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   999.999939
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           6
#    minmax rx,ix:   0.00000000       1980.00000               1         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         500
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1000.00000       1800.00000
#  vs   577.350281       1039.23047
#  rho   1000.00000       1000.00000
#  ip   1000000.00       1800000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 577.350281, 14.0000000
#  CFL value: 0.593969703
#  ppg%mu sanity:   333333344.       1.08000000E+09 F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.66051332E-03   3.54282162E-03
#  it----        1000
#  fld_u minmax values:  -2.43215729E-03   2.12444062E-03
#  it----        1500
#  fld_u minmax values:  -3.15657421E-03   2.07803957E-03
#  it----        2000
#  fld_u minmax values:  -5.88715309E-04   5.49600401E-04
#  Elapsed time to add source momenta   4.06265259E-04
#  Elapsed time to update momenta      0.996210217
#  Elapsed time to add source strains     1.78170204E-03
#  Elapsed time to update strains        0.777642131
#  Elapsed time to extract field           1.26860142E-02
#  Elapsed time to save boundary           2.32994556E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 21:59:13
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo "DIR_OUT     results_syn" >> setup
run(app='../../exe/fwd_DAS_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 610056 Nov  8 21:59 ../../exe/fwd_DAS_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 21:59:21
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_syn
#  Output directory:results_syn/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : pz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           6
#    minmax rx,ix:   0.00000000       1980.00000               1         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         500
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.18424606E-04
#  Elapsed time to update momenta       1.00991869
#  Elapsed time to add source strains     1.92010403E-03
#  Elapsed time to update strains        0.803214192
#  Elapsed time to extract field           1.37903690E-02
#  Elapsed time to save boundary           2.73144245E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 21:59:26
# System timezone: +03:00

# %%
data=read_su('results_obs/Ru_Shot0001.su',n=(5*ntr,nt))

plt.figure(figsize=(16,4))
plt.subplot(1,5,1); imshow(data[:,     :ntr],title='pz-pz',perc=98)
plt.subplot(1,5,2); imshow(data[:,  ntr:2*ntr],title='pz-px',perc=98)
plt.subplot(1,5,3); imshow(data[:,2*ntr:3*ntr],title='pz-ez',perc=98)
plt.subplot(1,5,4); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)
plt.subplot(1,5,5); imshow(data[:,4*ntr:5*ntr],title='pz-es',perc=98)

data=read_su('results_syn/Ru_Shot0001.su',n=(5*ntr,nt))

plt.figure(figsize=(16,4))
plt.subplot(1,5,1); imshow(data[:,     :ntr],title='pz-pz',perc=98)
plt.subplot(1,5,2); imshow(data[:,  ntr:2*ntr],title='pz-px',perc=98)
plt.subplot(1,5,3); imshow(data[:,2*ntr:3*ntr],title='pz-ez',perc=98)
plt.subplot(1,5,4); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)
plt.subplot(1,5,5); imshow(data[:,4*ntr:5*ntr],title='pz-es',perc=98)

# %%
data=read_su('results_obs/Ru_Shot0001.su',n=(5*ntr,nt))

plt.figure(figsize=(8,4))
plt.subplot(1,2,1); imshow(data[:,ntr:2*ntr],title='pz-px',perc=98)
plt.subplot(1,2,2); imshow(np.gradient(np.cumsum(data[:,3*ntr:4*ntr],axis=1),axis=0),
                           title='pz-converted_px',clip=(-1e-11,1e-11))
plt.figure(figsize=(8,4))
plt.subplot(1,2,1); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)
plt.subplot(1,2,2); imshow(np.cumsum(np.gradient(data[:,ntr:2*ntr],axis=1),axis=0),
                           title='pz-converted_ex',perc=98)


# data=read_su('results_syn/Ru_Shot0001.su',n=(5*ntr,nt))

# plt.figure(figsize=(16,4))
# plt.subplot(1,3,1); imshow(data[:,ntr:2*ntr],title='pz-px',perc=98)
# plt.subplot(1,3,2); imshow(-np.gradient(data[:,ntr:2*ntr],axis=1),title='neg pz-dx_px',perc=98)
# plt.subplot(1,3,3); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)

# %%
#case (11); self%rcv(i)%comp='p'  !pressure

#case (12); self%rcv(i)%comp='vz' !vertical velocity
#case (14); self%rcv(i)%comp='vx' !horizontal velocity in in-line
#case (13); self%rcv(i)%comp='vy' !horizontal velocity in cross-line

#case (21); self%rcv(i)%comp='ez' !ezz
#case (22); self%rcv(i)%comp='ex' !exx
#case (23); self%rcv(i)%comp='ey' !eyy
#case (24); self%rcv(i)%comp='es' !ezx

#case (32); self%rcv(i)%comp='pz' !vertical momenta
#case (34); self%rcv(i)%comp='px' !in-line momenta
#case (33); self%rcv(i)%comp='py' !cross-line momenta

# %%
#!lda = rho(vp^2-2vs^2)
#!mu  = rho*vs^2
#!rho0= rho
#!gvp = glda*2rho*vp
#!gvs = (glda*-2 + gmu)*2rho*vs
#!grho= glda*vp^2 + (-2glda+gmu)*vs^2 + grho0
vp=init
vs=vp/np.sqrt(3)
rho=1000.
def gvp(glda):     return  glda            *2*rho*vp
def gvs(glda,gmu): return (glda*(-2) + gmu)*2*rho*vs

# %% [markdown]
# ## Momentum-Strain formulation

# %% [markdown]
# ### pz-pz

# %%
# !suwind < results_obs/Ru_Shot0001.su key=trid min=32 max=32 > data_0001.su

# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo 'FILE_DATA_PREFIX   data_' >> setup
# !echo "DIR_OUT     results_pe" >> setup
run(app='../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 842320 Nov  8 21:57 ../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 22:00:16
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_pe
#  Output directory:results_pe/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : data_
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : data_
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : pz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               6           6
#    minmax rx,ix:   0.00000000       1980.00000               1         199
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.57763672E-04
#  Elapsed time to update momenta      0.993444920
#  Elapsed time to add source strains     1.93417072E-03
#  Elapsed time to update strains        0.775455952
#  Elapsed time to extract field           6.29687309E-03
#  Elapsed time to save boundary           3.24165821E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007071E-04   6.61906495E-04
#  it----        1500
#  fld_a minmax values:  -1.43816953E-06   2.61497871E-06
#  fld_u minmax values:  -1.41741871E-03   1.74610049E-03
#  it----        1000
#  fld_a minmax values:  -1.59237134E-05   4.31816952E-05
#  fld_u minmax values:  -2.24152976E-03   1.97815499E-03
#  it----         500
#  fld_a minmax values:  -1.35773462E-05   1.12594334E-05
#  fld_u minmax values:  -3.47582228E-03   3.53789120E-03
#  Elapsed time to load boundary               8.15820694E-03
#  Elapsed time to update strains             0.787008762
#  Elapsed time to rm source strains           2.17771530E-03
#  Elapsed time to update momenta              1.02123785
#  Elapsed time to rm source momenta           2.20823288E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource strains       3.77225876E-03
#  Elapsed time to update adj strains         0.789340496
#  Elapsed time to add adjsource momenta       5.74207306E-03
#  Elapsed time to update adj momenta          1.00632572
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   1.69625282E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 4.79360608E-07
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    4.79360608E-07  L2sq=    4.79360608E-07
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 22:00:30
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
comp='pz-pz'

plt.figure(figsize=(8,3))
plt.plot(read_su('results_pe/dadj_Shot0001.su')[:,75])

glda=read('results_pe/a_star_u%glda')
gmu =read('results_pe/a_star_u%gmu' )

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,2,2); imshow(gmu ,title=comp+':gmu' ,perc=98)

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,2,2); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)

# %% [markdown]
# ### pz-px

# %%
# !suwind < results_obs/Ru_Shot0001.su key=trid min=34 max=34 > data_0001.su

# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo 'FILE_DATA_PREFIX   data_' >> setup
# !echo "DIR_OUT     results_PE_pz-px" >> setup
run(app='../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 842320 Nov  8 22:00 ../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 23:35:17
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_PE_pz-px
#  Output directory:results_PE_pz-px/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : data_
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : data_
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : pz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           5
#    minmax rx,ix:   0.00000000       1980.00000               2         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.72664833E-04
#  Elapsed time to update momenta      0.997172356
#  Elapsed time to add source strains     1.83582306E-03
#  Elapsed time to update strains        0.775596976
#  Elapsed time to extract field           5.15031815E-03
#  Elapsed time to save boundary           3.21853161E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007071E-04   6.61906495E-04
#  it----        1500
#  fld_a minmax values:  -7.48175978E-07   7.48177001E-07
#  fld_u minmax values:  -1.41741871E-03   1.74610049E-03
#  it----        1000
#  fld_a minmax values:  -4.02397973E-07   5.51373319E-07
#  fld_u minmax values:  -2.24152976E-03   1.97815499E-03
#  it----         500
#  fld_a minmax values:  -3.40225029E-07   3.91481308E-07
#  fld_u minmax values:  -3.47582228E-03   3.53789120E-03
#  Elapsed time to load boundary               8.09288025E-03
#  Elapsed time to update strains             0.781520844
#  Elapsed time to rm source strains           2.06375122E-03
#  Elapsed time to update momenta              1.01355791
#  Elapsed time to rm source momenta           1.98888779E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource strains       3.71885300E-03
#  Elapsed time to update adj strains         0.783534527
#  Elapsed time to add adjsource momenta       4.27770615E-03
#  Elapsed time to update adj momenta          1.00855494
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   1.70073509E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 3.47032136E-09
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    3.47032136E-09  L2sq=    3.47032136E-09
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 23:35:30
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
comp='pz-px'

plt.figure(figsize=(8,3))
plt.plot(read_su('results_PE_pz-px/dadj_Shot0001.su')[:,75])

glda=read('results_PE_pz-px/a_star_u%glda')
gmu =read('results_PE_pz-px/a_star_u%gmu' )

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,2,2); imshow(gmu ,title=comp+':gmu' ,perc=98)

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,2,2); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)

# %% [markdown]
# ### pz-ex

# %%
# !suwind < results_obs/Ru_Shot0001.su key=trid min=22 max=22 > data_0001.su

# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo 'FILE_DATA_PREFIX   data_' >> setup
# !echo "DIR_OUT     results_pe" >> setup
run(app='../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 842320 Nov  8 22:00 ../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 22:45:29
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_pe
#  Output directory:results_pe/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : data_
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : data_
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : pz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           5
#    minmax rx,ix:   0.00000000       1980.00000               1         199
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.51326370E-04
#  Elapsed time to update momenta      0.993611455
#  Elapsed time to add source strains     1.74641609E-03
#  Elapsed time to update strains        0.775453568
#  Elapsed time to extract field           6.05916977E-03
#  Elapsed time to save boundary           3.54182720E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007071E-04   6.61906495E-04
#  it----        1500
#  fld_a minmax values:  -3.85342243E-19   5.40815699E-19
#  fld_u minmax values:  -1.41741871E-03   1.74610049E-03
#  it----        1000
#  fld_a minmax values:  -2.63333387E-19   3.87577234E-19
#  fld_u minmax values:  -2.24152976E-03   1.97815499E-03
#  it----         500
#  fld_a minmax values:  -2.58036769E-19   2.86547565E-19
#  fld_u minmax values:  -3.47582228E-03   3.53789120E-03
#  Elapsed time to load boundary               7.74431229E-03
#  Elapsed time to update strains             0.780750751
#  Elapsed time to rm source strains           2.02369690E-03
#  Elapsed time to update momenta              1.00914621
#  Elapsed time to rm source momenta           1.92928314E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource strains       4.49752808E-03
#  Elapsed time to update adj strains         0.775068760
#  Elapsed time to add adjsource momenta       2.12764740E-03
#  Elapsed time to update adj momenta         0.998368740
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   1.68070793E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 1.94523658E-21
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    1.94523658E-21  L2sq=    1.94523658E-21
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 22:45:43
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
comp='pz-ex'

plt.figure(figsize=(8,3))
plt.plot(read_su('results_pe/dadj_Shot0001.su')[:,75])

glda=read('results_pe/a_star_u%glda')
gmu =read('results_pe/a_star_u%gmu' )

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,2,2); imshow(gmu ,title=comp+':gmu' ,perc=98)

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,2,2); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)

# %% [markdown]
# ## Velocity-Stress formulation

# %% [markdown]
# ### Obs

# %%
# !cp setup_default setup
# !echo "DIR_OUT     results_obs_VS" >> setup
# !echo 'SCOMP       vz' >> setup
# !echo 'RCOMP       vx' >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 601680 Nov  8 23:28 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 23:28:55
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs_VS
#  Output directory:results_obs_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : vx
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   999.999939
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           5
#    minmax rx,ix:   0.00000000       1980.00000               2         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1000.00000       1800.00000
#  vs   577.350281       1039.23047
#  rho   1000.00000       1000.00000
#  ip   1000000.00       1800000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 577.350281, 14.0000000
#  CFL value: 0.593969703
#  ppg%mu sanity:   333333344.       1.08000000E+09 F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.66051278E-09   3.54282093E-09
#  it----        1000
#  fld_u minmax values:  -2.43215870E-09   2.12444196E-09
#  it----        1500
#  fld_u minmax values:  -3.15657256E-09   2.07804041E-09
#  it----        2000
#  fld_u minmax values:  -5.88715188E-10   5.49600754E-10
#  Elapsed time to add source velocities   4.97937202E-04
#  Elapsed time to update velocities      0.592832804
#  Elapsed time to add source stresses     1.43074989E-03
#  Elapsed time to update stresses        0.696566463
#  Elapsed time to extract field           4.57227230E-03
#  Elapsed time to save boundary           3.50713730E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 23:28:58
# System timezone: +03:00

# %%
plt.figure(figsize=(8,4))

data=read_su('results_obs_VS/Ru_Shot0001.su',n=(ntr,nt))
plt.subplot(1,2,1); imshow(data,title='VS:vz-vx',perc=98)

data=read_su('results_obs/Ru_Shot0001.su',n=(5*ntr,nt))
plt.subplot(1,2,2); imshow(data[:,ntr:2*ntr],title='pz-px',perc=98)

# %% [markdown]
# ### vz-vx

# %%
# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo "FILE_DATA_PREFIX   'results_obs_VS/Ru_Shot'" >> setup
# !echo 'SCOMP       vz' >> setup
# !echo "DIR_OUT     results_VS" >> setup
run(app='../../exe/fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_FWIgradient
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 833944 Nov  8 23:27 ../../exe/fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/08/2023
# System time: 23:29:48
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_VS
#  Output directory:results_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : results_obs_VS/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : results_obs_VS/Ru_Shot
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : vz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           5
#    minmax rx,ix:   0.00000000       1980.00000               2         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911032E-09   3.33863892E-09
#  it----        1000
#  fld_u minmax values:  -2.24744423E-09   1.98091255E-09
#  it----        1500
#  fld_u minmax values:  -1.47457713E-09   1.31981059E-09
#  it----        2000
#  fld_u minmax values:  -6.87819246E-10   6.60713262E-10
#  Elapsed time to add source velocities   4.71830368E-04
#  Elapsed time to update velocities      0.563960314
#  Elapsed time to add source stresses     1.52111053E-03
#  Elapsed time to update stresses        0.671808362
#  Elapsed time to extract field           4.53209877E-03
#  Elapsed time to save boundary           3.14235687E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007295E-10   6.61906585E-10
#  it----        1500
#  fld_a minmax values:  -7.48175300E-19   7.48176489E-19
#  fld_u minmax values:  -1.41741918E-09   1.74609993E-09
#  it----        1000
#  fld_a minmax values:  -4.02398294E-19   5.51373884E-19
#  fld_u minmax values:  -2.24152896E-09   1.97815608E-09
#  it----         500
#  fld_a minmax values:  -3.40225073E-19   3.91481733E-19
#  fld_u minmax values:  -3.47582252E-09   3.53789176E-09
#  Elapsed time to load boundary               7.62677193E-03
#  Elapsed time to update stresses            0.671060085
#  Elapsed time to rm source stresses          1.74260139E-03
#  Elapsed time to update velocities          0.567243814
#  Elapsed time to rm source velocities        1.97005272E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      1.84726715E-03
#  Elapsed time to update adj stresses        0.664476633
#  Elapsed time to add adjsource velocities    3.63874435E-03
#  Elapsed time to update adj velocities      0.558639288
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   2.80897617E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 3.47032357E-21
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    3.47032357E-21  L2sq=    3.47032357E-21
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/08/2023
# System time: 23:29:57
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
comp='VS:vz-vx'

plt.figure(figsize=(8,3))
plt.subplot(2,1,1); plt.plot(read_su('results_VS/dadj_Shot0001.su')[:,75]); plt.title(comp)
plt.subplot(2,1,2); plt.plot(read_su('results_PE_pz-px/dadj_Shot0001.su')[:,75]); plt.title('PE:pz-px')

glda=read('results_VS/a_star_u%glda')
gmu =read('results_VS/a_star_u%gmu' )

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,2,2); imshow(gmu ,title=comp+':gmu' ,perc=98)

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,2,2); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)
