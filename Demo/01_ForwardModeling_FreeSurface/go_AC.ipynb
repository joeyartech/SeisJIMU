# %% [markdown]
# ## Preamble

# %%
import os
import numpy as np
#from scipy import signal
import matplotlib.pyplot as plt

# %%
vp=3000
vs=0.
rho=2500

nz=241; nx=241; h=5
nzsnap=289; nxsnap=289; nsnap=51

fpeak=15

dt=0.0004
nt=2500
t=np.arange(0,nt*dt,dt)-0.067

nr=1

# %%
# !makevel nx=$nx nz=$nz v000=$vp > vp
# !makevel nx=$nx nz=$nz v000=$vs > vs
# !makevel nx=$nx nz=$nz v000=$rho> rho
# !cat vp vs rho > model

# %%
def read(filename,n=(nx,nz)):
    return np.fromfile(filename,dtype='float32').reshape(n).T

def read_su(filename,n=(nr,nt)):
    data=read(filename,n=(n[0],int(60+n[1])))
    return data[60:,:]

def read_snap(filename,n=(nsnap,nxsnap,nzsnap),i=17):
    tmp=np.fromfile(filename,dtype='float32').reshape(n).T
#     return tmp[:,:,i]
    return tmp[24:24+nz,24:24+nx,i]

def imshow(data,perc=None,clip=None,clipmin=None,extent=None,cmap='viridis',title=None,grid=True):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],extent=extent,cmap=cmap,aspect='auto')
    plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    #plt.xlabel(labels[0]); plt.ylabel(labels[1])
    if title!=None: plt.title(title)

def run(app='../../exe/FWI',setup='setup',np=1,nthreads=8,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OpenMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"{app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        # !./run.sh
    else:
        # !./run.sh > {out}

# %%
# !cat setup_default2
# Out:
# MODEL_SIZE              '241   241   1'
# MODEL_SPACING           '5     5     1'
# MODEL_ORIGIN            '0     0     0'
# FILE_MODEL              'model'
# MODEL_ATTRIBUTES        'vp vs rho'
#
# ACQUI_GEOMETRY          spread
# FS                      ' 0   100 0'
# FR                      '30  1100 0'
# DR                      ' 0     0 0'
# NR                       1
#
# SCOMP                    vx
# RCOMP                   'vz vx p'
#
# NT           2500
# DT           0.0004
# WAVELET_TYPE ricker
# FPEAK        15
#
# SNAPSHOT     'vz vx szz sxx szx'
#
# IF_USE_CHECKPOINT   F
#
#
# #why the vz comp of dsyn is weird?

# %% [markdown]
# ## Test vforce
# Robertsson, Fig 1,2

# %% [markdown]
# ### No FS

# %%
# PSV modeling
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup
# !echo "IS_FREESURFACE   F" >>setup
# !echo "SCOMP         p" >> setup
# !echo "SNAPSHOT     'szz sxx'" >> setup
# !echo "DIR_OUT       res_PSV" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 759056 Nov  3 10:33 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 3aabe74
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 11/03/2025
# System time: 10:33:52
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_PSV2nd
#  Output directory:res_PSV2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              22
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:          18          26
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   0.00000000       0.00000000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  ppg%mu sanity:   0.00000000       0.00000000     F F
#  SNAPSHOT : szz sxx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : szz sxx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.70874828E-10   2.33253805E-10
#  it----        1000
#  fld_reU minmax values:  -1.16926621E-10   1.50717744E-10
#  it----        1500
#  fld_reU minmax values:  -4.36755250E-11   5.05123686E-11
#  it----        2000
#  fld_reU minmax values:  -4.45381232E-12   1.87551363E-11
#  it----        2500
#  fld_reU minmax values:  -4.45490606E-12   1.87540261E-11
#  Elapsed time to add source velocities   1.00946426E-02
#  Elapsed time to update velocities       5.06522655
#  Elapsed time to add source stresses     3.55434418E-03
#  Elapsed time to update stresses         4.96518421
#  Elapsed time to extract field           5.39493561E-03
#  Elapsed time to save boundary           1.96151733E-02
#  Total elapsed time (min):  0.167817831
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/03/2025
# System time: 10:34:05
# System timezone: +03:00

# %%
# AC modeling
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup
# !echo "IS_FREESURFACE   F" >>setup
# !echo "SCOMP         p" >> setup
# !echo "SNAPSHOT     'p'" >> setup
# !echo "DIR_OUT       res_AC" >> setup
run(app='../../exe/fwd_AC_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 767160 Nov  3 10:40 ../../exe/fwd_AC_FDSG_O4_
#  Git Commit: 3aabe74
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 11/03/2025
# System time: 10:40:58
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_AC
#  Output directory:res_AC/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Poynting definitions: p_dotp_gradp, dotp_gradp, p_v, Esq_gradphi
# Imaging conditions: ipp ibksc ifwsc (P-Pxcorr of backward
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              22
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:          18          26
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   0.00000000       0.00000000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  POYNTING_DEF is NOT found, take default: p_v
#  IF_ADCIG is NOT found, take 0, '' or F
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.06815478E-05   1.45783051E-05
#  it----        1000
#  fld_reU minmax values:  -6.74440435E-06   9.22158870E-06
#  it----        1500
#  fld_reU minmax values:  -2.78119842E-06   3.13865417E-06
#  it----        2000
#  fld_reU minmax values:  -2.78161878E-07   1.17129821E-06
#  it----        2500
#  fld_reU minmax values:  -2.77886755E-07   1.17157845E-06
#  Elapsed time to add source velocities   4.52804565E-03
#  Elapsed time to update velocities       5.06743145
#  Elapsed time to add source stresses     2.52819061E-03
#  Elapsed time to update stresses         5.01472187
#  Elapsed time to extract field           5.98144531E-03
#  Elapsed time to save boundary           1.58910751E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/03/2025
# System time: 10:41:11
# System timezone: +03:00

# %%
# AC2nd modeling
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup
# !echo "IS_FREESURFACE   F" >>setup
# !echo "SCOMP         p" >> setup
# !echo "SNAPSHOT     'p'" >> setup
# !echo "DIR_OUT       res_AC2nd" >> setup
run(app='../../exe/fwd_AC2nd_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 725056 Nov  3 10:45 ../../exe/fwd_AC2nd_FDSG_O4_
#  Git Commit: 3aabe74
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 11/03/2025
# System time: 10:46:21
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_AC2nd
#  Output directory:res_AC2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gikpa, gbuo
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : p
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx p
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              21
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:          17          25
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           3
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   0.00000000       0.00000000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#
# Program received signal SIGSEGV: Segmentation fault - invalid memory reference.
#
# Backtrace for this error:
# #0  0xbccec223e59 in ???
# #1  0xbccec222e75 in ???
# #2  0xbccebe4532f in ???
# 	at ./signal/../sysdeps/unix/sysv/linux/x86_64/libc_sigaction.c:0
# #3  0x60a8c7030a1d in ???
# #4  0x60a8c7034b93 in ???
# #5  0x60a8c703d455 in ???
# #6  0x60a8c6fb153e in ???
# #7  0xbccebe2a1c9 in __libc_start_call_main
# 	at ../sysdeps/nptl/libc_start_call_main.h:58
# #8  0xbccebe2a28a in __libc_start_main_impl
# 	at ../csu/libc-start.c:360
# #9  0x60a8c6fb1594 in ???
# #10  0xffffffffffffffff in ???
# ./run.sh: line 3: 25837 Segmentation fault      (core dumped) ../../exe/fwd_AC2nd_FDSG_O4_ setup

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV/snap_fld_reU%szz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV/snap_fld_reU%sxx'),perc=98)
plt.subplot(1,3,3); imshow(read_snap('res_PSV/snap_fld_reU%szz')+read_snap('res_PSV/snap_fld_reU%sxx'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_AC/snap_fld_reU%p'),perc=98)

# %%
trs=read_su('res_VS/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,trs[:,0]); plt.grid()
plt.subplot(1,2,2); plt.plot(t,trs[:,1]); plt.grid()

trs=read_su('res_PSV2nd/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,np.gradient(trs[:,0])); plt.grid()
plt.subplot(1,2,2); plt.plot(t,np.gradient(trs[:,1])); plt.grid()

# %% [markdown]
# Good match!

# %% [markdown]
# ### w/ FS

# %%
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup

# !echo "SCOMP         vz" >> setup
# !echo "RCOMP        'vz vx'" >> setup
# !echo "SNAPSHOT     'vz vx'" >> setup
# !echo "DIR_OUT     res_VS" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 552968 Oct 18  2024 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 37e8fa6
#  Git Branch: DAS
#  Compiler: gfortran v13.2.0
#  Version: 13.2.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:24:43
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_VS
#  Output directory:res_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              22
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:          18          26
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -6.86468549E-10   1.02159303E-09
#  it----        1000
#  fld_u minmax values:  -5.19877863E-10   5.00603947E-10
#  it----        1500
#  fld_u minmax values:  -4.35721320E-10   4.51701787E-10
#  it----        2000
#  fld_u minmax values:  -2.41170528E-10   2.89996221E-10
#  it----        2500
#  fld_u minmax values:  -9.86460288E-11   1.35377015E-10
#  Elapsed time to add source velocities   5.06258011E-03
#  Elapsed time to update velocities      0.558226347
#  Elapsed time to add source stresses     3.51762772E-03
#  Elapsed time to update stresses        0.666308284
#  Elapsed time to extract field           6.60717487E-03
#  Elapsed time to save boundary           2.23525763E-02
#  Total elapsed time (min):   2.10345760E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:24:44
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx',i=34),perc=98)

# %%
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup

# !echo "SCOMP         uz" >> setup
# !echo "RCOMP        'uz ux'" >> setup
# !echo "SNAPSHOT     'uz ux'" >> setup
# !echo "DIR_OUT       res_PSV2nd" >> setup
run(app='../../exe/fwd_PSV2nd_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 758408 Oct 30 18:32 ../../exe/fwd_PSV2nd_FDSG_O4_
#  Git Commit: d719e67
#  Git Branch: grad_extd_VDSR
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:33:07
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_PSV2nd
#  Output directory:res_PSV2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D PSV (ELastic) propagation
# 2nd-order Displacement formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: uz, ux, uz_prev, ux_prev, uz_next, ux_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho(wait) glda gmu
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : uz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : uz ux
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              22
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:          18          26
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -8.81288618E-12   9.62446876E-12
#  it----        1000
#  fld_u minmax values:  -5.29183988E-12   4.96712827E-12
#  it----        1500
#  fld_u minmax values:  -4.90850459E-12   4.90898685E-12
#  it----        2000
#  fld_u minmax values:  -2.66896206E-12   4.18122741E-12
#  it----        2500
#  fld_u minmax values:  -9.29000366E-13   1.29550797E-12
#  Elapsed time to add source                 7.93409348E-03
#  Elapsed time to save boundary              2.16934681E-02
#  Elapsed time to update field               2.92437577
#  Elapsed time to evolve field               3.45849991E-03
#  Elapsed time to extract field              5.99408150E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:33:10
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux',i=34),perc=98)

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux',i=34),perc=98)

# %%
trs1=read_su('res_VS/Ru_Shot0001.su',n=(2,nt))
trs2=read_su('res_PSV2nd/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,trs1[:,0]); plt.grid()
plt.subplot(1,2,2); plt.plot(t,trs1[:,1]); plt.grid()

plt.subplot(1,2,1); plt.plot(t,np.gradient(trs2[:,0])/dt); plt.grid()
plt.subplot(1,2,2); plt.plot(t,np.gradient(trs2[:,1])/dt); plt.grid()

# %% [markdown]
# Good match!

# %% [markdown]
# ## Test hforce
# Robertsson, Fig 1,2

# %%
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup

# !echo "SCOMP         vx" >> setup
# !echo "RCOMP        'vz vx'" >> setup
# !echo "SNAPSHOT     'vz vx'" >> setup
# !echo "DIR_OUT     res_VS" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 552968 Oct 18  2024 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 37e8fa6
#  Git Branch: DAS
#  Compiler: gfortran v13.2.0
#  Version: 13.2.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:34:11
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_VS
#  Output directory:res_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vx
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              21
#    sx,ix:   100.000000              22
#    sy,iy:   0.00000000               1
#    ifz,ilz:          17          25
#    ifx,ilx:          18          26
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -5.10630205E-10   4.80696538E-10
#  it----        1000
#  fld_u minmax values:  -2.54697791E-10   2.73672890E-10
#  it----        1500
#  fld_u minmax values:  -2.38545711E-10   2.22602478E-10
#  it----        2000
#  fld_u minmax values:  -2.16839852E-10   1.92537319E-10
#  it----        2500
#  fld_u minmax values:  -1.09109971E-10   1.33861922E-10
#  Elapsed time to add source velocities   3.66556644E-03
#  Elapsed time to update velocities      0.465666175
#  Elapsed time to add source stresses     4.99415398E-03
#  Elapsed time to update stresses        0.535511017
#  Elapsed time to extract field           5.23185730E-03
#  Elapsed time to save boundary           1.32688284E-02
#  Total elapsed time (min):   1.71389598E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:34:12
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx',i=34),perc=98)

# %%
# !cp setup_default2 setup
# !echo "FS          '100   100 0'" >>setup
# !echo "FR          '600   600 0'" >>setup

# !echo "SCOMP         ux" >> setup
# !echo "RCOMP        'uz ux'" >> setup
# !echo "SNAPSHOT     'uz ux'" >> setup
# !echo "DIR_OUT       res_PSV2nd" >> setup
run(app='../../exe/fwd_PSV2nd_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 758408 Oct 30 18:32 ../../exe/fwd_PSV2nd_FDSG_O4_
#  Git Commit: d719e67
#  Git Branch: grad_extd_VDSR
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:34:15
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_PSV2nd
#  Output directory:res_PSV2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D PSV (ELastic) propagation
# 2nd-order Displacement formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: uz, ux, uz_prev, ux_prev, uz_next, ux_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho(wait) glda gmu
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : ux
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 100   100 0
#  RECEIVER_FIRST (FR) : 600   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : uz ux
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   100.000000              21
#    sx,ix:   100.000000              22
#    sy,iy:   0.00000000               1
#    ifz,ilz:          17          25
#    ifx,ilx:          18          26
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   600.000000       600.000000             121         122
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:         117         118         125         126
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -5.71951124E-12   4.89189115E-12
#  it----        1000
#  fld_u minmax values:  -2.29234882E-12   2.34772033E-12
#  it----        1500
#  fld_u minmax values:  -2.26644029E-12   1.98657280E-12
#  it----        2000
#  fld_u minmax values:  -2.10752900E-12   1.74669079E-12
#  it----        2500
#  fld_u minmax values:  -1.07067805E-12   1.33445371E-12
#  Elapsed time to add source                 4.13203239E-03
#  Elapsed time to save boundary              3.64367962E-02
#  Elapsed time to update field               2.88067198
#  Elapsed time to evolve field               2.44283676E-03
#  Elapsed time to extract field              6.40726089E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:34:19
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux',i=34),perc=98)

# %%
trs1=read_su('res_VS/Ru_Shot0001.su',n=(2,nt))
trs2=read_su('res_PSV2nd/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,trs1[:,0]); plt.grid()
plt.subplot(1,2,2); plt.plot(t,trs1[:,1]); plt.grid()

plt.subplot(1,2,1); plt.plot(t,np.gradient(trs2[:,0])/dt); plt.grid()
plt.subplot(1,2,2); plt.plot(t,np.gradient(trs2[:,1])/dt); plt.grid()

# %% [markdown]
# Good match!

# %% [markdown]
# ## acqui close to FS
# Robertsson, Fig 1,2

# %% [markdown]
# ### Test vforce

# %%
# !cp setup_default2 setup
# !echo "FS          '10   100 0'" >>setup
# !echo "FR          '10   600 0'" >>setup

# !echo "SCOMP         vz" >> setup
# !echo "RCOMP        'vz vx'" >> setup
# !echo "SNAPSHOT     'vz vx'" >> setup
# !echo "DIR_OUT     res_VS" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 552968 Oct 18  2024 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 37e8fa6
#  Git Branch: DAS
#  Compiler: gfortran v13.2.0
#  Version: 13.2.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:41:49
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_VS
#  Output directory:res_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 10   100 0
#  RECEIVER_FIRST (FR) : 10   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   10.0000000               4
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           8
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   10.0000000       10.0000000               3           4
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -1           0           7           8
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -1.43637513E-09   2.45435650E-09
#  it----        1000
#  fld_u minmax values:  -1.64284253E-09   2.62899724E-09
#  it----        1500
#  fld_u minmax values:  -1.68530312E-09   2.63701150E-09
#  it----        2000
#  fld_u minmax values:  -1.07384568E-09   9.66981606E-10
#  it----        2500
#  fld_u minmax values:  -1.53373259E-10   2.07392201E-10
#  Elapsed time to add source velocities   6.51001930E-03
#  Elapsed time to update velocities      0.447313190
#  Elapsed time to add source stresses     3.87024879E-03
#  Elapsed time to update stresses        0.497494340
#  Elapsed time to extract field           3.13246250E-03
#  Elapsed time to save boundary           1.86884403E-02
#  Total elapsed time (min):   1.62834786E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:41:50
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx',i=34),perc=98)

# %%
# !cp setup_default2 setup
# !echo "FS          '10   100 0'" >>setup
# !echo "FR          '10   600 0'" >>setup

# !echo "SCOMP         uz" >> setup
# !echo "RCOMP        'uz ux'" >> setup
# !echo "SNAPSHOT     'uz ux'" >> setup
# !echo "DIR_OUT       res_PSV2nd" >> setup
run(app='../../exe/fwd_PSV2nd_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 758408 Oct 30 18:32 ../../exe/fwd_PSV2nd_FDSG_O4_
#  Git Commit: d719e67
#  Git Branch: grad_extd_VDSR
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:41:56
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_PSV2nd
#  Output directory:res_PSV2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D PSV (ELastic) propagation
# 2nd-order Displacement formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: uz, ux, uz_prev, ux_prev, uz_next, ux_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho(wait) glda gmu
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : uz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 10   100 0
#  RECEIVER_FIRST (FR) : 10   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : uz ux
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   10.0000000               4
#    sx,ix:   100.000000              21
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           8
#    ifx,ilx:          17          25
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   10.0000000       10.0000000               3           4
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -1           0           7           8
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -1.89950139E-11   2.02446254E-11
#  it----        1000
#  fld_u minmax values:  -2.14830376E-11   1.99933594E-11
#  it----        1500
#  fld_u minmax values:  -2.21978581E-11   1.97495388E-11
#  it----        2000
#  fld_u minmax values:  -4.07960775E-12   1.32069017E-11
#  it----        2500
#  fld_u minmax values:  -1.37288585E-12   2.25042576E-12
#  Elapsed time to add source                 7.16280937E-03
#  Elapsed time to save boundary              2.12533474E-02
#  Elapsed time to update field               2.69948769
#  Elapsed time to evolve field               4.57668304E-03
#  Elapsed time to extract field              5.61809540E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:41:59
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux',i=34),perc=98)

# %%
trs1=read_su('res_VS/Ru_Shot0001.su',n=(2,nt))
trs2=read_su('res_PSV2nd/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,trs1[:,0]); plt.grid()
plt.subplot(1,2,2); plt.plot(t,trs1[:,1]); plt.grid()

plt.subplot(1,2,1); plt.plot(t,np.gradient(trs2[:,0])/dt); plt.grid()
plt.subplot(1,2,2); plt.plot(t,np.gradient(trs2[:,1])/dt); plt.grid()

# %% [markdown]
# Good match!

# %% [markdown]
# ### Test hforce

# %%
# !cp setup_default2 setup
# !echo "FS          '10   100 0'" >>setup
# !echo "FR          '10   600 0'" >>setup

# !echo "SCOMP         vx" >> setup
# !echo "RCOMP        'vz vx'" >> setup
# !echo "SNAPSHOT     'vz vx'" >> setup
# !echo "DIR_OUT     res_VS" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 552968 Oct 18  2024 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 37e8fa6
#  Git Branch: DAS
#  Compiler: gfortran v13.2.0
#  Version: 13.2.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:42:28
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_VS
#  Output directory:res_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : vx
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 10   100 0
#  RECEIVER_FIRST (FR) : 10   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   10.0000000               3
#    sx,ix:   100.000000              22
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -1           7
#    ifx,ilx:          18          26
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   10.0000000       10.0000000               3           4
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -1           0           7           8
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  FS_METHOD is NOT found, take default: stress_image
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : vz vx
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -4.90658514E-10   4.38330927E-10
#  it----        1000
#  fld_u minmax values:  -3.84579674E-10   3.98775873E-10
#  it----        1500
#  fld_u minmax values:  -3.86890658E-10   4.12154727E-10
#  it----        2000
#  fld_u minmax values:  -2.92357638E-10   2.53872506E-10
#  it----        2500
#  fld_u minmax values:  -2.72590339E-10   2.40989867E-10
#  Elapsed time to add source velocities   3.30102444E-03
#  Elapsed time to update velocities      0.452242851
#  Elapsed time to add source stresses     2.02357769E-03
#  Elapsed time to update stresses        0.502601862
#  Elapsed time to extract field           3.42273712E-03
#  Elapsed time to save boundary           2.02264786E-02
#  Total elapsed time (min):   1.63969751E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:42:29
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_VS/snap_fld_u%vz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_VS/snap_fld_u%vx',i=34),perc=98)

# %%
# !cp setup_default2 setup
# !echo "FS          '10   100 0'" >>setup
# !echo "FR          '10   600 0'" >>setup

# !echo "SCOMP         ux" >> setup
# !echo "RCOMP        'uz ux'" >> setup
# !echo "SNAPSHOT     'uz ux'" >> setup
# !echo "DIR_OUT       res_PSV2nd" >> setup
run(app='../../exe/fwd_PSV2nd_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/01_ForwardModeling_FreeSurface
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 wzhou wzhou 758408 Oct 30 18:32 ../../exe/fwd_PSV2nd_FDSG_O4_
#  Git Commit: d719e67
#  Git Branch: grad_extd_VDSR
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 10/30/2025
# System time: 18:42:35
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : res_PSV2nd
#  Output directory:res_PSV2nd/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D PSV (ELastic) propagation
# 2nd-order Displacement formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: uz, ux, uz_prev, ux_prev, uz_next, ux_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho(wait) glda gmu
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 241   241   1
#  MODEL_SPACING (DZXY) : 5     5     1
#  2D geometry
#  MODEL_ORIGIN (OZXY) : 0     0     0
#  FILE_MODEL : model
#  MODEL_ATTRIBUTES : vp vs rho
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp vs rho
#  vp model is read.
#  vs model is read.
#  rho model is read.
#  IS_FREESURFACE is NOT found, take default: T
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  IF_BATHY_FROM_VS is NOT found, take default: T
#  Freeze zone is additionally set from vs model.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2500
#  TIME_INTERVAL (DT) : 0.0004
#  SOURCE_COMPONENT (SCOMP) : ux
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 10   100 0
#  RECEIVER_FIRST (FR) : 10   600 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0     0 0
#  NUMBER_RECEIVER (NR) : 1
#  RECEIVER_COMPONENT (RCOMP) : uz ux
#  PEAK_FREQUENCY (FPEAK) : 15
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 30.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 6.66666701E-02
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   3000.00000
#  Reference rho value =   2500.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2500   3.99999990E-04
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   10.0000000               3
#    sx,ix:   100.000000              22
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -1           7
#    ifx,ilx:          18          26
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   10.0000000       10.0000000               3           4
#    minmax rx,ix:   600.000000       600.000000             121         122
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -1           0           7           8
#    minmax ifx,ilx:         117         118         125         126
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        83521
#    [ifz,ilz],nz:         -23         265         289
#    [ifx,ilx],nx:         -23         265         289
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         241
#    iox,mx:           1         241
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   3000.00000       3000.00000
#  vs   1730.00000       1730.00000
#  rho   2500.00000       2500.00000
#  ip   7500000.00       7500000.00
#  CFL value: 0.395979762
#  ppg%mu sanity:   7.48225024E+09   7.48225024E+09 F F
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : uz ux
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 1.66666675E-02
#  rdt, irdt = 1.64000001E-02, 41
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -4.31049901E-12   5.89143534E-12
#  it----        1000
#  fld_u minmax values:  -3.50361558E-12   5.50241406E-12
#  it----        1500
#  fld_u minmax values:  -3.15285341E-12   5.62936113E-12
#  it----        2000
#  fld_u minmax values:  -2.93245333E-12   2.80519618E-12
#  it----        2500
#  fld_u minmax values:  -2.77658343E-12   1.48410342E-12
#  Elapsed time to add source                 4.80866432E-03
#  Elapsed time to save boundary              2.30417252E-02
#  Elapsed time to update field               2.77018929
#  Elapsed time to evolve field               3.28111649E-03
#  Elapsed time to extract field              3.23081017E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=289 perc=99
#  xmovie < snap_sfield%*  n1=289 n2=289 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 10/30/2025
# System time: 18:42:38
# System timezone: +03:00

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz'),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read_snap('res_PSV2nd/snap_fld_u%uz',i=34),perc=98)
plt.subplot(1,3,2); imshow(read_snap('res_PSV2nd/snap_fld_u%ux',i=34),perc=98)

# %%
trs1=read_su('res_VS/Ru_Shot0001.su',n=(2,nt))
trs2=read_su('res_PSV2nd/Ru_Shot0001.su',n=(2,nt))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1); plt.plot(t,trs1[:,0]); plt.grid()
plt.subplot(1,2,2); plt.plot(t,trs1[:,1]); plt.grid()

plt.subplot(1,2,1); plt.plot(t,np.gradient(trs2[:,0])/dt); plt.grid()
plt.subplot(1,2,2); plt.plot(t,np.gradient(trs2[:,1])/dt); plt.grid()

# %% [markdown]
# Good match!
