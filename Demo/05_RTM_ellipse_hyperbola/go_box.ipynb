# %%
import os
import numpy as np
#from scipy import signal
import matplotlib.pyplot as plt

# %%
#make model to Xie (2021)
Z1=500; Z2=1000; X=1500
vmin=2500; vmax=3000

h=20  #500/20=25
nz1=26; nz2=50; nz=nz1+nz2; nx=X//h+1
print(nz,nx)
ntr=76

nsnap=51; nzsnap=124; nxsnap=124

#5h=lambda=vmin/fmax
fmax=vmin/(5*h) #
fpeak=fmax/2.5  #10 Hz

#on time
dt=0.002  #=half of CFL
nt=750
# Out:
# 76 76

# %%
def read(filename,n=(nx,nz)):
    return np.fromfile(filename,dtype='float32').reshape(n).T

def read_su(filename,n=(ntr,nt)):
    data=read(filename,n=(n[0],int(60+n[1])))
    return data[60:,:]

def read_snap(filename,n=(nsnap,nxsnap,nzsnap),i=26):
    tmp=np.fromfile(filename,dtype='float32').reshape(n).T
    return tmp[:,:,i]

def imshow(data,perc=None,clip=None,clipmin=None,extent=None,cmap='viridis',title=None,grid=True):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],extent=extent,cmap=cmap,aspect='auto')
    plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    #plt.xlabel(labels[0]); plt.ylabel(labels[1])
    if title!=None: plt.title(title)

def run(app='../../exe/RTM',setup='setup',np=1,nthreads=8,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OpenMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"{app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        # !./run.sh
    else:
        # !./run.sh > {out}
    

def poynting_dotp_gradp(p,p_prev,p_next):
    dotp=(p_next+p_prev-2.*p)/dt**2
    dpdz=np.gradient(p,1./h,axis=0)
    dpdx=np.gradient(p,1./h,axis=1)
    return (dotp*dpdz, dotp*dpdx)
    
def poynting_p_dotp_gradp(p,p_prev,p_next):
    tmp=poynting_dotp_gradp(p,p_prev,p_next)
    return (p*tmp[0], p*tmp[1])

def poynting_p_v(p,vz,vx):
    return (-p*vz, -p*vx)

def gradphi(v,u):
    ph=np.arctan2(v,u)
    dphdz=np.arcsin(np.sin(np.gradient(ph,axis=0)))/h
    dphdx=np.arcsin(np.sin(np.gradient(ph,axis=1)))/h
    return (dphdz,dphdx)

# %%
#make model
vp=np.zeros((nz,nx)); print(vp.shape)
vp[:,:]=vmin; vp[35:41,35:41]=vmax
vp.astype('float32').T.tofile('true')

vp[:nz1,:]=vmin; vp[nz1:,:]=vmin
vp.astype('float32').T.tofile('homo')

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('homo'))
# Out:
# (76, 76)

# %%
# !cat setup_default
# Out:
# MODEL_SIZE              '76 76 1'
# MODEL_SPACING           '20 20 1'
# FILE_MODEL              'true'
# MODEL_ATTRIBUTES         vp
# FILE_TOPO               'topo'
#
# IS_FREESURFACE          F
#
# ACQUI_GEOMETRY          spread
# FS                      '20 760 0'
# FR                      '20   0 0'
# DR                      '0   20  0'
# NR                      76
#
# SCOMP                   p
# RCOMP                   p #'p vz'
#
# NT               750
# DT               0.002
#
#
# FPEAK            10
# WAVELET_TYPE        'ricker'
# T0			0.15
# UPDATE_WAVELET		'no'
# RDT			0
#
#
# SNAPSHOT     'p'
# #SNAPSHOT     'p poynz poynx'
# #NSNAPSHOT    50
#
#
# ## for RTM ##
# FILE_DATA_PREFIX    'results_obs/Ru_Shot'
#
# JOB           imaging
#
# IF_USE_CHECKPOINT   F

# %% [markdown]
# ## Obs

# %%
# !cp setup_default setup
# !echo "DIR_OUT     results_obs" >> setup
run(app='../../exe/fwd_AC_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 646912 Aug 30 10:41 ../../exe/fwd_AC_FDSG_O4_
#  Git Commit: 27d8e8c
#  Git Branch: Poynting
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:16:46
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs
#  Output directory:results_obs/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Poynting definitions: p_dotp_gradp, dotp_gradp, p_v
# Imaging conditions: ipp ibksc ifwsc (P-Pxcorr of backward & forward sc
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 750
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : p
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 20 760 0
#  RECEIVER_FIRST (FR) : 20   0 0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0   20  0
#  NUMBER_RECEIVER (NR) : 76
#  RECEIVER_COMPONENT (RCOMP) : p
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   0.00000000       1500.00000               1          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          -3          72           5          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:          76
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       3000.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       3000000.00
#  CFL value: 0.494974762
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_dotp_gradp
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -394.207825       287.808807
#  Elapsed time to add source velocities   1.24774873E-04
#  Elapsed time to update velocities       2.93520167E-02
#  Elapsed time to add source stresses     5.38252294E-04
#  Elapsed time to update stresses         2.78952867E-02
#  Elapsed time to extract field           2.86534429E-03
#  Elapsed time to save boundary           2.66782939E-04
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  ----  Solving Av=H[s]  ----
#  FILE_WAVELET_HILB is NOT found, take 0, '' or F
#  WAVELET_TYPE_HILB is NOT found, take default: ricker hilbert
#  Use Ricker hilbert wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_v minmax values:  -299.908234       398.247223
#  Elapsed time to add source velocities   1.68785453E-04
#  Elapsed time to update velocities       2.80725211E-02
#  Elapsed time to add source stresses     5.15848398E-04
#  Elapsed time to update stresses         2.70312279E-02
#  Elapsed time to extract field           2.99242139E-03
#  Elapsed time to save boundary           3.73825431E-04
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:16:47
# System timezone: +03:00

# %%
## plot
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read_su('results_obs/Ru_Shot0001.su'),perc=90)

# %% [markdown]
# ## all traces

# %% [markdown]
# ### RTM

# %%
# !cp setup_default setup
# !echo "FILE_MODEL   homo" >>setup
# !echo "DIR_OUT     results_rtm" >> setup
run(app='../../exe/rtm_AC_FDSG_O4')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2439288 Sep  2 12:40 ../../exe/rtm_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:16:48
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTM
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_rtm
#  Output directory:results_rtm/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : results_obs/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : results_obs/Ru_Shot
#  ntr, ns, file_size = 76, 750, 61560
#  Shot0001 will read 76 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   0.00000000       1500.00000               1          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          -3          72           5          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:          76
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -453.117126       374.037689
#  Elapsed time to add source velocities   1.28164887E-04
#  Elapsed time to update velocities       8.90350491E-02
#  Elapsed time to add source stresses     9.57235694E-04
#  Elapsed time to update stresses         8.18700492E-02
#  Elapsed time to extract field           5.53300977E-03
#  Elapsed time to save boundary           1.28085911E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
# At line 437 of file m_field.f90
# Fortran runtime warning: An array temporary was created for argument 'datain' of procedure 'resampler'
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : imaging
#  JOB : imaging
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a minmax values:  -249738.391       265442.250
#  fld_u minmax values:  -20.2293873       14.9365501
#  Elapsed time to load boundary               2.34478712E-03
#  Elapsed time to update stresses             8.21226835E-02
#  Elapsed time to rm source stresses          1.02001429E-03
#  Elapsed time to update velocities           1.53211951E-02
#  Elapsed time to rm source velocities        9.14387107E-02
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      5.96129894E-03
#  Elapsed time to update adj stresses         8.70129466E-02
#  Elapsed time to add adjsource velocities    5.49018383E-04
#  Elapsed time to update adj velocities       1.53493881E-03
#  Elapsed time to extract&write fields        9.53223705E-02
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   1.53211951E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  JOB : imaging
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:16:50
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_rtm/correlate_image'),clip=(-2e11,2e11))

# %% [markdown]
# ## symm 2 traces

# %% [markdown]
# ### RTM ellipse

# %%
# !cp setup_default setup
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=19 max=19 > obs_Shot0001_1.su
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=57 max=57 > obs_Shot0001_2.su
# !cat obs_Shot0001_1.su obs_Shot0001_2.su > obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !echo "DIR_OUT     results_2tr_rtm" >> setup
run(app='../../exe/rtm_AC_FDSG_O4')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2439288 Sep  2 12:40 ../../exe/rtm_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:16:52
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTM
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtm
#  Output directory:results_2tr_rtm/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 2, 750, 1620
#  Shot0001 will read 2 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   360.000000       1120.00000              19          57
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          15          53          23          61
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -453.117126       374.037689
#  Elapsed time to add source velocities   1.06334686E-04
#  Elapsed time to update velocities       9.28533673E-02
#  Elapsed time to add source stresses     6.83292747E-04
#  Elapsed time to update stresses         8.51213783E-02
#  Elapsed time to extract field           7.56993890E-04
#  Elapsed time to save boundary           1.31177902E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
# At line 437 of file m_field.f90
# Fortran runtime warning: An array temporary was created for argument 'datain' of procedure 'resampler'
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : imaging
#  JOB : imaging
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a minmax values:  -4570.09082       11906.4229
#  fld_u minmax values:  -20.2293873       14.9365501
#  Elapsed time to load boundary               2.16418505E-03
#  Elapsed time to update stresses             8.25821757E-02
#  Elapsed time to rm source stresses          8.69631767E-04
#  Elapsed time to update velocities           1.52233839E-02
#  Elapsed time to rm source velocities        9.12302732E-02
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      7.85529613E-04
#  Elapsed time to update adj stresses         8.69456530E-02
#  Elapsed time to add adjsource velocities    4.93168831E-04
#  Elapsed time to update adj velocities       4.17768955E-04
#  Elapsed time to extract&write fields        9.52200294E-02
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   1.52233839E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  JOB : imaging
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:16:54
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtm/correlate_image'),clip=(-2e10,2e10))

# %% [markdown]
# ### RTM hyperbola

# %%
# !cp setup_default setup
# !cp obs_Shot0001_1.su obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !ls -l obs_Shot0001.su obs_Shot0001_2.su
# !echo "DIR_OUT     results_2tr_rtmhyperbola" >> setup
run(app='../../exe/rtmhyperbola_AC_FDSG_O4')
# Out:
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:16 obs_Shot0001_2.su
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:16 obs_Shot0001.su
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2437648 Sep  2 14:16 ../../exe/rtmhyperbola_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:16:56
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTMhyperbola
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtmhyperbola
#  Output directory:results_2tr_rtmhyperbola/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   360.000000       360.000000              19          19
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          15          15          23          23
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  IF_HICKS is NOT found, take default: T
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  R positions after removing m%oz,ox,iy,
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   1120.00000       1120.00000              57          57
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          53          53          61          61
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a1 minmax values:  -2747.56421       10898.4863
#  fld_a2 minmax values:  -1905.42188       4023.83032
#  it----           0
#  fld_a1 minmax values:  -7425549.00       12759446.0
#  fld_a2 minmax values:  -8050857.00       13818368.0
#  it----        -500
#  fld_a1 minmax values:  -28633.8867       23822.6035
#  fld_a2 minmax values:  -32026.2148       26213.8555
#  Elapsed time to add adjsource stresses      1.63489580E-03
#  Elapsed time to update adj stresses        0.389895558
#  Elapsed time to add adjsource velocities    0.00000000
#  Elapsed time to update adj velocities       0.00000000
#  Elapsed time to extract&write fields       0.420052052
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   3.43836546E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:16:58
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtmhyperbola/correlate_image'),perc=98)

# %%
ellipse=read('results_2tr_rtm/correlate_image')
hyperbola=read('results_2tr_rtmhyperbola/correlate_image')
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(ellipse,clip=(-2e10,2e10))
plt.subplot(1,2,2); imshow(hyperbola,clip=(-2e15,2e15))

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(ellipse*1e5+hyperbola,clip=(-2e15,2e15))

# %% [markdown]
# ## asymm 2 traces case 1

# %% [markdown]
# ### RTM ellipse

# %%
# !cp setup_default setup
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=38 max=38 > obs_Shot0001_1.su
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=76 max=76 > obs_Shot0001_2.su
# !cat obs_Shot0001_1.su obs_Shot0001_2.su > obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !echo "DIR_OUT     results_2tr_rtm" >> setup
run(app='../../exe/rtm_AC_FDSG_O4')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2439288 Sep  2 12:40 ../../exe/rtm_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:17:01
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTM
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtm
#  Output directory:results_2tr_rtm/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 2, 750, 1620
#  Shot0001 will read 2 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   740.000000       1500.00000              38          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          34          72          42          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -453.117126       374.037689
#  Elapsed time to add source velocities   1.19999051E-04
#  Elapsed time to update velocities       9.02861357E-02
#  Elapsed time to add source stresses     8.76575708E-04
#  Elapsed time to update stresses         8.29782486E-02
#  Elapsed time to extract field           9.73179936E-04
#  Elapsed time to save boundary           1.66279078E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
# At line 437 of file m_field.f90
# Fortran runtime warning: An array temporary was created for argument 'datain' of procedure 'resampler'
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : imaging
#  JOB : imaging
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a minmax values:  -14612.1094       3841.84106
#  fld_u minmax values:  -20.2293873       14.9365501
#  Elapsed time to load boundary               2.16495991E-03
#  Elapsed time to update stresses             8.28141570E-02
#  Elapsed time to rm source stresses          9.78529453E-04
#  Elapsed time to update velocities           1.46288276E-02
#  Elapsed time to rm source velocities        9.15819407E-02
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      8.00967216E-04
#  Elapsed time to update adj stresses         8.46649408E-02
#  Elapsed time to add adjsource velocities    5.28454781E-04
#  Elapsed time to update adj velocities       4.87029552E-04
#  Elapsed time to extract&write fields        9.25559402E-02
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   1.46288276E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  JOB : imaging
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:17:02
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtm/correlate_image'),clip=(-2e10,2e10))

# %% [markdown]
# ### RTM hyperbola

# %%
# !cp setup_default setup
# !cp obs_Shot0001_1.su obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !ls -l obs_Shot0001.su obs_Shot0001_2.su
# !echo "DIR_OUT     results_2tr_rtmhyperbola" >> setup
run(app='../../exe/rtmhyperbola_AC_FDSG_O4')
# Out:
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:17 obs_Shot0001_2.su
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:17 obs_Shot0001.su
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2437648 Sep  2 14:16 ../../exe/rtmhyperbola_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:17:04
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTMhyperbola
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtmhyperbola
#  Output directory:results_2tr_rtmhyperbola/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   740.000000       740.000000              38          38
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          34          34          42          42
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  IF_HICKS is NOT found, take default: T
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  R positions after removing m%oz,ox,iy,
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   1500.00000       1500.00000              76          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          72          72          80          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a1 minmax values:  -3215.83545       3542.44507
#  fld_a2 minmax values:  -15543.0742       4392.35449
#  it----           0
#  fld_a1 minmax values:  -44176452.0       75014544.0
#  fld_a2 minmax values:  -4480503.00       7820543.00
#  it----        -500
#  fld_a1 minmax values:  -241333.312       222873.125
#  fld_a2 minmax values:  -17463.1211       15241.8135
#  Elapsed time to add adjsource stresses      1.56432390E-03
#  Elapsed time to update adj stresses        0.397190630
#  Elapsed time to add adjsource velocities    0.00000000
#  Elapsed time to update adj velocities       0.00000000
#  Elapsed time to extract&write fields       0.426895142
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   3.48513126E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:17:06
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtmhyperbola/correlate_image'),perc=98)

# %%
ellipse=read('results_2tr_rtm/correlate_image')
hyperbola=read('results_2tr_rtmhyperbola/correlate_image')
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(ellipse,clip=(-2e10,2e10))
plt.subplot(1,2,2); imshow(hyperbola,clip=(-2e14,2e14))

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(ellipse*1e5+hyperbola,clip=(-2e15,2e15))

# %% [markdown]
# ## asymm 2 traces Case 2

# %% [markdown]
# ### RTM ellipse

# %%
# !cp setup_default setup
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=19 max=19 > obs_Shot0001_1.su
# !suwind < results_obs/Ru_Shot0001.su key=tracl min=76 max=76 > obs_Shot0001_2.su
# !cat obs_Shot0001_1.su obs_Shot0001_2.su > obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !echo "DIR_OUT     results_2tr_rtm" >> setup
run(app='../../exe/rtm_AC_FDSG_O4')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2439288 Sep  2 12:40 ../../exe/rtm_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:17:10
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTM
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtm
#  Output directory:results_2tr_rtm/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 2, 750, 1620
#  Shot0001 will read 2 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   360.000000       1500.00000              19          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          15          72          23          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:           2
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_u minmax values:  -453.117126       374.037689
#  Elapsed time to add source velocities   1.32694840E-04
#  Elapsed time to update velocities       9.02322531E-02
#  Elapsed time to add source stresses     7.74607062E-04
#  Elapsed time to update stresses         8.26220214E-02
#  Elapsed time to extract field           8.82685184E-04
#  Elapsed time to save boundary           1.78466737E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=124 perc=99
#  xmovie < snap_sfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
# At line 437 of file m_field.f90
# Fortran runtime warning: An array temporary was created for argument 'datain' of procedure 'resampler'
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : imaging
#  JOB : imaging
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a minmax values:  -14778.0918       11799.9424
#  fld_u minmax values:  -20.2293873       14.9365501
#  Elapsed time to load boundary               2.14833021E-03
#  Elapsed time to update stresses             8.33647251E-02
#  Elapsed time to rm source stresses          8.60571861E-04
#  Elapsed time to update velocities           1.48437023E-02
#  Elapsed time to rm source velocities        9.19327140E-02
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      7.95483589E-04
#  Elapsed time to update adj stresses         8.70381594E-02
#  Elapsed time to add adjsource velocities    5.21361828E-04
#  Elapsed time to update adj velocities       4.60743904E-04
#  Elapsed time to extract&write fields        9.51064825E-02
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   1.48437023E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  JOB : imaging
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:17:11
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtm/correlate_image'),clip=(-2e10,2e10))

# %% [markdown]
# ### RTM hyperbola

# %%
# !cp setup_default setup
# !cp obs_Shot0001_1.su obs_Shot0001.su
# !echo "FILE_MODEL   homo" >>setup
# !echo "FILE_DATA_PREFIX    obs_Shot" >>setup
# !ls -l obs_Shot0001.su obs_Shot0001_2.su
# !echo "DIR_OUT     results_2tr_rtmhyperbola" >> setup
run(app='../../exe/rtmhyperbola_AC_FDSG_O4')
# Out:
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:17 obs_Shot0001_2.su
# -rw-rw-r-- 1 joey joey 3240 Sep  2 14:17 obs_Shot0001.su
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_Imaging
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 2437648 Sep  2 14:16 ../../exe/rtmhyperbola_AC_FDSG_O4
#  Git Commit: 2ca4544
#  Git Branch: ellipse_hyperbola
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 09/02/2023
# System time: 14:17:13
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU RTMhyperbola
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_2tr_rtmhyperbola
#  Output directory:results_2tr_rtmhyperbola/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D ACoustic propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606(for 2D) or 0.494(3D) *Vmax/dx
# Required model attributes: vp, rho
# Required field components: vz, vx, vy(3D), p
# Required boundary layer thickness: 2
# Imaging conditions: ipp (P-Pxcorr of backward & forward scattering)
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradient
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 76 76 1
#  MODEL_SPACING (DZXY) : 20 20 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : homo
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) : topo
#  File topo has 0 size or does NOT exist, return empty filename.
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : obs_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  FILE_DATA_PREFIX : obs_Shot
#  ntr, ns, file_size = 1, 750, 810
#  Shot0001 will read 1 traces, each trace has 750 samples.
#  SU data read success.
#  PEAK_FREQUENCY (FPEAK) : 10
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 20.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) : 0.15
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   2500.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   20.0000000               2
#    sx,ix:   760.000000              39
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -2           6
#    ifx,ilx:          35          43
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   360.000000       360.000000              19          19
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          15          15          23          23
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  IF_HICKS is NOT found, take default: T
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:         750   2.00000009E-03
#  ---------------------------------
#  R positions after removing m%oz,ox,iy,
#    minmax rz,iz:   20.0000000       20.0000000               2           2
#    minmax rx,ix:   1500.00000       1500.00000              76          76
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -2          -2           6           6
#    minmax ifx,ilx:          72          72          80          80
#    minmax ify,ily:           1           1           1           1
#    nrcv:           1
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        15376
#    [ifz,ilz],nz:         -23         100         124
#    [ifx,ilx],nx:         -23         100         124
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1          76
#    iox,mx:           1          76
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   2500.00000       2500.00000
#  rho   1000.00000       1000.00000
#  ip   2500000.00       2500000.00
#  CFL value: 0.412478954
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  SNAPSHOT : p
#  REF_NUMBER_SNAPSHOT (NSNAPSHOT) is NOT found, take default: 50
#  REF_RECT_TIME_INTEVAL (RDT) : 0
#  rdt, irdt = 2.00000009E-03, 1
#  POYNTING_DEF is NOT found, take default: p_v
#  -----------------------
#          Imaging
#  -----------------------
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----         500
#  fld_a1 minmax values:  -2747.56421       10898.4863
#  fld_a2 minmax values:  -14635.3691       1171.51318
#  it----           0
#  fld_a1 minmax values:  -7425549.00       12759446.0
#  fld_a2 minmax values:  -4480496.50       7820653.00
#  it----        -500
#  fld_a1 minmax values:  -28633.8867       23822.6035
#  fld_a2 minmax values:  -17213.2188       15072.0811
#  Elapsed time to add adjsource stresses      1.68102980E-03
#  Elapsed time to update adj stresses        0.396642625
#  Elapsed time to add adjsource velocities    0.00000000
#  Elapsed time to update adj velocities       0.00000000
#  Elapsed time to extract&write fields       0.422735870
#  Elapsed time to compute Poynting vectors    0.00000000
#  Elapsed time to correlate                   3.58460546E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=124 perc=99
#  xmovie < snap_rfield%*  n1=124 n2=124 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=76 perc=99
#  xmovie < snap_*  n1=76 n2=76 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/02/2023
# System time: 14:17:16
# System timezone: +03:00

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(read('results_2tr_rtmhyperbola/correlate_image'),perc=98)

# %%
ellipse=read('results_2tr_rtm/correlate_image')
hyperbola=read('results_2tr_rtmhyperbola/correlate_image')
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(ellipse,clip=(-2e10,2e10))
plt.subplot(1,2,2); imshow(hyperbola,clip=(-2e14,2e14))

plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('true'))
plt.subplot(1,2,2); imshow(ellipse*1e5+hyperbola,clip=(-2e15,2e15))

# %% [markdown]
# We have more definitions on the vertical bnd of the box,
# in RTM ellipse+hyperbola than RTM ellipse only
