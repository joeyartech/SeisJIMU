# %% [markdown]
# ## Preamble

# %%
import os
import numpy as np
#from scipy import signal
import matplotlib.pyplot as plt

# %%
nz=201; nx=201; h=10

fpeak=7
dt=0.002
nt=2000

ntr=100

# %%
def read(filename,n=(nx,nz)):
    return np.fromfile(filename,dtype='float32').reshape(n).T

def read_su(filename,n=(ntr,nt)):
    data=read(filename,n=(n[0],int(60+n[1])))
    return data[60:,:]

# def read_snap(filename,n=(nsnap,nxsnap,nzsnap),i=26):
#     tmp=np.fromfile(filename,dtyPE='float32').reshaPE(n).T
#     return tmp[:,:,i]

def imshow(data,perc=None,clip=None,clipmin=None,extent=None,cmap='viridis',title=None,grid=True):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],extent=extent,cmap=cmap,aspect='auto')
    plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    #plt.xlabel(labels[0]); plt.ylabel(labels[1])
    if title!=None: plt.title(title)

def run(app='../../exe/FWI',setup='setup',np=1,nthreads=8,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OPEnMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"{app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        # !./run.sh
    else:
        # !./run.sh > {out}

# %%
# True
# !makevel nz=100 nx=$nx v000=1000 > c1
# !makevel nz=101 nx=$nx v000=1800 > c2
# !cat c1 c2 > tmp && transp < tmp n1=$nx > true
# !rm c1 c2 tmp

# Background
# !makevel nz=$nz nx=$nx v000=1050 > init

#plot
plt.figure(figsize=(8,3))
true=read('true'); init=read('init')
plt.subplot(1,2,1); imshow(true)
plt.subplot(1,2,2); imshow(init)

# %%
# !cat setup_default
# Out:
# MODEL_SIZE              '201 201 1'
# MODEL_SPACING           '10 10 1'
# FILE_MODEL              true
# MODEL_ATTRIBUTES        vp  #'vp rho'
#
# IS_FREESURFACE          F
#
# ACQUI_GEOMETRY          spread
# FS                      '40 500  0'
# DR                      '0  20   0'
# FR                      '40 0    0'
# NR                      100
#
# SCOMP                   pz
# RCOMP                   'pz px ez ex es'
#
# WAVELET_TYPE            ricker
#
# IF_BLOOM        F
# IF_HICKS        F
#
# IF_USE_RANDOM   F
#
# NT           2000
# DT           0.002
# FPEAK        7
# #RDT			0.006
#
# #SNAPSHOT     'pz px ez ex'
# #NSNAPSHOT    50
#
# ## for FWI ##
# FILE_DATA_PREFIX    'results_obs/Ru_Shot'
#
# WEIGHTING    'aoffset_range:1000:1000'
#
# JOB           gradient
#
#
# IF_USE_CHECKPOINT   F

# %%
#case (11); self%rcv(i)%comp='p'  !pressure

#case (12); self%rcv(i)%comp='vz' !vertical velocity
#case (14); self%rcv(i)%comp='vx' !horizontal velocity in in-line
#case (13); self%rcv(i)%comp='vy' !horizontal velocity in cross-line

#case (21); self%rcv(i)%comp='ez' !ezz
#case (22); self%rcv(i)%comp='ex' !exx
#case (23); self%rcv(i)%comp='ey' !eyy
#case (24); self%rcv(i)%comp='es' !ezx

#case (32); self%rcv(i)%comp='pz' !vertical momenta
#case (34); self%rcv(i)%comp='px' !in-line momenta
#case (33); self%rcv(i)%comp='py' !cross-line momenta

# %%
#!lda = rho(vp^2-2vs^2)
#!mu  = rho*vs^2
#!rho0= rho
#!gvp = glda*2rho*vp
#!gvs = (glda*-2 + gmu)*2rho*vs
#!grho= glda*vp^2 + (-2glda+gmu)*vs^2 + grho0
vp=init
vs=vp/np.sqrt(3)
rho=1000.
def gvp(glda):     return  glda            *2*rho*vp
def gvs(glda,gmu): return (glda*(-2) + gmu)*2*rho*vs

# %% [markdown]
# ## Data

# %%
# !cp setup_default setup
# !echo "DIR_OUT     results_obs" >> setup
run(app='../../exe/fwd_DAS_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_GradientCompar
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 614152 Nov 15 21:39 ../../exe/fwd_DAS_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/15/2023
# System time: 23:20:26
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs
#  Output directory:results_obs/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : pz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   999.999939
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           6
#    minmax rx,ix:   0.00000000       1980.00000               1         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         500
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1000.00000       1800.00000
#  vs   577.350281       1039.23047
#  rho   1000.00000       1000.00000
#  ip   1000000.00       1800000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 577.350281, 14.0000000
#  CFL value: 0.593969703
#  ppg%mu sanity:   333333344.       1.08000000E+09 F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.66051332E-03   3.54282162E-03
#  it----        1000
#  fld_u minmax values:  -2.43215729E-03   2.12444062E-03
#  it----        1500
#  fld_u minmax values:  -3.15657421E-03   2.07803957E-03
#  it----        2000
#  fld_u minmax values:  -5.88715309E-04   5.49600401E-04
#  Elapsed time to add source momenta   4.99010086E-04
#  Elapsed time to update momenta       1.02381933
#  Elapsed time to add source strains     1.75416470E-03
#  Elapsed time to update strains        0.812767267
#  Elapsed time to extract field           1.59146786E-02
#  Elapsed time to save boundary           3.74090672E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/15/2023
# System time: 23:20:31
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo "DIR_OUT     results_syn" >> setup
run(app='../../exe/fwd_DAS_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_GradientCompar
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 614152 Nov 15 21:39 ../../exe/fwd_DAS_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/15/2023
# System time: 23:20:32
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_syn
#  Output directory:results_syn/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : pz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           6
#    minmax rx,ix:   0.00000000       1980.00000               1         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         500
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.83751297E-04
#  Elapsed time to update momenta       1.02055573
#  Elapsed time to add source strains     1.73354149E-03
#  Elapsed time to update strains        0.815365911
#  Elapsed time to extract field           1.50194168E-02
#  Elapsed time to save boundary           3.28457355E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/15/2023
# System time: 23:20:38
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo "DIR_OUT     results_obs_VS" >> setup
# !echo 'SCOMP       vz' >> setup
# !echo "RCOMP       'vz vx'" >> setup
run(app='../../exe/fwd_PSV_FDSG_O4_')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_GradientCompar
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 601680 Nov 15 21:39 ../../exe/fwd_PSV_FDSG_O4_
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/15/2023
# System time: 23:20:39
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs_VS
#  Output directory:results_obs_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) is NOT found, take default: 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 2000
#  TIME_INTERVAL (DT) : 0.002
#  SOURCE_COMPONENT (SCOMP) : vz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 40 500  0
#  RECEIVER_FIRST (FR) : 40 0    0
#  SOURCE_SPACING (DS) is NOT found, take default: 0. 0. 0.
#  RECEIVER_SPACING (DR) : 0  20   0
#  NUMBER_RECEIVER (NR) : 100
#  RECEIVER_COMPONENT (RCOMP) : vz vx
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   999.999939
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               5           6
#    minmax rx,ix:   0.00000000       1980.00000               1         200
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         200
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1000.00000       1800.00000
#  vs   577.350281       1039.23047
#  rho   1000.00000       1000.00000
#  ip   1000000.00       1800000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 577.350281, 14.0000000
#  CFL value: 0.593969703
#  ppg%mu sanity:   333333344.       1.08000000E+09 F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.66051278E-09   3.54282093E-09
#  it----        1000
#  fld_u minmax values:  -2.43215870E-09   2.12444196E-09
#  it----        1500
#  fld_u minmax values:  -3.15657256E-09   2.07804041E-09
#  it----        2000
#  fld_u minmax values:  -5.88715188E-10   5.49600754E-10
#  Elapsed time to add source velocities   4.25577164E-04
#  Elapsed time to update velocities      0.566274166
#  Elapsed time to add source stresses     1.56021118E-03
#  Elapsed time to update stresses        0.680330992
#  Elapsed time to extract field           6.35099411E-03
#  Elapsed time to save boundary           2.86018848E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/15/2023
# System time: 23:20:42
# System timezone: +03:00

# %%
data=read_su('results_obs/Ru_Shot0001.su',n=(5*ntr,nt))

plt.figure(figsize=(16,4))
plt.subplot(1,5,1); imshow(data[:,     :ntr],title='pz-pz',perc=98)
plt.subplot(1,5,2); imshow(data[:,  ntr:2*ntr],title='pz-px',perc=98)
plt.subplot(1,5,3); imshow(data[:,2*ntr:3*ntr],title='pz-ez',perc=98)
plt.subplot(1,5,4); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)
plt.subplot(1,5,5); imshow(data[:,4*ntr:5*ntr],title='pz-es',perc=98)

data=read_su('results_syn/Ru_Shot0001.su',n=(5*ntr,nt))

plt.figure(figsize=(16,4))
plt.subplot(1,5,1); imshow(data[:,     :ntr],title='pz-pz',perc=98)
plt.subplot(1,5,2); imshow(data[:,  ntr:2*ntr],title='pz-px',perc=98)
plt.subplot(1,5,3); imshow(data[:,2*ntr:3*ntr],title='pz-ez',perc=98)
plt.subplot(1,5,4); imshow(data[:,3*ntr:4*ntr],title='pz-ex',perc=98)
plt.subplot(1,5,5); imshow(data[:,4*ntr:5*ntr],title='pz-es',perc=98)

# %% [markdown]
# ## Validate new code

# %%
# !cd ../../; sed -i 's/WaveEq=DAS/WaveEq=PSV/' modules.inc; make fwi; sed -i 's/WaveEq=PSV/WaveEq=DAS/' modules.inc; make fwi
# Out:
# (cd FWI; make)
# make[1]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/FWI'
# #System
# (cd ../Modules/System; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/System'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/System'
# #Etc
# (cd ../Modules/Etc; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Etc'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Etc'
# #Signal
# (cd ../Modules/Signal; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Signal'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Signal'
# #Modeling
# (cd ../Modules/Modeling; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Modeling'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Modeling'
# #Kernel
# (cd ../Modules/Kernel; make App=FWI)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Kernel'
# m_parametrizer_velocities-density.f90 m_querypoint.f90 m_weighter.f90 m_preconditioner.f90 m_fobjective.f90 m_Kernel.f90
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Kernel'
# #Optimization
# (cd ../Modules/Optimization; make App=FWI)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Optimization'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Optimization'
# mpif90 -Ofast -fopenmp -ffree-line-length-none -fbacktrace  -fno-unsafe-math-optimizations -frounding-math -fsignaling-nans -J ../mod/ ../Modules/System/*.o ../Modules/Etc/*.o ../Modules/Signal/*.o ../Modules/Modeling/m_model.o ../Modules/Modeling/m_shotlist_batching.o ../Modules/Modeling/m_shot.o ../Modules/Modeling/m_computebox.o ../Modules/Modeling/m_correlate.o ../Modules/Modeling/m_field.o ../Modules/Modeling/m_cpml.o ../Modules/Modeling/m_propagator_PSV_FDSG_O4.o ../Modules/Modeling/m_Modeling.o ../Modules/Kernel/m_parametrizer_velocities-density.o ../Modules/Kernel/m_querypoint.o ../Modules/Kernel/m_weighter.o ../Modules/Kernel/m_preconditioner.o ../Modules/Kernel/m_fobjective.o ../Modules/Kernel/m_Kernel.o ../Modules/Optimization/m_linesearcher_Wolfe.o ../Modules/Optimization/m_optimizer_common.o ../Modules/Optimization/m_optimizer_NLCG.o ../Modules/Optimization/m_Optimization.o sub_modeling_gradient.o main.o -o ../exe/fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG
# (cd ../exe; ln -sf fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG FWI )
# make[1]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/FWI'
#
# (cd FWI; make)
# make[1]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/FWI'
# #System
# (cd ../Modules/System; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/System'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/System'
# #Etc
# (cd ../Modules/Etc; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Etc'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Etc'
# #Signal
# (cd ../Modules/Signal; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Signal'
#
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Signal'
# #Modeling
# (cd ../Modules/Modeling; make)
# make[2]: Entering directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Modeling'
# mpif90 -cpp -Dgfortran -D"git_commit='65073d2'" -D"git_branch='DAS'" -Ofast -fopenmp -ffree-line-length-none -fbacktrace  -fno-unsafe-math-optimizations -frounding-math -fsignaling-nans -J ../../mod/ -c m_propagator_DAS_FDSG_O4.f90 -o m_propagator_DAS_FDSG_O4.o
# m_propagator_DAS_FDSG_O4.f90:1103:36-44:
#
#  1103 |             call grad2d_glda_gmu(ppg%buoz*rf%pz,ppg%buox*rf%px,&
#       |                                    1       2
# Error: Inconsistent ranks for operator at (1) and (2)
# m_propagator_DAS_FDSG_O4.f90:943:30-37:
#
#   943 |         call fd2d_strains(self%buoz*f%pz,self%buox*f%px,f%ez,f%ex,f%es,    &
#       |                              1      2
# Error: Inconsistent ranks for operator at (1) and (2)
# m_propagator_DAS_FDSG_O4.f90:822:50-55:
#
#   822 |         call fd2d_momenta(f%pz,f%px,f%ez,f%ex,self%mu*f%es,                   &
#       |                                                  1    2
# Error: Inconsistent ranks for operator at (1) and (2)
# make[2]: *** [../../compiler.inc:21: m_propagator_DAS_FDSG_O4.o] Error 1
# make[2]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/Modules/Modeling'
# make[1]: *** [Makefile:44: mod] Error 2
# make[1]: Leaving directory '/home/joey/Codes/GitHub/SeisJIMU/FWI'
# make: *** [Makefile:34: fwi] Error 2

# %%
# !suwind < results_obs_VS/Ru_Shot0001.su key=trid min=12 max=12 > data_0001.su

# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo "FILE_DATA_PREFIX   data_" >> setup
# !echo 'SCOMP       vz' >> setup
# !echo "SNAPSHOT   'vz vx szz sxx szx'" >> setup
# !echo "DIR_OUT     results_VS" >> setup
run(app='../../exe/fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG')

# !suwind < results_obs/Ru_Shot0001.su key=trid min=32 max=32 > data_0001.su

# !cp setup_default setup
# !echo 'FILE_MODEL  init' >> setup
# !echo 'FILE_DATA_PREFIX   data_' >> setup
# !echo "SNAPSHOT   'pz px ez ex es'" >> setup
# !echo "DIR_OUT     results_PE" >> setup
run(app='../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_GradientCompar
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 833944 Nov 15 23:20 ../../exe/fwi_PSV_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/15/2023
# System time: 23:20:47
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_VS
#  Output directory:results_VS/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Velocity-Stress formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: vz, vx
# Required field components: szz, sxx, szx
# Required boundary layer thickness: 2
# Imaging conditions: P-Pxcorr
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: grho glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : data_
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : data_
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : vz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               6           6
#    minmax rx,ix:   0.00000000       1980.00000               1         199
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911032E-09   3.33863892E-09
#  it----        1000
#  fld_u minmax values:  -2.24744423E-09   1.98091255E-09
#  it----        1500
#  fld_u minmax values:  -1.47457713E-09   1.31981059E-09
#  it----        2000
#  fld_u minmax values:  -6.87819246E-10   6.60713262E-10
#  Elapsed time to add source velocities   4.08172607E-04
#  Elapsed time to update velocities      0.561013579
#  Elapsed time to add source stresses     1.40368938E-03
#  Elapsed time to update stresses        0.671725512
#  Elapsed time to extract field           4.80508804E-03
#  Elapsed time to save boundary           2.84945965E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007295E-10   6.61906585E-10
#  it----        1500
#  fld_a minmax values:  -1.43816113E-18   2.61491437E-18
#  fld_u minmax values:  -1.41741918E-09   1.74609993E-09
#  it----        1000
#  fld_a minmax values:  -1.59237281E-17   4.31816073E-17
#  fld_u minmax values:  -2.24152896E-09   1.97815608E-09
#  it----         500
#  fld_a minmax values:  -1.35773583E-17   1.12594377E-17
#  fld_u minmax values:  -3.47582252E-09   3.53789176E-09
#  Elapsed time to load boundary               8.24427605E-03
#  Elapsed time to update stresses            0.686746597
#  Elapsed time to rm source stresses          1.70850754E-03
#  Elapsed time to update velocities          0.583773851
#  Elapsed time to rm source velocities        1.90210342E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource stresses      1.87873840E-03
#  Elapsed time to update adj stresses        0.680827618
#  Elapsed time to add adjsource velocities    4.93597984E-03
#  Elapsed time to update adj velocities      0.569313526
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   2.84433365E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 4.79360316E-19
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    4.79360316E-19  L2sq=    4.79360316E-19
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/15/2023
# System time: 23:20:57
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           8
#  Working directory: (pwd)
# /home/joey/Codes/GitHub/SeisJIMU/Demo/05_GradientCompar
#  Using executable: (ls -l $exe)
# -rwxrwxr-x 1 joey joey 842320 Nov 15 22:18 ../../exe/fwi_DAS_FDSG_O4_velocities-density_Wolfe_NLCG
#  Git Commit: 0dae357
#  Git Branch: DAS
#  Compiler: gfortran v11.4.0
#  Version: 11.4.0
#  Endianness:         1234
#  System date: 11/15/2023
# System time: 23:20:58
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_PE
#  Output directory:results_PE/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D P-SV (ELastic) propagation
# 1st-order Momemtum-Strain formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.606 *Vmax/dx
# Required model attributes: vp, vs, rho
# Required field components: pz,px,
# Required field components: ez,ex,es
# Required boundary layer thickness: 2
# Basic gradients: glda gmu
#  FDGS Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 201 201 1
#  MODEL_SPACING (DZXY) : 10 10 1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp
#  MODEL_ATTRIBUTES_WRITE is NOT found, take default: vp
#  vp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  WARNING: Poisson solid (vs=vp/√3) is assumed by propagator.
#  WARNING: Constant rho model (1000 kg/m³) is allocated by propagator.
#  FILE_DATA_PREFIX : data_
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
# Available empirical law: Gardner, Castagna
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  PARAMETER is NOT found, take default: vp:1500:3400
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : data_
#  ntr, ns, file_size = 100, 2000, 206000
#  Shot0001 will read 100 traces, each trace has 2000 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : pz
#  RECEIVER_COMPONENT (RCOMP) : pz px ez ex es
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 7
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 14.0000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.142857149
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS : F
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1050.00000
#  Reference rho value =   1000.00000
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        2000   2.00000009E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   40.0000000               6
#    sx,ix:   500.000000              51
#    sy,iy:   0.00000000               1
#    ifz,ilz:           0           0
#    ifx,ilx:           0           0
#    ify,ily:           0           0
#  ---------------------------------
#    minmax rz,iz:   40.0000000       40.0000000               6           6
#    minmax rx,ix:   0.00000000       1980.00000               1         199
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:           0           0           0           0
#    minmax ifx,ilx:           0           0           0           0
#    minmax ify,ily:           0           0           0           0
#    nrcv:         100
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =        62001
#    [ifz,ilz],nz:         -23         225         249
#    [ifx,ilx],nx:         -23         225         249
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         201
#    iox,mx:           1         201
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1050.00000       1050.00000
#  vs   606.217773       606.217773
#  rho   1000.00000       1000.00000
#  ip   1050000.00       1050000.00
#  WARNING: Shot0001 can have grid dispersion!
#  5*dz, velmin, fmax = 50.0000000, 606.217773, 14.0000000
#  CFL value: 0.346482307
#  ppg%mu sanity:   367500000.       367500000.     F F
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 3.57142873E-02
#  rdt, irdt = 3.40000018E-02, 17
#  ----  Solving Au=s  ----
#  IF_BLOOM : F
#  it----         500
#  fld_u minmax values:  -3.36911017E-03   3.33863986E-03
#  it----        1000
#  fld_u minmax values:  -2.24744459E-03   1.98091287E-03
#  it----        1500
#  fld_u minmax values:  -1.47457700E-03   1.31981017E-03
#  it----        2000
#  fld_u minmax values:  -6.87818916E-04   6.60713471E-04
#  Elapsed time to add source momenta   4.32252884E-04
#  Elapsed time to update momenta      0.987629890
#  Elapsed time to add source strains     1.55556202E-03
#  Elapsed time to update strains        0.766978145
#  Elapsed time to extract field           5.71346283E-03
#  Elapsed time to save boundary           2.79629230E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=249 perc=99
#  xmovie < snap_sfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM : F
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : aoffset_range:1000:1000
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  Will weight traces by aoffset range:1000:1000
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        2000
#  fld_a minmax values:   0.00000000       0.00000000
#  fld_u minmax values:  -6.84007071E-04   6.61906495E-04
#  it----        1500
#  fld_a minmax values:  -1.43816953E-06   2.61497871E-06
#  fld_u minmax values:  -1.41741871E-03   1.74610049E-03
#  it----        1000
#  fld_a minmax values:  -1.59237134E-05   4.31816952E-05
#  fld_u minmax values:  -2.24152976E-03   1.97815499E-03
#  it----         500
#  fld_a minmax values:  -1.35773462E-05   1.12594334E-05
#  fld_u minmax values:  -3.47582228E-03   3.53789120E-03
#  Elapsed time to load boundary               7.13348389E-03
#  Elapsed time to update strains             0.769803047
#  Elapsed time to rm source strains           2.00128555E-03
#  Elapsed time to update momenta             0.999654293
#  Elapsed time to rm source momenta           1.78289413E-03
#  Elapsed time ----------------------------
#  Elapsed time to add adjsource strains       3.51762772E-03
#  Elapsed time to update adj strains         0.764834404
#  Elapsed time to add adjsource momenta       4.75597382E-03
#  Elapsed time to update adj momenta         0.988632202
#  Elapsed time to extract&write fields        0.00000000
#  Elapsed time to correlate                   2.65240669E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=249 perc=99
#  xmovie < snap_rfield%*  n1=249 n2=249 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=201 perc=99
#  xmovie < snap_*  n1=201 n2=201 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 4.79360608E-07
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    4.79360608E-07  L2sq=    4.79360608E-07
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 11/15/2023
# System time: 23:21:11
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
comp='VS:vz-vz'

glda=read('results_VS/a_star_u%glda')
gmu =read('results_VS/a_star_u%gmu' )

plt.figure(figsize=(16,3))
plt.subplot(1,4,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,4,2); imshow(gmu ,title=comp+':gmu' ,perc=98)
plt.subplot(1,4,3); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,4,4); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)

comp='pz-pz'

glda=read('results_PE/a_star_u%glda')
gmu =read('results_PE/a_star_u%gmu' )

plt.figure(figsize=(16,3))
plt.subplot(1,4,1); imshow(glda,title=comp+':glda',perc=98)
plt.subplot(1,4,2); imshow(gmu ,title=comp+':gmu' ,perc=98)
plt.subplot(1,4,3); imshow(gvp(glda),title=comp+':gvp',perc=98)
plt.subplot(1,4,4); imshow(gvs(glda,gmu),title=comp+':gvs',perc=98)
