# %%
nz=281; nx=1361
h=12.5
sig=0.48/(0.5/h)

fpeak=6.4
dt=0.0015
nt=4600

ntr=600

#How good initial model do you want?
siginit=200

#How many MPI processors do you order?
np=1

#How many OpenMP threads do you order?
nthreads=8

# %%
import os
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

def read(filename,n=None):
    if n==None:
        nn=(nx,nz)
    else:
        nn=n
    return np.fromfile(filename,dtype='float32').reshape(nn).T
    #return np.fromfile(filename,dtype='float32')
tmppath=os.path.expanduser('~')+'/tmp'

def read_su(filename,n=(ntr,nt)):
    # !sustrip < $filename > $tmppath outpar=outpar
    data=read(tmppath,n)
    # !rm $tmppath
    return data

def imshow(data,perc=None,clip=None,clipmin=None,cmap='viridis',title=None,grid=True, label=None, colorbar_title=None):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    im=plt.imshow(data,vmin=clipp[0],vmax=clipp[1],cmap=cmap,aspect='auto',extent=[0,(nx-1)*h/1000 , (nz-1)*h/1000, 0 ])
    #plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    if label!=None:plt.xlabel(label[0]); plt.ylabel(label[1])
    if title!=None: plt.title(title)
    if colorbar_title!=None:
        cbar = plt.colorbar(im);cbar.ax.set_title(colorbar_title)

def imshow_shot(data,perc=None,clip=None,clipmin=None,cmap='viridis',colorbar=None,title=None,grid=True, label=None):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],cmap=cmap,aspect='auto',extent=[0,(nx-1)*h/1000 , (nt-1)*dt, 0 ])
    if colorbar!=None: plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    if label!=None: plt.xlabel(label[0]); plt.ylabel(label[1])
    if title!=None: plt.title(title)

# %% [markdown]
# ## Prepare

# %%
##code
#!(cd ../../ ; git pull ; git checkout teaching ; make prepare)
#!(cd ../../FWD ; make cleanall ; make)
#!(cd ../../FWI ; make cleanall ; make)
#!gfortran smoothgauss2dfast_zhou.f90 -o smoothgauss2dfast_zhou

# %%
#clone model
# !wget https://s3.amazonaws.com/open.source.geoscience/open_data/elastic-marmousi/elastic-marmousi-model.tar.gz #https://wiki.seg.org/wiki/AGL_Elastic_Marmousi
# !tar -xvzf elastic-marmousi-model.tar.gz
# !(cd ./elastic-marmousi-model/model/ ; for fi in `ls *.tar.gz`; do tar -xvzf $$fi; done)
# !segyread tape=./elastic-marmousi-model/model/MODEL_P-WAVE_VELOCITY_1.25m.segy | sugain bias=1000 | sustrip > vp.bin
# !segyread tape=./elastic-marmousi-model/model/MODEL_DENSITY_1.25m.segy | sustrip | farith op=scale scale=1000 > rho.bin  #convert to [kg/m3]
# Out:
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00194957 s, 1.6 MB/s
# n1=2801 n2=13601 d1=0.001250
# nt=2801 ntr=13601 dt=0.001250
# ns=2801
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00193817 s, 1.7 MB/s
# n1=2801 n2=13601 d1=0.001250
# nt=2801 ntr=13601 dt=0.001250
# ns=2801

# %%
# nz=281; nx=1361
# true.shape
# true2 = true[27:,:]
# true2  = np.vstack((true2,np.ones([27,2*nx])*3000))
# true2.shape
# true2.T.flatten().astype('float32').tofile('true2')
# init2 = read('init')[27:,:]
# init2  = np.vstack((init2,np.ones([27,nx])*3000))
# init2.T.flatten().astype('float32').tofile('init2')

# %%
#nz=281-27; nx=1361
#!make code

##smooth & resample the models
# !make sig=$sig smooth resamp topo

##make initial model
# !make siginit=$siginit init

##gathering
# !make model

#!cat vp.bin rho.bin qp.bin > true
#!cat vp.bin rho.bin > true

#plot
fig=plt.figure(figsize=(15,3))

true=read('true',(2*nx,nz))
plt.subplot(1,3,1); imshow(true[:,:nx],cmap='jet',clip=[1028,4700],title='vp',colorbar_title='m/s',label=['offset(km)','depth(km)'])
plt.subplot(1,3,2); imshow(true[:,nx:2*nx],cmap='jet',clip=[1028,2700],title=r'density',colorbar_title='kg/$m^3$',label=['offset(km)','depth(km)'])
#plt.subplot(1,4,3); imshow(true[:,:nx]/10,clip=[1028/10,4700/10],title='Q')
#plt.subplot(1,3,2); imshow(true[:,2*nx:],clip=[1028,4700])
plt.subplot(1,3,3); imshow(read('init'),cmap='jet',clip=[1028,4700],title='initial vp',colorbar_title='m/s',label=['offset(km)','depth(km)'])
fig.subplots_adjust(wspace=0.3)
plt.savefig('models.svg')
# Out:
# echo 12.0
# 12.0
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           39          39
#   go back from the square inverse
#    1.39585667E+11
# echo 12.0
# 12.0
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
# ...

# %%
true[:,:nx].shape
# Out:
# (281, 1361)

# %%
# fig=plt.figure(figsize=(15,3))

# plt.subplot(1,3,1); imshow(true2[:,:nx],clip=[1028,4700],title='vp(m/s)')
# plt.subplot(1,3,2); imshow(true2[:,nx:2*nx],clip=[1028,4700],title=r'density(kg/$m^3$)')
# #plt.subplot(1,4,3); imshow(true[:,:nx]/10,clip=[1028/10,4700/10],title='Q')
# #plt.subplot(1,3,2); imshow(true[:,2*nx:],clip=[1028,4700])
# plt.subplot(1,3,3); imshow(init2,clip=[1028,4700],title='initial vp(m/s)')
# fig.subplots_adjust(wspace=0.3)
# #plt.savefig('models.svg')

# %%
# rho=read_su('./Central_Model/Density_Central_Model.su',n=(5001,2001))
# rho=np.fromfile('./Central_Model/Density_Central_Model.su',dtype='float32')
# rho.shape
# !sustrip < Density_Central_Model_swap.su > rho.bin
rho = np.fromfile('./Central_Model/rho.bin',dtype='float32')
rho = rho.reshape(5001,2001).T
imshow(rho,cmap='jet',title='rho',colorbar_title='m/s',label=['offset(km)','depth(km)'])

# %% [markdown]
# ## Observed data

# %%
# !mkdir results_fwd
# !cp setup.in setup_fwd.in
# !echo "DIR_OUT         './results_fwd' " >> setup_fwd.in
# !echo "FILE_MODEL              'true' " >> setup_fwd.in
# !echo "DS			'  0   400  0'  " >> setup_fwd.in # Shot Spacing
# !echo "FS                      '800  1200  0'" >> setup_fwd.in #First Shot
# !echo "NS              1 " >> setup_fwd.in  #Number of Shots
# !echo "ISHOT              $ishot"  >> setup_fwd.in
# !rm -r ./results_fwd
# !export OMP_NUM_THREADS=10; ulimit -s unlimited; mpirun -np 10 ../../exe/FWD setup_fwd.in > out_fwd

# %%
plt.figure(figsize=(4,4))
imshow_shot(read_su('results_fwd/Ru_Shot0001.su'),perc=98,cmap='gray',label=['offset(m)','time(s)'])

# %%
plt.figure(figsize=(4,4))
imshow_shot(read_su('results_fwd/Ru_Shot0001.su'),perc=98,cmap='gray',label=['offset(m)','time(s)'])

# %%
plt.figure(figsize=(4,4))
imshow_shot(read_su('results_fwd/Ru_Shot0001.su'),perc=98,cmap='gray',label=['offset(m)','time(s)'])
#plt.savefig('observe shots.svg')

# %%
true=read('true',(2*nx,nz))
true[:,:nx].shape
# Out:
# (281, 1361)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1); imshow_shot(read_su('results_fwd/Ru_Shot0001_without_Q.su'),perc=98,cmap='gray',title='record without attanuation',label=['offset(km)','time(s)'])
plt.subplot(1,3,2); imshow_shot(read_su('results_fwd/Ru_Shot0001_with_Q.su'),perc=98,cmap='gray',title='record with attanuation',label=['offset(km)','time(s)'])
plt.subplot(1,3,3); imshow_shot(read_su('results_fwd/Ru_Shot0001_without_Q.su')-read_su('results_fwd/Ru_Shot0001_with_Q.su'),perc=98,cmap='gray',title='residual',label=['offset(km)','time(s)'])
fig.subplots_adjust(wspace=1)
plt.savefig('compare_1shot.svg')

# %%
mask = np.fromfile('mask.bin', dtype=np.float32)  # or np.float64 if Fortran uses double
mask = mask.reshape((-1,329)).T
plt.figure()
plt.imshow(mask,cmap='jet',aspect='auto',vmin=0,vmax=1)
plt.colorbar()

# %%
t_step=4000
m=329
spectrum_p = np.fromfile(f'spectrum_p_{t_step}.bin', dtype=np.complex128)  # or np.float64 if Fortran uses double
spectrum_p = spectrum_p.reshape((-1,m)).T
spectrum_p_filted = np.fromfile(f'spectrum_p_filted_{t_step}.bin', dtype=np.complex128)  # or np.float64 if Fortran uses double
spectrum_p_filted = spectrum_p_filted.reshape((-1,m)).T
fig=plt.figure(figsize=(15,3))
plt.figure(figsize=(16,4))
plt.subplot(1,2,1);
plt.imshow(spectrum_p.real,cmap='jet',aspect='auto',vmin=np.min(spectrum_p.real)/1000,vmax=np.max(spectrum_p.real)/1000)
plt.colorbar()
plt.subplot(1,2,2);
plt.imshow(spectrum_p_filted.real,cmap='jet',aspect='auto',vmin=np.min(spectrum_p.real)/1000,vmax=np.max(spectrum_p.real)/1000)
plt.colorbar()
fig.subplots_adjust(wspace=0.3)

# %%
spectrum_p==spectrum_p_filted
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.figure()
plt.plot(mask[:,1])

# %%
wavelet = np.fromfile('wavelet.bin', dtype=np.float32)  # or np.float64 if Fortran uses double
wavelet_hilbert = np.fromfile('wavelet_hilb.bin', dtype=np.float32)
wavelet.shape
# Out:
# (4600,)

# %%
plt.figure()
plt.plot(wavelet)
plt.plot(wavelet_hilbert)

# %%
snap_vis=read_su('results_fwd/Ru_vis_Shot0001.su')
# snap_no_vis=read_su('results_fwd/Ru_Shot0001.su')
plt.figure()
plt.plot(snap_vis[:,20])
# plt.plot(snap_no_vis[:,20])
# plt.legend(('Vis','No Vis'))

# %% [markdown]
# ## FWI gradient

# %%
#ishot=1
# ishot="'1:10:80'"
#ishot='1:20:144'
ishot="'1:1:30'"

# !cp setup.in setup_grad.in
# !echo "DIR_OUT            './results_grad' " >> setup_grad.in
# !echo "FR                      '200     0  0' " >> setup_grad.in
# !echo "DS			'  0   400  0'  " >> setup_grad.in
# !echo "FILE_MODEL         init2" >> setup_grad.in
# !echo "MODEL_ATTRIBUTES   vp" >> setup_grad.in
# !echo "FILE_DATA_PREFIX   './results_fwd/Ru_Shot'" >> setup_grad.in
# !echo "ISHOT              $ishot"  >> setup_grad.in
# !echo "NBATCH              30"  >> setup_grad.in
# !rm -r ./results_grad
# !export OMP_NUM_THREADS=10; ulimit -s unlimited; mpirun -np 10 ../../exe/FWI setup_grad.in > out_grad
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# ...

# %%
scalar_z = np.tile(np.arange(nz), (nx, 1)).T

plt.figure(figsize=(16,4))
plt.subplot(1,4,1); imshow_shot(read_su('results_fwd/Ru_Shot0001.su'),perc=98,cmap='gray',title='observed data',label=['offset(km)','time(s)'])
plt.subplot(1,4,2); imshow_shot(read_su('results_grad/Ru_Shot0001.su'),perc=98,cmap='gray',title='synthetic data',label=['offset(km)','time(s)'])
plt.subplot(1,4,3); imshow_shot(read_su('results_grad/dadj_Shot0001.su'),perc=98,cmap='gray',title='residual',label=['offset(km)','time(s)'])
plt.subplot(1,4,4); imshow(read('results_grad/qp0%pg')*scalar_z,perc=80,cmap='gray',title='gradient',label=['offset(km)','depth(km)'])
fig.subplots_adjust(wspace=1)
plt.savefig('results_with_Q.svg')

# %%
a=np.fromfile('results_grad/qp0%pg',dtype='float32').reshape(-1,254).T
read('results_grad/qp0%pg').shape
# Out:
# (254, 1361)

# %%
plt.figure(figsize=(4,4))
imshow(read('results_grad/qp0%pg')*scalar_z,perc=80,title='gradient with attenuation',label=['offset(km)','depth(km)'])
plt.savefig('gradient_mul_shots_with_Q.svg')

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1); imshow(read('results_grad/qp0%g'),perc=98)
plt.subplot(1,2,2); imshow(read('results_grad/qp0%pg'),perc=98)

# %%
# For non-visco case
ishot="'1:1:30'"

# !cp setup.in setup_grad.in
# !echo "DIR_OUT            './results_grad' " >> setup_grad.in
# !echo "DS			'  0   400  0'  " >> setup_grad.in
# !echo "FILE_MODEL         init" >> setup_grad.in
# !echo "MODEL_ATTRIBUTES   vp" >> setup_grad.in
# !echo "FILE_DATA_PREFIX   './results_fwd/Ru_Shot'" >> setup_grad.in
# !echo "ISHOT              $ishot"  >> setup_grad.in
# !echo "NBATCH              30"  >> setup_grad.in
# !rm -r ./results_grad
# !export OMP_NUM_THREADS=10; ulimit -s unlimited; mpirun -np 10 ../../exe/FWI setup_grad.in > out_grad
# Out:
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# ...

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1); imshow_shot(read_su('results_fwd/Ru_Shot0001.su'),perc=98,cmap='gray',title='observed data',label=['offset(km)','time(s)'])
plt.subplot(1,4,2); imshow_shot(read_su('results_grad/Ru_Shot0001.su'),perc=98,cmap='gray',title='synthetic data',label=['offset(km)','time(s)'])
plt.subplot(1,4,3); imshow_shot(read_su('results_grad/dadj_Shot0001.su'),perc=98,cmap='gray',title='residual',label=['offset(km)','time(s)'])
plt.subplot(1,4,4); imshow(read('results_grad/qp0%pg')*scalar_z,perc=94,cmap='gray',title='gradient',label=['offset(km)','depth(km)'])
fig.subplots_adjust(wspace=1)
plt.savefig('results_without_Q.svg')

# %%
plt.figure(figsize=(4,4))
imshow(read('results_grad/qp0%pg')*scalar_z*2,perc=94,title='gradient without attenuation',label=['offset(km)','depth(km)'])
plt.savefig('gradient_mul_shots_without_Q.svg')

# %% [markdown]
# ## FWI iterations

# %%
ishot=1
#ishot=1:10:80
#ishot=1:20:144

# !cp setup.in setup_fwi.in
# !echo "DIR_OUT            './results_fwi' " >> setup_fwi.in
# !echo "FILE_MODEL         init" >> setup_fwi.in
# !echo "MODEL_ATTRIBUTES   vp" >> setup_fwi.in
# !echo "ISHOT              $ishot " >> setup_fwi.in
# !echo "FILE_DATA_PREFIX   './results_fwd/Ru_Shot'" >> setup_fwi.in
# !echo "SMOOTHING          Laplacian  " >> setup_fwi.in
# !echo "JOB                optimization " >> setup_fwi.in
# !rm -r ./results_fwi
# !export OMP_NUM_THREADS=1; ulimit -s unlimited; mpirun -np 1 ../../exe/FWI setup_fwi.in > out_fwi
# Out:
# mv: cannot stat './results_fwi/updated_wavelet.su': No such file or directory
# mv: cannot stat './results_fwi/dsyn_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/RE_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/updated_wavelet.su': No such file or directory
# mv: cannot stat './results_fwi/dsyn_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/RE_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/updated_wavelet.su': No such file or directory
# mv: cannot stat './results_fwi/dsyn_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/RE_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/updated_wavelet.su': No such file or directory
# mv: cannot stat './results_fwi/dsyn_Shot0001.su': No such file or directory
# mv: cannot stat './results_fwi/RE_Shot0001.su': No such file or directory
# ...

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1); imshow(read_su('results_fwd/Ru_Shot0001.su'),perc=98)
# plt.subplot(1,3,2); imshow(read_su('results_fwi/dsyn_Shot0001.su'),perc=98)
# plt.subplot(1,3,3); imshow(read_su('results_fwi/dadj_Shot0001.su'),perc=98)
plt.subplot(1,3,2); imshow(read_su('results_fwi/Ru_Iter1_Shot0001.su'),perc=98)
plt.subplot(1,3,3); imshow(read_su('results_fwi/dadj_Iter1_Shot0001.su'),perc=98)

plt.figure(figsize=(12,4))
plt.subplot(1,3,1); imshow(read_su('results_fwd/Ru_Shot0001.su'),perc=98)
# plt.subplot(1,3,2); imshow(read_su('results_fwi/dsyn_Shot0001.su'),perc=98)
# plt.subplot(1,3,3); imshow(read_su('results_fwi/dadj_Shot0001.su'),perc=98)
plt.subplot(1,3,2); imshow(read_su('results_fwi/Ru_Iter60_Shot0001.su'),perc=98)
plt.subplot(1,3,3); imshow(read_su('results_fwi/dadj_Iter60_Shot0001.su'),perc=98)

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('init'),clip=[1028,4700])
# plt.subplot(1,3,2); imshow(read('results_fwi/model_final'),clip=[1028,4700])
plt.subplot(1,3,2); imshow(read('results_fwi/model_Iter31'),clip=[1028,4700])
plt.subplot(1,3,3); imshow(true[:,:nx-1],clip=[1028,4700])

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('results_fwi/model_Iter1'),clip=[1028,4700])
plt.subplot(1,3,2); imshow(read('results_fwi/model_Iter10'),clip=[1028,4700])
plt.subplot(1,3,3); imshow(read('results_fwi/model_Iter60'),clip=[1028,4700])

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('results_fwi/model_Iter1'),clip=[1028,4700])
plt.subplot(1,3,2); imshow(read('results_fwi/model_Iter2'),clip=[1028,4700])
plt.subplot(1,3,3); imshow(read('results_fwi/model_Iter1')-read('results_fwi/model_Iter2'))
