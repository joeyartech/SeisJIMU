# %%
NZ=2396; NX=13601; H=1.25

velmin=1065
velmax=4700

#chosen
fpeak=4

#consequently
h=int(velmin/fpeak/2.5/5)
nz=int(NZ*H/h)+1
nx=int(NX*H/h)+1

print('h,nz,nx=',h,nz,nx)

dt=0.6*h/velmax *0.98
T=5 #time window [s]
nt=int(T/dt)
print('dt,nt=',dt,nt)

dt=0.0026
nt=int(T/dt)
print('adjusted dt,nt=',dt,nt)

ntr=670
# Out:
# h,nz,nx= 21 143 810
# dt,nt= 0.0026272340425531914 1903
# adjusted dt,nt= 0.0026 1923

# %%
import os
import numpy as np
from scipy.signal import hilbert
import matplotlib.pyplot as plt

def read(filename,n=(nx,nz)):
    return np.fromfile(filename,dtype='float32').reshape(n).T

def read_su(filename,n=(ntr,nt)):
    data=read(filename,n=(n[0],int(60+n[1])))
    return data[60:,:]

def write(filename,data,n=(nx,nz)):
    data.T.astype('float32').tofile(filename)

    
def hilb(data,axis=0):
    return np.imag(hilbert(data,axis=axis))

    
def imshow(data,perc=None,clip=None,clipmin=None,extent=None,cmap='viridis',title=None,grid=True):
    
    if perc==None:
        clipp=[np.amin(data),np.amax(data)]
    else:
        tmp=np.percentile(np.abs(data),q=perc)
        clipp=[-tmp,tmp]
    
    if clip!=None: clipp=clip
    
    if clipmin!=None: clipp[0]=clipmin
    
    plt.imshow(data,vmin=clipp[0],vmax=clipp[1],extent=extent,cmap=cmap,aspect='auto')
    plt.colorbar(location='right')
    plt.grid(visible=grid, axis='both', which='both', color='w', linestyle='--',linewidth=0.5)
    #plt.xlabel(labels[0]); plt.ylabel(labels[1])
    if title!=None: plt.title(title)

def run(app='../../exe/FWD',setup='setup',nthreads=4,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OpenMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"{app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        # !./run.sh
    else:
        # !./run.sh > $out
        
def run_remote(app='../../exe/FWD',setup='setup',np=1,nthreads=4,out=None):
    '''
    run(app,setup,np=1,nthreads=8)
    run in a bash env
    ----------------------------
    app      : application/executable to run
    setup    : setup file
    np       : number of MPI processors (default=1)
    nthreads : number of OpenMP threads (default=8)
    
    Caveat: np*nthreads should not exceed total number of CPU cores
    otherwise the running will be very slow
    '''
    
    # !echo 'ulimit -s unlimited' > run.sh
    str=f"export OMP_NUM_THREADS={nthreads}"
    # !echo $str >> run.sh
    str=f"mpirun -np {np} --oversubscribe {app} {setup}"
    # !echo $str >> run.sh
    # !chmod +x run.sh
    if out==None:
        #!./run.sh
        print("bash ./run.sh")
    else:
        #!./run.sh > $out
        print(f"bash ./run.sh > {out}")

# %% [markdown]
# ## Prepare

# %%
##code
#!(cd ../../ ; git pull ; git checkout teaching ; make prepare)
#!(cd ../../FWD ; make cleanall ; make)
#!(cd ../../FWI ; make cleanall ; make)
#!gfortran smoothgauss2dfast_zhou.f90 -o smoothgauss2dfast_zhou

# %%
# #clone model
# # !wget https://s3.amazonaws.com/open.source.geoscience/open_data/elastic-marmousi/elastic-marmousi-model.tar.gz #https://wiki.seg.org/wiki/AGL_Elastic_Marmousi
# # !tar -xvzf elastic-marmousi-model.tar.gz
# # !(cd ./elastic-marmousi-model/model/ ; for fi in `ls *.tar.gz`; do tar -xvzf $$fi; done)
# !segyread tape=./elastic-marmousi-model/model/MODEL_P-WAVE_VELOCITY_1.25m.segy | sugain bias=0 | sustrip > vp.bin
# !segyread tape=./elastic-marmousi-model/model/MODEL_DENSITY_1.25m.segy | sustrip | farith op=scale scale=1000 > rho.bin  #convert to [kg/m3]

# !unif2 ninf=1 nz=281 nx=1361 v00=2000 > vp.bin
# !makevel nx=13601 nz=2801 dx=10 dz=10 v000=4000 > vp.bin
# !makevel nx=13601 nz=2801 dx=10 dz=10 v000=1 > rho.bin

# %%
#chop the water layer
vp = read('vp.bin',(13601,2801)) [405:,:]
rho= read('rho.bin',(13601,2801))[405:,:]

#make Qp model by empirical law
qp = vp**0.5 #leads to a range of ~35--65, small enough to cause instability
qp = vp**0.75 #leads to a range of ~200--550, not yet instability

#plot
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(vp)
plt.subplot(1,3,2); imshow(rho)
plt.subplot(1,3,3); imshow(qp)

# %%
print(vp.shape)
# Out:
# (2396, 13601)

# %%
#save to disk
write('vpt.bin',vp)
write('rhot.bin',rho)
write('qpt.bin',qp)

# %%
#downsample true models
# !make -B true

#make init models
# !make -B init

#catenate
str=f'cat vpt.{h}m   rhot.{h}m   qpt.{h}m  > true'
# !$str
# !cat vpt.init  rhot.init  qpt.init > init
# Out:
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    9.28382976E+10
# unisam2 < vpt.smth > vpt.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    7.28378081E+10
# unisam2 < rhot.smth > rhot.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    1.26036593E+10
# unisam2 < qpt.smth > qpt.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# rm vpt.smth rhot.smth qpt.smth
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    9.28382976E+10
# unisam2 < vpt.smth > vpt.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# echo 200
# 200
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   grids points involved il2 il1 =           39          39
#    329711776.
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    7.28378081E+10
# unisam2 < rhot.smth > rhot.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# echo 200
# 200
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   grids points involved il2 il1 =           39          39
#    258730368.
# echo 20.1680
# 20.1680
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   go to the square inverse
#   grids points involved il2 il1 =           65          65
#   go back from the square inverse
#    1.26036593E+10
# unisam2 < qpt.smth > qpt.21m \
#   nx1=2396  dx1=1.25    nx2=13601  dx2=1.25 \
#   n1=143    d1=21      n2=810   d2=21
# echo 200
# 200
# ./smoothgauss2dfast_zhou < par
#  Input / Output file names (name_in name_out)
#  Grid dimensions (n1 n2)
#  Grid interval (d1 d2)
#  Standard deviation of the Gaussian function (sig1, sig2)
#  Wavenumbers (without factor 2*pi) higher than 0.48/sig will be suppressed
#  c'est à dire que les nombres d'onde qui sont plus large que 0.48/sig ont l'amplitude sous 1% du crête.
#  Smooth parameter (0) or its inverse (1) or its inverse square (2)
#  Constant topography (>=0) or variant (<0)
#   grids points involved il2 il1 =           39          39
#    44768988.0
# rm vpt.smth rhot.smth qpt.smth

# %%
#plot

plt.figure(figsize=(12,3))

true=read('true',(3*nx,nz))
plt.subplot(1,3,1); imshow(true[:,:nx])
plt.subplot(1,3,2); imshow(true[:,nx:2*nx])
plt.subplot(1,3,3); imshow(true[:,2*nx:])

plt.figure(figsize=(12,3))

init=read('init',(3*nx,nz))
plt.subplot(1,3,1); imshow(init[:,:nx])
plt.subplot(1,3,2); imshow(init[:,nx:2*nx])
plt.subplot(1,3,3); imshow(init[:,2*nx:])

# %%
#min max of true vp
print(true[:,:nx].min(),true[:,:nx].max())
# Out:
# 1142.8925 4691.6123

# %%
# !cat setup_default
# Out:
# MODEL_SIZE              '143 810  1'
# MODEL_SPACING           '21  21   1'
# FILE_MODEL              'true'
# MODEL_ATTRIBUTES        'vp rho qp'
# MODEL_ATTRIBUTES_WRITE   vp
# #FILE_TOPO              'topo'
#
# IS_FREESURFACE          F
#
# ACQUI_GEOMETRY          spread
# FS                      '  0   1200  0'
# #DS			'  0   100   0'
# #NS			 144
# DS			'  0   400  0'
# NS			 36
# FR                      '  0   0   0'
# DR                      '  0   25  0'
# NR                       670
#
# SCOMP                   dpdz
# RCOMP                   dpdz #'p vz'
# IF_MUST_USE_RCOMP       T
#
# WAVELET_TYPE	ricker
#
# FPEAK        4
# NT           1923
# DT           0.0026
#
# #SNAPSHOT      p
# #NSNAPSHOT    50
#
# #############
# ## for FWI ##
# #############
# FILE_DATA_PREFIX    './results_obs/Ru_Shot'
# WEIGHTING           'none'
#
# UPDATE_WAVELET	no
#
# PARAMETER           'vp:1065:4700'
#
# SMOOTHING     'none'
# #PRECO         'z^0'
#
# JOB             gradient
#
# MAX_ITERATE     120
# MAX_MODELING    150
#
#
# IF_USE_CHECKPOINT   F

# %% [markdown]
# ## Observed data

# %%
# !cp setup_default setup
# !echo "DIR_OUT            results_obs_noQ " >> setup
# !echo "IS_Q_ATTENUATION   F" >> setup
# !echo "NS                 1 " >> setup  #Number of Shots
run()
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           4
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 wzhou wzhou 21 Sep 25 15:12 ../../exe/FWD -> fwd_VisAC2nd_FDSG_O4_
#  Git Commit: 2810ac8
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:20:56
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs_noQ
#  Output directory:results_obs_noQ/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION : F
#  visac coefs:0.00000000, 0.00000000, 0.00000000, 0.00000000
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) : 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 1923
#  TIME_INTERVAL (DT) : 0.0026
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 0   1200  0
#  RECEIVER_FIRST (FR) : 0   0   0
#  SOURCE_SPACING (DS) : 0   400  0
#  RECEIVER_SPACING (DR) : 0   25  0
#  NUMBER_RECEIVER (NR) : 670
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1665.24377
#  Reference rho value =   2003.46765
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   0.00000000       0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1142.89246       4691.61230
#  rho   1688.35657       2622.54517
#  ip   1929610.00       12275885.0
#  qp   198.101273       566.895752
#  CFL value: 0.958380401
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.37516022       1.57241476
#  fld_imU minmax values:  -1.02254355       1.71586180
#  it----        1000
#  fld_reU minmax values: -0.711203575      0.719304144
#  fld_imU minmax values: -0.616799712      0.743576825
#  it----        1500
#  fld_reU minmax values: -0.390015036      0.372323662
#  fld_imU minmax values: -0.394967556      0.336817831
#  Elapsed time to add source                 5.98239899E-03
#  Elapsed time to save boundary              5.14659882E-02
#  Elapsed time to update field               8.82264900
#  Elapsed time to evolve field               4.51374054E-03
#  Elapsed time to extract field             0.625813484
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:21:05
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo "DIR_OUT          results_obs " >> setup
# !echo "NS               1 " >> setup  #Number of Shots
#!echo "SNAPSHOT         p" >> setup
run()
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           4
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 wzhou wzhou 21 Sep 25 15:12 ../../exe/FWD -> fwd_VisAC2nd_FDSG_O4_
#  Git Commit: 2810ac8
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:21:06
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs
#  Output directory:results_obs/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION is NOT found, take default: T
#  visac coefs:3.78010011, -110.686996, 1111.50000, 1.00000000
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) : 1
#  Will compute 1 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 1923
#  TIME_INTERVAL (DT) : 0.0026
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 0   1200  0
#  RECEIVER_FIRST (FR) : 0   0   0
#  SOURCE_SPACING (DS) : 0   400  0
#  RECEIVER_SPACING (DR) : 0   25  0
#  NUMBER_RECEIVER (NR) : 670
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1665.24377
#  Reference rho value =   2003.46765
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   0.00000000       0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1142.89246       4691.61230
#  rho   1688.35657       2622.54517
#  ip   1929610.00       12275885.0
#  qp   198.101273       566.895752
#  CFL value: 0.958380401
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.27175736       1.45979393
#  fld_imU minmax values: -0.956109643       1.58811224
#  it----        1000
#  fld_reU minmax values: -0.604755878      0.611984670
#  fld_imU minmax values: -0.540429831      0.628002465
#  it----        1500
#  fld_reU minmax values: -0.326686114      0.306114018
#  fld_imU minmax values: -0.337302893      0.267324954
#  Elapsed time to add source                 8.70132446E-03
#  Elapsed time to save boundary              4.68873978E-02
#  Elapsed time to update field               8.60369205
#  Elapsed time to evolve field               1.44195557E-03
#  Elapsed time to extract field             0.611952782
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:21:16
# System timezone: +03:00

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1); imshow(read_su('results_obs_noQ/Ru_Shot0001.su'),perc=98,title='no Q')
plt.subplot(1,3,2); imshow(read_su('results_obs/Ru_Shot0001.su'    ),perc=98,title='with Q')
plt.subplot(1,3,3); imshow(read_su('results_obs_noQ/Ru_Shot0001.su')-read_su('results_obs/Ru_Shot0001.su'),perc=98,title='diff')

# %%
plt.figure(figsize=(10,3))
plt.plot(read_su('results_obs_noQ/Ru_Shot0001.su')[:,75])
plt.plot(read_su('results_obs/Ru_Shot0001.su'    )[:,75])

# %% [markdown]
# ## FWI gradient

# %%
# !cp setup_default setup
# !echo "FILE_MODEL         init" >> setup
# !echo "DIR_OUT            results_grad_noQ " >> setup
# !echo "IS_Q_ATTENUATION   F" >> setup
run(app='../../exe/FWI')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           4
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 wzhou wzhou 51 Sep 25 15:12 ../../exe/FWI -> fwi_VisAC2nd_FDSG_O4_velocities-density_Wolfe_lBFGS
#  Git Commit: 2810ac8
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:21:23
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_grad_noQ
#  Output directory:results_grad_noQ/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION : F
#  visac coefs:0.00000000, 0.00000000, 0.00000000, 0.00000000
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
#  PARAMETER : vp:1065:4700
#  Empirical laws module is invoked.
#  Available empirical law: Gardner, Castagna, VpQp.
#    - If Gardner law is used, rho from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If Castagna law is used, vs from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If VpQp law is used, vs, qp from PARAMETER setup (if loaded) will be neglected and become passive.
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  ntr, ns, file_size = 670, 1923, 1328610
#  Shot0001 will read 670 traces, each trace has 1923 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  IF_MUST_USE_RCOMP : T
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1716.70312
#  Reference rho value =   2018.42371
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:  -0.00000000      -0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1648.80200       4301.59375
#  rho   1987.04187       2486.74146
#  ip   3279186.00       10296275.0
#  qp   258.757263       530.913269
#  CFL value: 0.878709316
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving AU=S  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.01478076       1.29564929
#  fld_imU minmax values: -0.900166154       1.36478853
#  it----        1000
#  fld_reU minmax values: -0.818829894      0.820746660
#  fld_imU minmax values: -0.501522541      0.967999458
#  it----        1500
#  fld_reU minmax values: -0.376535207      0.255275786
#  fld_imU minmax values: -0.275997370      0.363649398
#  Elapsed time to add source                 3.43608856E-03
#  Elapsed time to save boundary              4.04095650E-02
#  Elapsed time to update field               3.97118664
#  Elapsed time to evolve field               2.87103653E-03
#  Elapsed time to extract field             0.597002983
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : none
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        1500
#  fld_reA minmax values: -0.186505899      0.175068751
#  fld_imA minmax values: -0.147328630      0.191739932
#  fld_reU minmax values: -0.329768777      0.229556412
#  fld_imU minmax values: -0.269643396      0.306576341
#  it----        1000
#  fld_reA minmax values: -0.524090052      0.513620675
#  fld_imA minmax values: -0.425644755      0.569218457
#  fld_reU minmax values: -0.818451047      0.819962323
#  fld_imU minmax values: -0.500520587      0.962804675
#  it----         500
#  fld_reA minmax values: -0.693073869       1.07354045
#  fld_imA minmax values: -0.925999403      0.940393031
#  fld_reU minmax values:  -1.01335645       1.29086947
#  fld_imU minmax values: -0.898300886       1.36526680
#  Elapsed time to evolve field           3.40652466E-03
#  Elapsed time to load boundary          9.51967239E-02
#  Elapsed time to update field           3.87309361
#  Elapsed time to rm source              9.26113129E-03
#  Elapsed time -----------------------
#  Elapsed time to add adj & virtual src      0.818781853
#  Elapsed time to update adj field            4.51134205
#  Elapsed time to evolve adj field            1.44290924E-03
#  Elapsed time to extract fields              0.00000000
#  Elapsed time to correlate                   8.32843781E-03
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=191 perc=99
#  xmovie < snap_rfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=143 perc=99
#  xmovie < snap_*  n1=143 n2=810 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 8.14070867E-04
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    8.14070867E-04  L2sq=    8.14070867E-04
#  SMOOTHING (SMTH) : none
#  GRADIENT_SOFT_MASK (MASK) is NOT found, take 0, '' or F
#  Parametrizer finds gbuo & gikpa
#  PRECONDITIONING (PRECO) is NOT found, take default: z^1
#  Will precondition the gradient by z^1
#  Linesearch based on a bracketing - dichotomy algoritm
# Steplength (alpha) judged by Wolfe conditions
#  Wolfe condition parameters: c1=9.99999975E-05, c2=0.899999976
#  MAX_SEARCH is NOT found, take default: 12
#  WOLFE_C2 is NOT found, take default: 0.9
#  LINESEARCHER_SCALING (LS_SCALING) is NOT found, take default: by total_volume/||pg(1)||1
#  Linesearch scaler= 452.201782
#  qp0%f, ║g║₁ = 0.368124306, 31.8710213
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:21:39
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
# !cp setup_default setup
# !echo "FILE_MODEL         init" >> setup
# !echo "DIR_OUT          results_grad " >> setup
run(app='../../exe/FWI')
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:           1
#   Max number of OMP threads / processor:           4
#  Working directory: (pwd)
# /home/wzhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 wzhou wzhou 51 Sep 25 15:12 ../../exe/FWI -> fwi_VisAC2nd_FDSG_O4_velocities-density_Wolfe_lBFGS
#  Git Commit: 2810ac8
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:21:40
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_grad
#  Output directory:results_grad/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION is NOT found, take default: T
#  visac coefs:3.78010011, -110.686996, 1111.50000, 1.00000000
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 1 sequential shots.
#  Number of processors = 1
# Number of shots = 1
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 1
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
#  PARAMETER : vp:1065:4700
#  Empirical laws module is invoked.
#  Available empirical law: Gardner, Castagna, VpQp.
#    - If Gardner law is used, rho from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If Castagna law is used, vs from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If VpQp law is used, vs, qp from PARAMETER setup (if loaded) will be neglected and become passive.
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  ntr, ns, file_size = 670, 1923, 1328610
#  Shot0001 will read 670 traces, each trace has 1923 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  IF_MUST_USE_RCOMP : T
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1716.70312
#  Reference rho value =   2018.42371
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:  -0.00000000      -0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1648.80200       4301.59375
#  rho   1987.04187       2486.74146
#  ip   3279186.00       10296275.0
#  qp   258.757263       530.913269
#  CFL value: 0.878709316
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving AU=S  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values: -0.940717041       1.20794284
#  fld_imU minmax values: -0.842525542       1.27017605
#  it----        1000
#  fld_reU minmax values: -0.696078598      0.711581647
#  fld_imU minmax values: -0.443106055      0.828201592
#  it----        1500
#  fld_reU minmax values: -0.293518871      0.200187817
#  fld_imU minmax values: -0.218352780      0.284507185
#  Elapsed time to add source                 4.31156158E-03
#  Elapsed time to save boundary              4.68220711E-02
#  Elapsed time to update field               3.92612553
#  Elapsed time to evolve field               2.85530090E-03
#  Elapsed time to extract field             0.572096825
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : none
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        1500
#  fld_reA minmax values: -0.145851091      0.146891281
#  fld_imA minmax values: -0.139626786      0.152809188
#  fld_reU minmax values: -0.272787243      0.194095373
#  fld_imU minmax values: -0.217111871      0.257533967
#  it----        1000
#  fld_reA minmax values: -0.480061650      0.465985447
#  fld_imA minmax values: -0.393680930      0.512226045
#  fld_reU minmax values: -0.688188732      0.703760266
#  fld_imU minmax values: -0.437480241      0.819521546
#  it----         500
#  fld_reA minmax values: -0.591418266      0.890178084
#  fld_imA minmax values: -0.752519846      0.785252452
#  fld_reU minmax values: -0.936428726       1.20511186
#  fld_imU minmax values: -0.840017498       1.27030993
#  Elapsed time to evolve field           2.35462189E-03
#  Elapsed time to load boundary          9.78155136E-02
#  Elapsed time to update field           3.88054943
#  Elapsed time to rm source              6.39247894E-03
#  Elapsed time -----------------------
#  Elapsed time to add adj & virtual src      0.793643951
#  Elapsed time to update adj field            4.44385052
#  Elapsed time to evolve adj field            5.16796112E-03
#  Elapsed time to extract fields              0.00000000
#  Elapsed time to correlate                   1.12628937E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=191 perc=99
#  xmovie < snap_rfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=143 perc=99
#  xmovie < snap_*  n1=143 n2=810 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 7.27683306E-04
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    7.27683306E-04  L2sq=    7.27683306E-04
#  SMOOTHING (SMTH) : none
#  GRADIENT_SOFT_MASK (MASK) is NOT found, take 0, '' or F
#  Parametrizer finds gbuo & gikpa
#  PRECONDITIONING (PRECO) is NOT found, take default: z^1
#  Will precondition the gradient by z^1
#  Linesearch based on a bracketing - dichotomy algoritm
# Steplength (alpha) judged by Wolfe conditions
#  Wolfe condition parameters: c1=9.99999975E-05, c2=0.899999976
#  MAX_SEARCH is NOT found, take default: 12
#  WOLFE_C2 is NOT found, take default: 0.9
#  LINESEARCHER_SCALING (LS_SCALING) is NOT found, take default: by total_volume/||pg(1)||1
#  Linesearch scaler= 569.067017
#  qp0%f, ║g║₁ = 0.414100558, 31.8648911
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:21:56
# System timezone: +03:00
#
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1); imshow(read_su('results_obs/Ru_Shot0001.su' ),perc=98)
plt.subplot(1,3,2); imshow(read_su('results_grad/Ru_Shot0001.su'),perc=98)
plt.subplot(1,3,3); imshow(read_su('results_grad/dadj_Shot0001.su'),perc=98)

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('results_grad_noQ/qp0%pg'),perc=98,title='no Q')
plt.subplot(1,3,2); imshow(read('results_grad/qp0%pg'    ),perc=98,title='with Q')
plt.subplot(1,3,3); imshow(read('results_grad_noQ/qp0%pg')-read('results_grad/qp0%pg'),perc=98,title='diff')

# %%
plt.figure(figsize=(8,2))
plt.plot(read('results_grad_noQ/qp0%pg')[100,:500],label='no Q')
plt.plot(read('results_grad/qp0%pg'    )[100,:500],label='with Q')

# %% [markdown]
# ## Multiple shots

# %% [markdown]
# ### data

# %%
# !cp setup_default setup
# !echo "DIR_OUT            results_obs_noQ " >> setup
# !echo "IS_Q_ATTENUATION   F" >> setup
run_remote(np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
# !cat out
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:          36
#   Max number of OMP threads / processor:           1
#  Working directory: (pwd)
# /home/weizhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 weizhou weizhou 21 Sep 25 15:28 ../../exe/FWD -> fwd_VisAC2nd_FDSG_O4_
#  Git Commit: 68ce864
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:31:12
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs_noQ
#  Output directory:results_obs_noQ/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION : F
#  visac coefs:0.00000000, 0.00000000, 0.00000000, 0.00000000
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) : 36
#  Will compute 36 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 36
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 1923
#  TIME_INTERVAL (DT) : 0.0026
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 0   1200  0
#  RECEIVER_FIRST (FR) : 0   0   0
#  SOURCE_SPACING (DS) : 0   400  0
#  RECEIVER_SPACING (DR) : 0   25  0
#  NUMBER_RECEIVER (NR) : 670
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1665.24377
#  Reference rho value =   2003.46765
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   0.00000000       0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1142.89246       4691.61230
#  rho   1688.35657       2622.54517
#  ip   1929610.00       12275885.0
#  qp   198.101273       566.895752
#  CFL value: 0.958380401
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.37516022       1.57241476
#  fld_imU minmax values:  -1.02254355       1.71586180
#  it----        1000
#  fld_reU minmax values: -0.711203575      0.719304144
#  fld_imU minmax values: -0.616799712      0.743576825
#  it----        1500
#  fld_reU minmax values: -0.390015036      0.372323662
#  fld_imU minmax values: -0.394967556      0.336817831
#  Elapsed time to add source                 2.70118713E-02
#  Elapsed time to save boundary             0.572929382
#  Elapsed time to update field               40.3282700
#  Elapsed time to evolve field               6.71768188E-03
#  Elapsed time to extract field              2.26825333
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:31:56
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo "DIR_OUT          results_obs " >> setup
run_remote(np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
# !cat out
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:          36
#   Max number of OMP threads / processor:           1
#  Working directory: (pwd)
# /home/weizhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 weizhou weizhou 21 Sep 25 15:28 ../../exe/FWD -> fwd_VisAC2nd_FDSG_O4_
#  Git Commit: 68ce864
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:41:20
# System timezone: +03:00
#
#  ======================================
#    WELCOME TO SeisJIMU FWD MODELING
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_obs
#  Output directory:results_obs/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : true
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION is NOT found, take default: T
#  visac coefs:3.78010011, -110.686996, 1111.50000, 1.00000000
#  ACQUI_GEOMETRY : spread
#  NUMBER_SOURCE (NS) : 36
#  Will compute 36 synthetic shots.
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 36
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  ===== START LOOP OVER SHOTS =====
#  TIME_STEP (NT) : 1923
#  TIME_INTERVAL (DT) : 0.0026
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  ACQUI_GEOMETRY : spread
#  SOURCE_FIRST (FS) : 0   1200  0
#  RECEIVER_FIRST (FR) : 0   0   0
#  SOURCE_SPACING (DS) : 0   400  0
#  RECEIVER_SPACING (DR) : 0   25  0
#  NUMBER_RECEIVER (NR) : 670
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1665.24377
#  Reference rho value =   2003.46765
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:   0.00000000       0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1142.89246       4691.61230
#  rho   1688.35657       2622.54517
#  ip   1929610.00       12275885.0
#  qp   198.101273       566.895752
#  CFL value: 0.958380401
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving Au=s  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.27175736       1.45979393
#  fld_imU minmax values: -0.956109643       1.58811224
#  it----        1000
#  fld_reU minmax values: -0.604755878      0.611984670
#  fld_imU minmax values: -0.540429831      0.628002465
#  it----        1500
#  fld_reU minmax values: -0.326686114      0.306114018
#  fld_imU minmax values: -0.337302893      0.267324954
#  Elapsed time to add source                 2.67028809E-02
#  Elapsed time to save boundary             0.580471039
#  Elapsed time to update field               39.8115349
#  Elapsed time to evolve field               5.61523438E-03
#  Elapsed time to extract field              2.35900879
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#          END LOOP OVER SHOTS
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:42:03
# System timezone: +03:00

# %% [markdown]
# ### gradient

# %%
# !cp setup_default setup
# !echo "FILE_MODEL         init" >> setup
# !echo "DIR_OUT            results_grad_noQ " >> setup
# !echo "IS_Q_ATTENUATION   F" >> setup
run_remote(app='../../exe/FWI',np=36,nthreads=1,out='out')
#~3min for one gradient
# Out:
# bash ./run.sh > out

# %%
# !cat out
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:          36
#   Max number of OMP threads / processor:           1
#  Working directory: (pwd)
# /home/weizhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 weizhou weizhou 51 Sep 25 15:28 ../../exe/FWI -> fwi_VisAC2nd_FDSG_O4_velocities-density_Wolfe_lBFGS
#  Git Commit: 68ce864
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:42:52
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_grad_noQ
#  Output directory:results_grad_noQ/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION : F
#  visac coefs:0.00000000, 0.00000000, 0.00000000, 0.00000000
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 36 sequential shots.
#  Number of processors = 36
# Number of shots = 36
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 36
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) is NOT found, take 0, '' or F
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
#  PARAMETER : vp:1065:4700
#  Empirical laws module is invoked.
#  Available empirical law: Gardner, Castagna, VpQp.
#    - If Gardner law is used, rho from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If Castagna law is used, vs from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If VpQp law is used, vs, qp from PARAMETER setup (if loaded) will be neglected and become passive.
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  ntr, ns, file_size = 670, 1923, 1328610
#  Shot0036 will read 670 traces, each trace has 1923 samples.
#  Shot0014 will read 670 traces, each trace has 1923 samples.
#  Shot0024 will read 670 traces, each trace has 1923 samples.
#  Shot0025 will read 670 traces, each trace has 1923 samples.
#  Shot0026 will read 670 traces, each trace has 1923 samples.
#  Shot0029 will read 670 traces, each trace has 1923 samples.
#  Shot0030 will read 670 traces, each trace has 1923 samples.
#  Shot0031 will read 670 traces, each trace has 1923 samples.
#  Shot0033 will read 670 traces, each trace has 1923 samples.
#  Shot0034 will read 670 traces, each trace has 1923 samples.
#  Shot0035 will read 670 traces, each trace has 1923 samples.
#  Shot0002 will read 670 traces, each trace has 1923 samples.
#  Shot0006 will read 670 traces, each trace has 1923 samples.
#  Shot0007 will read 670 traces, each trace has 1923 samples.
#  Shot0010 will read 670 traces, each trace has 1923 samples.
#  Shot0011 will read 670 traces, each trace has 1923 samples.
#  Shot0012 will read 670 traces, each trace has 1923 samples.
#  Shot0015 will read 670 traces, each trace has 1923 samples.
#  Shot0016 will read 670 traces, each trace has 1923 samples.
#  Shot0017 will read 670 traces, each trace has 1923 samples.
#  Shot0018 will read 670 traces, each trace has 1923 samples.
#  Shot0019 will read 670 traces, each trace has 1923 samples.
#  Shot0020 will read 670 traces, each trace has 1923 samples.
#  Shot0021 will read 670 traces, each trace has 1923 samples.
#  Shot0023 will read 670 traces, each trace has 1923 samples.
#  Shot0028 will read 670 traces, each trace has 1923 samples.
#  Shot0027 will read 670 traces, each trace has 1923 samples.
#  Shot0004 will read 670 traces, each trace has 1923 samples.
#  Shot0013 will read 670 traces, each trace has 1923 samples.
#  Shot0009 will read 670 traces, each trace has 1923 samples.
#  Shot0003 will read 670 traces, each trace has 1923 samples.
#  Shot0008 will read 670 traces, each trace has 1923 samples.
#  Shot0022 will read 670 traces, each trace has 1923 samples.
#  Shot0032 will read 670 traces, each trace has 1923 samples.
#  Shot0001 will read 670 traces, each trace has 1923 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  IF_MUST_USE_RCOMP : T
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1716.70312
#  Reference rho value =   2018.42371
#  Shot0005 will read 670 traces, each trace has 1923 samples.
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:  -0.00000000      -0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1648.80200       4301.59375
#  rho   1987.04187       2486.74146
#  ip   3279186.00       10296275.0
#  qp   258.757263       530.913269
#  CFL value: 0.878709316
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving AU=S  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values:  -1.01478076       1.29564929
#  fld_imU minmax values: -0.900166154       1.36478853
#  it----        1000
#  fld_reU minmax values: -0.818829894      0.820746660
#  fld_imU minmax values: -0.501522541      0.967999458
#  it----        1500
#  fld_reU minmax values: -0.376535207      0.255275786
#  fld_imU minmax values: -0.275997370      0.363649398
#  Elapsed time to add source                 2.97431946E-02
#  Elapsed time to save boundary             0.667728424
#  Elapsed time to update field               42.4362030
#  Elapsed time to evolve field               6.50405884E-03
#  Elapsed time to extract field              2.61423874
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : none
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        1500
#  fld_reA minmax values: -0.186505899      0.175068751
#  fld_imA minmax values: -0.147328630      0.191739932
#  fld_reU minmax values: -0.329768777      0.229556412
#  fld_imU minmax values: -0.269643396      0.306576341
#  it----        1000
#  fld_reA minmax values: -0.524090052      0.513620675
#  fld_imA minmax values: -0.425644755      0.569218457
#  fld_reU minmax values: -0.818451047      0.819962323
#  fld_imU minmax values: -0.500520587      0.962804675
#  it----         500
#  fld_reA minmax values: -0.693073869       1.07354045
#  fld_imA minmax values: -0.925999403      0.940393031
#  fld_reU minmax values:  -1.01335645       1.29086947
#  fld_imU minmax values: -0.898300886       1.36526680
#  Elapsed time to evolve field           3.86047363E-03
#  Elapsed time to load boundary         0.543121338
#  Elapsed time to update field           42.0780640
#  Elapsed time to rm source              4.53643799E-02
#  Elapsed time -----------------------
#  Elapsed time to add adj & virtual src       3.75265503
#  Elapsed time to update adj field            48.0292816
#  Elapsed time to evolve adj field            7.04956055E-03
#  Elapsed time to extract fields              0.00000000
#  Elapsed time to correlate                   8.76007080E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=191 perc=99
#  xmovie < snap_rfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=143 perc=99
#  xmovie < snap_*  n1=143 n2=810 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 8.14070867E-04
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    8.14070867E-04  L2sq=    8.14070867E-04
#  SMOOTHING (SMTH) : none
#  GRADIENT_SOFT_MASK (MASK) is NOT found, take 0, '' or F
#  Parametrizer finds gbuo & gikpa
#  PRECONDITIONING (PRECO) is NOT found, take default: z^1
#  Will precondition the gradient by z^1
#  Linesearch based on a bracketing - dichotomy algoritm
# Steplength (alpha) judged by Wolfe conditions
#  Wolfe condition parameters: c1=9.99999975E-05, c2=0.899999976
#  MAX_SEARCH is NOT found, take default: 12
#  WOLFE_C2 is NOT found, take default: 0.9
#  LINESEARCHER_SCALING (LS_SCALING) is NOT found, take default: by total_volume/||pg(1)||1
#  Linesearch scaler= 17.3772926
#  qp0%f, ║g║₁ = 1.41463475E-02, 31.8647499
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:45:23
# System timezone: +03:00

# %%
# !cp setup_default setup
# !echo "FILE_MODEL         init" >> setup
# !echo "DIR_OUT          results_grad " >> setup
# !echo "SMOOTHING        Laplacian "  >> setup
# !echo "LAP_FRAC       '0.5 0.5 0.5' "  >> setup
# !echo "PRECO            z^1.5       "  >> setup
run_remote(app='../../exe/FWI',np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
# !cat out
# Out:
#  MPIWorld info:
#   MPI_INIT_THREAD level:           0
#   Number of MPI processors:          36
#   Max number of OMP threads / processor:           1
#  Working directory: (pwd)
# /home/weizhou/Codes/GitHub/SeisJIMU/Demo/11_Marmousi-runFWI-4Hz
#  Using executable: (ls -l $exe)
# lrwxrwxrwx 1 weizhou weizhou 51 Sep 25 15:28 ../../exe/FWI -> fwi_VisAC2nd_FDSG_O4_velocities-density_Wolfe_lBFGS
#  Git Commit: 68ce864
#  Git Branch: VisAC_ZFL_WZ
#  Compiler: gfortran v13.3.0
#  Version: 13.3.0
#  Endianness:         1234
#  System date: 09/25/2025
# System time: 15:52:59
# System timezone: +03:00
#
#  ======================================
#        WELCOME TO SeisJIMU FWI
# ======================================
#  Setup file: setup
#  DIR_IN is NOT found, take default: ./
#  Input directory: ./
#  DIR_OUT : results_grad
#  Output directory:results_grad/
#  Invoked field & propagator modules info :
# Time-domain ISOtropic 2D/3D VIScoACoustic propagation
# 2nd-order Pressure formulation
# Vireux-Levandar Staggered-Grid Finite-Difference (FDSG) method
# Cartesian O(x⁴,t²) stencil
# CFL = Σ|coef| *Vmax *dt /rev_cell_diagonal
#    -> dt ≤ 0.5*Vmax/dx
# Required model attributes: vp, rho, qp
# Required field components: p, p_prev, p_next
# Required boundary layer thickness: 2
# Energy terms: Σ_shot ∫ sfield%p² dt
# Basic gradients: gbuo(wait), gikpa, gqp
#  FDSG Coef : 1.12500000, -4.16666679E-02
#  IF_CHECKPOINT is NOT found, take default: F
#  IF_USE_CHECKPOINT : F
#  DIR_CHECKPOINT (DIR_CHP) is NOT found, take default: ./checkpoints/
#  MODEL_SIZE (NZXY) : 143 810  1
#  MODEL_SPACING (DZXY) : 21  21   1
#  2D geometry
#  MODEL_ORIGIN (OZXY) is NOT found, take default: 0. 0. 0.
#  FILE_MODEL : init
#  MODEL_ATTRIBUTES : vp rho qp
#  MODEL_ATTRIBUTES_WRITE : vp
#  vp model is read.
#  rho model is read.
#  qp model is read.
#  IS_FREESURFACE : F
#  FILE_BATHYMETRY (FILE_BATHY) is NOT found, take 0, '' or F
#  FILE_TOPOGRAPHY (FILE_TOPO) is NOT found, take 0, '' or F
#  FILE_FREEZE_ZONE is NOT found, take 0, '' or F
#  IS_Q_ATTENUATION is NOT found, take default: T
#  visac coefs:3.78010011, -110.686996, 1111.50000, 1.00000000
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  SHOT_INDEX (ISHOT) is NOT found, take 0, '' or F
#  SHOT_INDEX is not given. Now count how many data files exist in the directory..
#  Found 36 sequential shots.
#  Number of processors = 36
# Number of shots = 36
#  FILE_SHOT_BATCH is NOT found, take 0, '' or F
#  SHOT_BATCH_SIZE (NBATCH) is NOT found, take default: 36
#  SHOT_SAMPLE_METHOD is NOT found, take default: cyclic
#  Proc0001 has 1 assigned shots
#  See file "shotlist.log" for details.
#  PRECONDITIONING (PRECO) : z^1.5
#  Invoked parametrizer module info :
# Parameterization: velocities-density
# Allowed pars: vp, vs, rho
#  PARAMETER : vp:1065:4700
#  Empirical laws module is invoked.
#  Available empirical law: Gardner, Castagna, VpQp.
#    - If Gardner law is used, rho from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If Castagna law is used, vs from PARAMETER setup (if loaded) will be neglected and become passive.
#    - If VpQp law is used, vs, qp from PARAMETER setup (if loaded) will be neglected and become passive.
#  EMPIRICAL_LAW is NOT found, take 0, '' or F
#  DATA_NORMS (DNORMS) is NOT found, take default: L1 L2sq
#  DATA_NORM_WEIGHTS (DWEIGHTS) is NOT found, take default: 0. 1.
#  DATA_NORM_NORMALIZERS is NOT found in setup
#  PARAMETER_NORMS (XNORMS) is NOT found, take default: none
#  PARAMETER_NORM_WEIGHTS (XWEIGHTS) is NOT found, take default: 0.
#  FILE_PRIOR_MODEL is NOT found, take 0, '' or F
#  Shot0023 will read 670 traces, each trace has 1923 samples.
#  Shot0033 will read 670 traces, each trace has 1923 samples.
#  ===== START LOOP OVER SHOTS =====
#  FILE_DATA_PREFIX : ./results_obs/Ru_Shot
#  ntr, ns, file_size = 670, 1923, 1328610
#  Shot0035 will read 670 traces, each trace has 1923 samples.
#  Shot0002 will read 670 traces, each trace has 1923 samples.
#  Shot0024 will read 670 traces, each trace has 1923 samples.
#  Shot0012 will read 670 traces, each trace has 1923 samples.
#  Shot0034 will read 670 traces, each trace has 1923 samples.
#  Shot0022 will read 670 traces, each trace has 1923 samples.
#  Shot0006 will read 670 traces, each trace has 1923 samples.
#  Shot0013 will read 670 traces, each trace has 1923 samples.
#  Shot0017 will read 670 traces, each trace has 1923 samples.
#  Shot0016 will read 670 traces, each trace has 1923 samples.
#  Shot0027 will read 670 traces, each trace has 1923 samples.
#  Shot0019 will read 670 traces, each trace has 1923 samples.
#  Shot0028 will read 670 traces, each trace has 1923 samples.
#  Shot0026 will read 670 traces, each trace has 1923 samples.
#  Shot0003 will read 670 traces, each trace has 1923 samples.
#  Shot0032 will read 670 traces, each trace has 1923 samples.
#  Shot0005 will read 670 traces, each trace has 1923 samples.
#  Shot0021 will read 670 traces, each trace has 1923 samples.
#  Shot0008 will read 670 traces, each trace has 1923 samples.
#  Shot0004 will read 670 traces, each trace has 1923 samples.
#  Shot0007 will read 670 traces, each trace has 1923 samples.
#  Shot0010 will read 670 traces, each trace has 1923 samples.
#  Shot0018 will read 670 traces, each trace has 1923 samples.
#  Shot0014 will read 670 traces, each trace has 1923 samples.
#  Shot0031 will read 670 traces, each trace has 1923 samples.
#  Shot0029 will read 670 traces, each trace has 1923 samples.
#  Shot0025 will read 670 traces, each trace has 1923 samples.
#  Shot0009 will read 670 traces, each trace has 1923 samples.
#  Shot0030 will read 670 traces, each trace has 1923 samples.
#  Shot0036 will read 670 traces, each trace has 1923 samples.
#  Shot0001 will read 670 traces, each trace has 1923 samples.
#  Shot0020 will read 670 traces, each trace has 1923 samples.
#  SU data read success.
#  SOURCE_COMPONENT (SCOMP) : dpdz
#  RECEIVER_COMPONENT (RCOMP) : dpdz
#  IF_MUST_USE_RCOMP : T
#  FILTER_DATA (BFILT) is NOT found, take default: none
#  PEAK_FREQUENCY (FPEAK) : 4
#  MAX_FREQUENCY (FMAX) is NOT found, take default: 8.00000000
#  Shot0011 will read 670 traces, each trace has 1923 samples.
#  Shot0015 will read 670 traces, each trace has 1923 samples.
#  FILE_SRC_TIME_FUNC (FILE_WAVELET) is NOT found, take 0, '' or F
#  WAVELET_TYPE : ricker
#  Use Ricker wavelet
#  RICKER_DELAYTIME (T0) is NOT found, take default: 0.250000000
#  FILE_WAVELET_PREFIX is NOT found, take 0, '' or F
#  WAVELET_SCALING is NOT found, take 0, '' or F
#  SU data write success.
#  IF_HICKS is NOT found, take default: T
#  MODEL_REFERENCE is NOT found in setup
#  Reference vp value =   1716.70312
#  Reference rho value =   2018.42371
#  =================================
#  Shot0001 info:
#  =================================
#    nt,dt:        1923   2.60000001E-03
#  ---------------------------------
#  S/R positions after removing m%oz,ox,iy,
#    sz,iz:   0.00000000               1
#    sx,ix:   1200.00000              58
#    sy,iy:   0.00000000               1
#    ifz,ilz:          -3           5
#    ifx,ilx:          54          62
#    ify,ily:           1           1
#  ---------------------------------
#    minmax rz,iz:  -0.00000000      -0.00000000               1           1
#    minmax rx,ix:   0.00000000       16725.0000               1         797
#    minmax ry,iy:   0.00000000       0.00000000               1           1
#    minmax ifz,ilz:          -3          -3           5           5
#    minmax ifx,ilx:          -3         793           5         801
#    minmax ify,ily:           1           1           1           1
#    nrcv:         670
#  ---------------------------------
#  Modeling Shot# Shot0001
#  ADD_APERTURE is NOT found, take default: -99999 99999 -99999 99999
#  REF_BNDLAYER_THICKNESS (NCPML) is NOT found, take default: 20
#  Computebox Size = [ifz,ilz] x [ifx,ilx] x [ify,ily] =       163878
#    [ifz,ilz],nz:         -23         167         191
#    [ifx,ilx],nx:         -23         834         858
#    [ify,ilx],ny:           1           1           1
#  Inner area of Computebox:
#    ioz,mz:           1         143
#    iox,mx:           1         810
#    ioy,my:           1           1
#  Computebox value ranges:
#  vp   1648.80200       4301.59375
#  rho   1987.04187       2486.74146
#  ip   3279186.00       10296275.0
#  qp   258.757263       530.913269
#  CFL value: 0.878709316
#  SNAPSHOT is NOT found, take 0, '' or F
#  SNAPSHOT is NOT found, take 0, '' or F
#  REF_RECT_TIME_INTEVAL (RDT) is NOT found, take default: 6.25000000E-02
#  rdt, irdt = 6.23999983E-02, 24
#  ----  Solving AU=S  ----
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  it----         500
#  fld_reU minmax values: -0.940717041       1.20794284
#  fld_imU minmax values: -0.842525542       1.27017605
#  it----        1000
#  fld_reU minmax values: -0.696078598      0.711581647
#  fld_imU minmax values: -0.443106055      0.828201592
#  it----        1500
#  fld_reU minmax values: -0.293518871      0.200187817
#  fld_imU minmax values: -0.218352780      0.284507185
#  Elapsed time to add source                 3.21578979E-02
#  Elapsed time to save boundary             0.685096741
#  Elapsed time to update field               42.3374977
#  Elapsed time to evolve field               5.43212891E-03
#  Elapsed time to extract field              2.70853424
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_sfield%*  n1=191 perc=99
#  xmovie < snap_sfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  DATA_FORMAT is NOT found, take default: su
#  Found proper SU scalel = 1.00000000
#  SU_SCALEL is NOT found, take default: 1.00000000
#  Found proper SU scalco = 1.00000000
#  SU_SCALCO is NOT found, take default: 1.00000000
#  SU data write success.
#  SU data write success.
#  JOB : gradient
#  IF_BLOOM is NOT found, take default: T
#  IF_BLOOM is NOT found, take default: T
#  ----  Computing obj func & dadj  ----
#  WEIGHTING (WEI) : none
#  WEIGHTING_OPERATIONS (WEI_OP) is NOT found, take default: multiply
#  SU data write success.
#  DATA_NORM (DNORM) is NOT found, take default: L2
#  SU data write success.
#  SU data write success.
#  ----  Solving adjoint eqn & xcorrelate  ----
#  it----        1500
#  fld_reA minmax values: -0.145851091      0.146891281
#  fld_imA minmax values: -0.139626786      0.152809188
#  fld_reU minmax values: -0.272787243      0.194095373
#  fld_imU minmax values: -0.217111871      0.257533967
#  it----        1000
#  fld_reA minmax values: -0.480061650      0.465985447
#  fld_imA minmax values: -0.393680930      0.512226045
#  fld_reU minmax values: -0.688188732      0.703760266
#  fld_imU minmax values: -0.437480241      0.819521546
#  it----         500
#  fld_reA minmax values: -0.591418266      0.890178084
#  fld_imA minmax values: -0.752519846      0.785252452
#  fld_reU minmax values: -0.936428726       1.20511186
#  fld_imU minmax values: -0.840017498       1.27030993
#  Elapsed time to evolve field           4.60815430E-03
#  Elapsed time to load boundary         0.522247314
#  Elapsed time to update field           41.9475250
#  Elapsed time to rm source              4.75769043E-02
#  Elapsed time -----------------------
#  Elapsed time to add adj & virtual src       4.07934570
#  Elapsed time to update adj field            48.1852722
#  Elapsed time to evolve adj field            7.32421875E-03
#  Elapsed time to extract fields              0.00000000
#  Elapsed time to correlate                   8.47778320E-02
#  Viewing the snapshots (if written) with SU ximage/xmovie:
#  ximage < snap_rfield%*  n1=191 perc=99
#  xmovie < snap_rfield%*  n1=191 n2=858 clip=?e-?? loop=2 title=%g
#  ximage < snap_*  n1=143 perc=99
#  xmovie < snap_*  n1=143 n2=810 clip=?e-?? loop=2 title=%g
#  ----  Assemble  ----
#  ---------------------------------
#          END LOOP OVER SHOTS
#  Stacked misfit 7.27683306E-04
#  Stacked but not yet linesearch-scaled fobj%dnorms :  L1=    7.27683306E-04  L2sq=    7.27683306E-04
#  SMOOTHING (SMTH) : Laplacian
#  Laplacian smoothing
#  SMTH_ADDMIRROR is NOT found, take default: 21.0000000
#  LAPLACIAN_SMTH_FRACTION_WAVELENGTH (LAP_FRAC) : 0.5 0.5 0.5
#  LAPLACIAN_SMTH_PRESERVE_GRAD_NORM (LAP_PRESERVE) is NOT found, take default: nopreserve
#  GRADIENT_SOFT_MASK (MASK) is NOT found, take 0, '' or F
#  Parametrizer finds gbuo & gikpa
#  PRECONDITIONING (PRECO) : z^1.5
#  Will precondition the gradient by z^1.5
#  Linesearch based on a bracketing - dichotomy algoritm
# Steplength (alpha) judged by Wolfe conditions
#  Wolfe condition parameters: c1=9.99999975E-05, c2=0.899999976
#  MAX_SEARCH is NOT found, take default: 12
#  WOLFE_C2 is NOT found, take default: 0.9
#  LINESEARCHER_SCALING (LS_SCALING) is NOT found, take default: by total_volume/||pg(1)||1
#  Linesearch scaler= 15976.6348
#  qp0%f, ║g║₁ = 11.6259308, 31.8660965
#  JOB : gradient
#  ===================================
#    SeisJIMU has finished the job
# ===================================
#  System date: 09/25/2025
# System time: 15:55:30
# System timezone: +03:00

# %%
grad0=read('results_grad_noQ/correlate_gradient',(2*nx,nz)) [:,nx:]
grad1=read('results_grad/correlate_gradient'    ,(2*nx,nz)) [:,nx:]

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(grad0,perc=90,title='no Q')
plt.subplot(1,3,2); imshow(grad1,perc=90,title='with Q')
plt.subplot(1,3,3); imshow(grad0-grad1,perc=90,title='diff')

# %%
plt.figure(figsize=(8,2))
plt.plot(grad0[:,200],label='no Q')
plt.plot(grad1[:,200],label='with Q')

# %%
grad2=read('results_grad/qp0%pg')

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(grad0,perc=98)
plt.subplot(1,3,2); imshow(grad1,perc=98)
plt.subplot(1,3,3); imshow(grad2,perc=98)

# %% [markdown]
# ## FWI NOsmth NOzpow

# %%
# !cp setup_default setup
# !echo "FILE_MODEL       init" >> setup
# !echo "DIR_OUT          res_NOsmth_NOzpow " >> setup
# !echo "PRECO            none         "  >> setup
# !echo "JOB              optimization " >> setup
run_remote(app='../../exe/FWI',np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
plt.figure(figsize=(12,3))
imshow(read('res_NOsmth_NOzpow/qp0%pg'),perc=98)

# %%
# !cat res_NOsmth_NOzpow/optimization.log
# Out:
#  **********************************************************************
#     LIMITED-MEMORY BFGS ALGORITHM
#  **********************************************************************
#      Min descent allowed      =1.0000E-08
#      Max iterates allowed     =  120
#      Max linesearches allowed =   12
#      Max gradients allowed    =  150
#      Linesearch scaler        =2.08152695E+01
#      Initial gradient L1norm (║g0║₁)  =3.1865E+01
#  **********************************************************************
#          LinS#  Grad#     α    pert%       f                            g·d   Wolfe_cond
#   Iter#         Grad#          curr%       f    f/f0(%) ║g║₁/║g0║₁(%)   g·d
#  ========================================================================================
#      0             1                 1.5147E-02 100.000  100.000     -1.03E-01
#             1      2  1.00E+00       1.5075E-02                       1.03E-02   T T
#      1             2                 1.5075E-02  99.528  100.858     -2.95E-02
#  ----------------------------------------------------------------------------------------
#             1      3  1.00E+00       1.4400E-02                      -2.30E-02   T T
#      2             3                 1.4400E-02  95.070  101.000     -1.83E-01
#  ----------------------------------------------------------------------------------------
#             1      4  1.00E+00       1.0525E-02                       6.93E-03   T T
#      3             4                 1.0525E-02  69.485   93.898     -1.49E-01
#  ----------------------------------------------------------------------------------------
#             1      5  1.00E+00       9.1210E-03                      -5.26E-02   T T
#      4             5                 9.1210E-03  60.217   62.981     -1.32E-01
#  ----------------------------------------------------------------------------------------
#             1      6  1.00E+00       8.6636E-03                       5.93E-02   T T
#      5             6                 8.6636E-03  57.197   60.327     -5.05E-02
#  ----------------------------------------------------------------------------------------
#             1      7  1.00E+00       8.6803E-03                      -1.26E-02   F T
#             2      8  5.00E-01       8.6613E-03                      -3.15E-02   F T
#             3      9  2.50E-01       8.6598E-03                      -4.10E-02   T T
#      6             9                 8.6598E-03  57.172   58.146     -6.68E-02
#  ----------------------------------------------------------------------------------------
#             1     10  1.00E+00       8.5891E-03                       5.25E-03   T T
#      7            10                 8.5891E-03  56.705   51.676     -1.32E-02
#  ----------------------------------------------------------------------------------------
#             1     11  1.00E+00       8.4953E-03                      -9.77E-03   T T
#      8            11                 8.4953E-03  56.086   50.407     -6.41E-02
#  ----------------------------------------------------------------------------------------
#             1     12  1.00E+00       7.9972E-03                      -1.80E-02   T T
#      9            12                 7.9972E-03  52.798   46.682     -6.68E-02
#  ----------------------------------------------------------------------------------------
#             1     13  1.00E+00       7.4024E-03                       6.54E-02   T F
#             2     14  1.00E+01       1.6393E-02                       1.08E+00   F F
#             3     15  5.50E+00       7.8375E-03                       8.16E-01   T F
#             4     16  7.75E+00       1.1053E-02                       1.00E+00   F F
#             5     17  6.62E+00       9.1473E-03                       9.19E-01   F F
#             6     18  6.06E+00       8.4203E-03                       8.68E-01   F F
#             7     19  5.78E+00       8.1101E-03                       8.41E-01   F F
#             8     20  5.64E+00       7.9694E-03                       8.28E-01   F F
#             9     21  5.57E+00       7.9024E-03                       8.22E-01   T F
#            10     22  5.61E+00       7.9357E-03                       8.25E-01   T F
#            11     23  5.62E+00       7.9525E-03                       8.26E-01   T F
#     10            23                 7.9525E-03  52.502  135.080     -3.34E+00
#  ----------------------------------------------------------------------------------------
#             1     24  1.00E+00       7.3289E-03                      -5.66E-03   T T
#     11            24                 7.3289E-03  48.385   44.397     -2.33E-02
#  ----------------------------------------------------------------------------------------
#             1     25  1.00E+00       7.4769E-03                      -1.78E-03   F T
#             2     26  5.00E-01       7.3944E-03                      -1.29E-02   F T
#             3     27  2.50E-01       7.3596E-03                      -1.82E-02   F T
#             4     28  1.25E-01       7.3436E-03                      -2.08E-02   F T
#             5     29  6.26E-02       7.3361E-03                      -2.21E-02   F F

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('res_NOsmth_NOzpow/model_Iter1'))
plt.subplot(1,3,2); imshow(read('res_NOsmth_NOzpow/model_Iter5'))
plt.subplot(1,3,3); imshow(read('res_NOsmth_NOzpow/model_Iter9'))

# %% [markdown]
# ## FWI smthx0.2 zpow1

# %%
# !cp setup_default setup
# !echo "FILE_MODEL       init         " >> setup
# !echo "DIR_OUT          res_smthx0.2_zpow1 " >> setup
# !echo "SMTH             Laplacian "     >> setup
# !echo "LAP_FRAC        '0.1 0.2 0.2' "  >> setup
# !echo "PRECO            z^1          "  >> setup
# !echo "JOB              optimization " >> setup
run_remote(app='../../exe/FWI',np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
plt.figure(figsize=(12,3))
imshow(read('res_smthx0.2_zpow1/qp0%pg'),perc=98)

# %%
# !cat res_smthx0.2_zpow1/optimization.log
# Out:
#  **********************************************************************
#     LIMITED-MEMORY BFGS ALGORITHM
#  **********************************************************************
#      Min descent allowed      =1.0000E-08
#      Max iterates allowed     =  120
#      Max linesearches allowed =   12
#      Max gradients allowed    =  150
#      Linesearch scaler        =1.41585957E+04
#      Initial gradient L1norm (║g0║₁)  =3.1867E+01
#  **********************************************************************
#          LinS#  Grad#     α    pert%       f                            g·d   Wolfe_cond
#   Iter#         Grad#          curr%       f    f/f0(%) ║g║₁/║g0║₁(%)   g·d
#  ========================================================================================
#      0             1                 1.0303E+01 100.000  100.000     -1.84E-02
#             1      2  1.00E+00       9.9317E+00                      -1.91E-02   T F
#             2      3  1.00E+01       6.7140E+00                      -1.32E-02   T T
#      1             3                 6.7140E+00  65.166   82.287     -5.76E-01
#  ----------------------------------------------------------------------------------------
#             1      4  1.00E+00       1.0165E+01                      -1.42E-02   F T
#             2      5  5.00E-01       8.2906E+00                       4.44E-01   F T
#             3      6  2.50E-01       6.0001E+00                       1.33E-01   T T
#      2             6                 6.0001E+00  58.237   75.877     -3.70E-02
#  ----------------------------------------------------------------------------------------
#             1      7  1.00E+00       5.6220E+00                      -2.92E-02   T T
#      3             7                 5.6220E+00  54.567   60.324     -1.74E-01
#  ----------------------------------------------------------------------------------------
#             1      8  1.00E+00       4.5416E+00                       5.43E-02   T T
#      4             8                 4.5416E+00  44.081   55.784     -2.67E-02
#  ----------------------------------------------------------------------------------------
#             1      9  1.00E+00       4.4689E+00                      -1.17E-02   T T
#      5             9                 4.4689E+00  43.375   36.478     -2.51E-02
#  ----------------------------------------------------------------------------------------
#             1     10  1.00E+00       4.3495E+00                      -1.25E-02   T T
#      6            10                 4.3495E+00  42.216   35.462     -4.05E-02
#  ----------------------------------------------------------------------------------------
#             1     11  1.00E+00       3.9897E+00                      -1.99E-02   T T
#      7            11                 3.9897E+00  38.723   45.684     -5.64E-02
#  ----------------------------------------------------------------------------------------
#             1     12  1.00E+00       3.2982E+00                      -1.64E-02   T T
#      8            12                 3.2982E+00  32.012   49.224     -5.87E-02
#  ----------------------------------------------------------------------------------------
#             1     13  1.00E+00       2.4820E+00                      -9.26E-04   T T
#      9            13                 2.4820E+00  24.091   36.072     -1.61E-02
#  ----------------------------------------------------------------------------------------
#             1     14  1.00E+00       2.3571E+00                      -8.64E-03   T T
#     10            14                 2.3571E+00  22.878   27.121     -1.96E-02
#  ----------------------------------------------------------------------------------------
#             1     15  1.00E+00       2.1225E+00                      -3.88E-03   T T
#     11            15                 2.1225E+00  20.601   28.047     -8.50E-03
#  ----------------------------------------------------------------------------------------
#             1     16  1.00E+00       1.9577E+00                      -6.20E-03   T T
#     12            16                 1.9577E+00  19.001   27.223     -3.43E-02
#  ----------------------------------------------------------------------------------------
#             1     17  1.00E+00       1.6237E+00                      -6.38E-03   T T
#     13            17                 1.6237E+00  15.759   25.709     -1.33E-02
#  ----------------------------------------------------------------------------------------
#             1     18  1.00E+00       1.5412E+00                      -7.87E-03   T T
#     14            18                 1.5412E+00  14.959   21.036     -2.10E-02
#  ----------------------------------------------------------------------------------------
#             1     19  1.00E+00       1.3909E+00                      -4.39E-03   T T
#     15            19                 1.3909E+00  13.500   19.574     -7.23E-03
#  ----------------------------------------------------------------------------------------
#             1     20  1.00E+00       1.2944E+00                      -4.21E-03   T T
#     16            20                 1.2944E+00  12.563   18.782     -1.38E-02
#  ----------------------------------------------------------------------------------------
#             1     21  1.00E+00       1.1588E+00                      -3.02E-03   T T
#     17            21                 1.1588E+00  11.248   17.658     -6.29E-03
#  ----------------------------------------------------------------------------------------
#             1     22  1.00E+00       1.0859E+00                      -2.76E-03   T T
#     18            22                 1.0859E+00  10.540   16.838     -6.97E-03
#  ----------------------------------------------------------------------------------------
#             1     23  1.00E+00       9.5754E-01                      -2.40E-03   T T
#     19            23                 9.5754E-01   9.294   14.060     -4.48E-03
#  ----------------------------------------------------------------------------------------
#             1     24  1.00E+00       8.8435E-01                      -1.92E-03   T T
#     20            24                 8.8435E-01   8.583   12.103     -4.11E-03
#  ----------------------------------------------------------------------------------------
#             1     25  1.00E+00       8.5291E-01                      -1.91E-03   T T
#     21            25                 8.5291E-01   8.278   11.612     -4.30E-03
#  ----------------------------------------------------------------------------------------
#             1     26  1.00E+00       8.2244E-01                      -1.86E-03   T T
#     22            26                 8.2244E-01   7.983   12.273     -4.26E-03
#  ----------------------------------------------------------------------------------------
#             1     27  1.00E+00       7.7701E-01                      -1.91E-03   T T
#     23            27                 7.7701E-01   7.542   12.224     -4.87E-03
#  ----------------------------------------------------------------------------------------
#             1     28  1.00E+00       7.0838E-01                      -1.53E-03   T T
#     24            28                 7.0838E-01   6.876   11.205     -3.58E-03
#  ----------------------------------------------------------------------------------------
#             1     29  1.00E+00       6.6291E-01                      -6.22E-04   T T
#     25            29                 6.6291E-01   6.434    9.547     -1.70E-03
#  ----------------------------------------------------------------------------------------
#             1     30  1.00E+00       6.2632E-01                      -7.50E-04   T T
#     26            30                 6.2632E-01   6.079    8.378     -1.73E-03
#  ----------------------------------------------------------------------------------------
#             1     31  1.00E+00       5.9098E-01                      -8.61E-04   T T
#     27            31                 5.9098E-01   5.736    7.804     -2.41E-03
#  ----------------------------------------------------------------------------------------
#             1     32  1.00E+00       5.5395E-01                      -1.15E-03   T T
#     28            32                 5.5395E-01   5.377    7.149     -2.51E-03
#  ----------------------------------------------------------------------------------------
#             1     33  1.00E+00       5.1650E-01                      -9.83E-04   T T
#     29            33                 5.1650E-01   5.013    6.220     -1.80E-03
#  ----------------------------------------------------------------------------------------
#             1     34  1.00E+00       4.8245E-01                      -6.49E-04   T T
#     30            34                 4.8245E-01   4.683    6.259     -1.61E-03
#  ----------------------------------------------------------------------------------------
#             1     35  1.00E+00       4.5964E-01                      -1.80E-04   T T
#     31            35                 4.5964E-01   4.461    7.856     -9.46E-04
#  ----------------------------------------------------------------------------------------
#             1     36  1.00E+00       4.3869E-01                      -3.78E-04   T T
#     32            36                 4.3869E-01   4.258    5.759     -8.19E-04
#  ----------------------------------------------------------------------------------------
#             1     37  1.00E+00       4.2688E-01                      -3.63E-04   T T
#     33            37                 4.2688E-01   4.143    5.312     -8.93E-04
#  ----------------------------------------------------------------------------------------
#             1     38  1.00E+00       4.0858E-01                      -4.67E-04   T T
#     34            38                 4.0858E-01   3.966    4.898     -1.17E-03
#  ----------------------------------------------------------------------------------------
#             1     39  1.00E+00       3.8317E-01                      -4.77E-04   T T
#     35            39                 3.8317E-01   3.719    4.576     -9.27E-04
#  ----------------------------------------------------------------------------------------
#             1     40  1.00E+00       3.6490E-01                      -4.48E-04   T T
#     36            40                 3.6490E-01   3.542    4.394     -1.10E-03
#  ----------------------------------------------------------------------------------------
#             1     41  1.00E+00       3.4652E-01                      -4.82E-04   T T
#     37            41                 3.4652E-01   3.363    4.403     -1.14E-03
#  ----------------------------------------------------------------------------------------
#             1     42  1.00E+00       3.2350E-01                       2.27E-04   T T
#     38            42                 3.2350E-01   3.140    8.275     -5.92E-04
#  ----------------------------------------------------------------------------------------
#             1     43  1.00E+00       3.1990E-01                      -2.30E-04   T T
#     39            43                 3.1990E-01   3.105    4.176     -3.35E-04
#  ----------------------------------------------------------------------------------------
#             1     44  1.00E+00       3.1612E-01                      -1.22E-04   T T
#     40            44                 3.1612E-01   3.068    3.602     -2.33E-04
#  ----------------------------------------------------------------------------------------
#             1     45  1.00E+00       3.1148E-01                      -1.36E-04   T T
#     41            45                 3.1148E-01   3.023    3.497     -5.19E-04
#  ----------------------------------------------------------------------------------------
#             1     46  1.00E+00       3.0109E-01                      -2.40E-04   T T
#     42            46                 3.0109E-01   2.922    3.499     -5.82E-04
#  ----------------------------------------------------------------------------------------
#             1     47  1.00E+00       2.8674E-01                      -2.11E-04   T T
#     43            47                 2.8674E-01   2.783    3.645     -5.20E-04
#  ----------------------------------------------------------------------------------------
#             1     48  1.00E+00       2.7659E-01                      -9.28E-05   T T
#     44            48                 2.7659E-01   2.685    3.644     -3.22E-04
#  ----------------------------------------------------------------------------------------
#             1     49  1.00E+00       2.6770E-01                      -1.55E-04   T T
#     45            49                 2.6770E-01   2.598    3.253     -4.20E-04
#  ----------------------------------------------------------------------------------------
#             1     50  1.00E+00       2.5995E-01                      -1.35E-04   T T
#     46            50                 2.5995E-01   2.523    3.382     -4.09E-04
#  ----------------------------------------------------------------------------------------
#             1     51  1.00E+00       2.5099E-01                       7.56E-06   T T
#     47            51                 2.5099E-01   2.436    4.036     -1.72E-04
#  ----------------------------------------------------------------------------------------
#             1     52  1.00E+00       2.4888E-01                      -1.13E-04   T T
#     48            52                 2.4888E-01   2.416    2.803     -3.50E-04
#  ----------------------------------------------------------------------------------------
#             1     53  1.00E+00       2.4495E-01                      -7.59E-05   T T
#     49            53                 2.4495E-01   2.377    3.094     -1.25E-04
#  ----------------------------------------------------------------------------------------
#             1     54  1.00E+00       2.4111E-01                      -8.19E-05   T T
#     50            54                 2.4111E-01   2.340    3.042     -4.04E-04
#  ----------------------------------------------------------------------------------------
#             1     55  1.00E+00       2.3170E-01                      -1.42E-04   T T
#     51            55                 2.3170E-01   2.249    3.256     -4.17E-04
#  ----------------------------------------------------------------------------------------
#             1     56  1.00E+00       2.1925E-01                      -7.05E-07   T T
#     52            56                 2.1925E-01   2.128    4.060     -2.07E-04
#  ----------------------------------------------------------------------------------------
#             1     57  1.00E+00       2.1421E-01                      -1.16E-04   T T
#     53            57                 2.1421E-01   2.079    2.826     -2.62E-04
#  ----------------------------------------------------------------------------------------
#             1     58  1.00E+00       2.0780E-01                      -7.64E-05   T T
#     54            58                 2.0780E-01   2.017    2.343     -1.25E-04
#  ----------------------------------------------------------------------------------------
#             1     59  1.00E+00       2.0411E-01                      -7.78E-05   T T
#     55            59                 2.0411E-01   1.981    2.309     -2.96E-04
#  ----------------------------------------------------------------------------------------
#             1     60  1.00E+00       1.9640E-01                      -6.78E-05   T T
#     56            60                 1.9640E-01   1.906    2.980     -2.04E-04
#  ----------------------------------------------------------------------------------------
#             1     61  1.00E+00       1.9443E-01                      -1.84E-05   T T
#     57            61                 1.9443E-01   1.887    2.855     -9.13E-05
#  ----------------------------------------------------------------------------------------
#             1     62  1.00E+00       1.9210E-01                      -5.16E-05   T T
#     58            62                 1.9210E-01   1.865    2.397     -1.47E-04
#  ----------------------------------------------------------------------------------------
#             1     63  1.00E+00       1.8849E-01                      -5.81E-05   T T
#     59            63                 1.8849E-01   1.830    2.240     -1.15E-04
#  ----------------------------------------------------------------------------------------
#             1     64  1.00E+00       1.8476E-01                      -6.28E-05   T T
#     60            64                 1.8476E-01   1.793    2.172     -1.95E-04
#  ----------------------------------------------------------------------------------------
#             1     65  1.00E+00       1.7772E-01                      -8.19E-05   T T
#     61            65                 1.7772E-01   1.725    2.149     -1.99E-04
#  ----------------------------------------------------------------------------------------
#             1     66  1.00E+00       1.7341E-01                      -3.78E-05   T T
#     62            66                 1.7341E-01   1.683    2.380     -1.26E-04
#  ----------------------------------------------------------------------------------------
#             1     67  1.00E+00       1.6891E-01                      -5.76E-05   T T
#     63            67                 1.6891E-01   1.639    1.855     -1.30E-04
#  ----------------------------------------------------------------------------------------
#             1     68  1.00E+00       1.6565E-01                      -5.58E-05   T T
#     64            68                 1.6565E-01   1.608    1.850     -1.21E-04
#  ----------------------------------------------------------------------------------------
#             1     69  1.00E+00       1.6248E-01                      -3.30E-05   T T
#     65            69                 1.6248E-01   1.577    2.245     -9.89E-05
#  ----------------------------------------------------------------------------------------
#             1     70  1.00E+00       1.6150E-01                      -3.42E-05   T T
#     66            70                 1.6150E-01   1.567    2.009     -8.37E-05
#  ----------------------------------------------------------------------------------------
#             1     71  1.00E+00       1.6049E-01                      -4.11E-05   T T
#     67            71                 1.6049E-01   1.558    1.910     -1.22E-04
#  ----------------------------------------------------------------------------------------
#             1     72  1.00E+00       1.5776E-01                      -6.14E-05   T T
#     68            72                 1.5776E-01   1.531    1.861     -1.49E-04
#  ----------------------------------------------------------------------------------------
#             1     73  1.00E+00       1.5298E-01                      -6.23E-05   T T
#     69            73                 1.5298E-01   1.485    1.762     -1.19E-04
#  ----------------------------------------------------------------------------------------
#             1     74  1.00E+00       1.4861E-01                      -5.61E-05   T T
#     70            74                 1.4861E-01   1.442    1.631     -1.29E-04
#  ----------------------------------------------------------------------------------------
#             1     75  1.00E+00       1.4428E-01                      -5.47E-05   T T
#     71            75                 1.4428E-01   1.400    1.616     -1.37E-04
#  ----------------------------------------------------------------------------------------
#             1     76  1.00E+00       1.4266E-01                       4.25E-05   T T
#     72            76                 1.4266E-01   1.385    3.560     -7.88E-05
#  ----------------------------------------------------------------------------------------
#             1     77  1.00E+00       1.4070E-01                      -3.02E-05   T T
#     73            77                 1.4070E-01   1.366    1.804     -4.06E-05
#  ----------------------------------------------------------------------------------------
#             1     78  1.00E+00       1.3981E-01                      -1.59E-05   T T
#     74            78                 1.3981E-01   1.357    1.521     -3.10E-05
#  ----------------------------------------------------------------------------------------
#             1     79  1.00E+00       1.3929E-01                      -1.77E-05   T T
#     75            79                 1.3929E-01   1.352    1.585     -6.97E-05
#  ----------------------------------------------------------------------------------------
#             1     80  1.00E+00       1.3813E-01                      -3.89E-05   T T
#     76            80                 1.3813E-01   1.341    1.591     -1.17E-04
#  ----------------------------------------------------------------------------------------
#             1     81  1.00E+00       1.3623E-01                      -4.96E-05   T T
#     77            81                 1.3623E-01   1.322    1.511     -1.04E-04
#  ----------------------------------------------------------------------------------------
#             1     82  1.00E+00       1.3436E-01                      -3.93E-05   T T
#     78            82                 1.3436E-01   1.304    1.472     -9.92E-05
#  ----------------------------------------------------------------------------------------
#             1     83  1.00E+00       1.3178E-01                      -1.41E-05   T T
#     79            83                 1.3178E-01   1.279    1.834     -5.66E-05
#  ----------------------------------------------------------------------------------------
#             1     84  1.00E+00       1.3009E-01                      -2.77E-05   T T
#     80            84                 1.3009E-01   1.263    1.476     -7.11E-05
#  ----------------------------------------------------------------------------------------
#             1     85  1.00E+00       1.2885E-01                      -2.70E-05   T T
#     81            85                 1.2885E-01   1.251    1.349     -6.04E-05
#  ----------------------------------------------------------------------------------------
#             1     86  1.00E+00       1.2757E-01                      -2.94E-05   T T
#     82            86                 1.2757E-01   1.238    1.566     -8.65E-05
#  ----------------------------------------------------------------------------------------
#             1     87  1.00E+00       1.2705E-01                      -2.56E-05   T T
#     83            87                 1.2705E-01   1.233    1.400     -5.58E-05
#  ----------------------------------------------------------------------------------------
#             1     88  1.00E+00       1.2599E-01                      -1.91E-05   T T
#     84            88                 1.2599E-01   1.223    1.271     -4.10E-05
#  ----------------------------------------------------------------------------------------
#             1     89  1.00E+00       1.2559E-01                      -2.09E-05   T T
#     85            89                 1.2559E-01   1.219    1.200     -5.40E-05
#  ----------------------------------------------------------------------------------------
#             1     90  1.00E+00       1.2492E-01                      -2.09E-05   T T
#     86            90                 1.2492E-01   1.212    1.239     -4.93E-05
#  ----------------------------------------------------------------------------------------
#             1     91  1.00E+00       1.2441E-01                      -2.08E-05   T T
#     87            91                 1.2441E-01   1.208    1.394     -6.03E-05
#  ----------------------------------------------------------------------------------------
#             1     92  1.00E+00       1.2358E-01                      -1.92E-05   T T
#     88            92                 1.2358E-01   1.200    1.225     -4.66E-05
#  ----------------------------------------------------------------------------------------
#             1     93  1.00E+00       1.2287E-01                      -2.22E-05   T T
#     89            93                 1.2287E-01   1.193    1.246     -5.46E-05
#  ----------------------------------------------------------------------------------------
#             1     94  1.00E+00       1.2167E-01                      -1.59E-05   T T
#     90            94                 1.2167E-01   1.181    1.129     -3.50E-05
#  ----------------------------------------------------------------------------------------
#             1     95  1.00E+00       1.2164E-01                      -1.52E-05   T T
#     91            95                 1.2164E-01   1.181    1.268     -4.24E-05
#  ----------------------------------------------------------------------------------------
#             1     96  1.00E+00       1.2121E-01                      -1.78E-05   T T
#     92            96                 1.2121E-01   1.176    1.190     -4.58E-05
#  ----------------------------------------------------------------------------------------
#             1     97  1.00E+00       1.2102E-01                      -2.31E-05   T T
#     93            97                 1.2102E-01   1.175    1.195     -6.54E-05
#  ----------------------------------------------------------------------------------------
#             1     98  1.00E+00       1.2030E-01                      -1.60E-05   T T
#     94            98                 1.2030E-01   1.168    1.367     -3.69E-05
#  ----------------------------------------------------------------------------------------
#             1     99  1.00E+00       1.2040E-01                      -1.33E-05   F T
#             2    100  5.00E-01       1.2030E-01                      -2.52E-05   F T
#             3    101  2.50E-01       1.2029E-01                      -3.11E-05   T T
#     95           101                 1.2029E-01   1.168    1.222     -6.10E-05
#  ----------------------------------------------------------------------------------------
#             1    102  1.00E+00       1.2036E-01                      -1.08E-05   F T
#             2    103  5.00E-01       1.2021E-01                      -3.61E-05   T T
#     96           103                 1.2021E-01   1.167    0.987     -4.21E-05
#  ----------------------------------------------------------------------------------------
#             1    104  1.00E+00       1.2039E-01                      -1.23E-05   F T
#             2    105  5.00E-01       1.2023E-01                      -2.73E-05   F T
#             3    106  2.50E-01       1.2020E-01                      -3.47E-05   T T
#     97           106                 1.2020E-01   1.167    0.932     -5.72E-05
#  ----------------------------------------------------------------------------------------
#             1    107  1.00E+00       1.2014E-01                      -1.27E-05   T T
#     98           107                 1.2014E-01   1.166    1.025     -2.17E-05
#  ----------------------------------------------------------------------------------------
#             1    108  1.00E+00       1.2027E-01                      -1.39E-05   F T
#             2    109  5.00E-01       1.2018E-01                      -1.78E-05   F T
#             3    110  2.50E-01       1.2016E-01                      -1.98E-05   F F
#             4    111  1.25E-01       1.2015E-01                      -2.07E-05   F F
#             5    112  6.26E-02       1.2015E-01                      -2.12E-05   F F
#             6    113  3.13E-02       1.2015E-01                      -2.14E-05   F F
#             7    114  1.57E-02       1.2015E-01                      -2.16E-05   F F
#             8    115  7.91E-03       1.2014E-01                      -2.16E-05   F F
#             9    116  4.01E-03       1.2014E-01                      -2.16E-05   T F
#            10    117  5.96E-03       1.2015E-01                      -2.16E-05   F F
#            11    118  4.98E-03       1.2015E-01                      -2.16E-05   F F
#            12    119  4.01E-03       1.2014E-01                      -2.16E-05   T F
#     99           119                 1.2014E-01   1.166    1.025     -9.72E-05
#  ----------------------------------------------------------------------------------------
#             1    120  1.00E+00       1.1982E-01                      -1.04E-05   T T
#    100           120                 1.1982E-01   1.163    1.123     -3.45E-05
#  ----------------------------------------------------------------------------------------
#             1    121  1.00E+00       1.1928E-01                      -1.14E-05   T T
#    101           121                 1.1928E-01   1.158    1.773     -3.42E-05
#  ----------------------------------------------------------------------------------------
#             1    122  1.00E+00       1.1838E-01                      -1.60E-05   T T
#    102           122                 1.1838E-01   1.149    1.512     -3.92E-05
#  ----------------------------------------------------------------------------------------
#             1    123  1.00E+00       1.1742E-01                      -1.86E-05   T T
#    103           123                 1.1742E-01   1.140    1.135     -3.61E-05
#  ----------------------------------------------------------------------------------------
#             1    124  1.00E+00       1.1646E-01                      -1.54E-05   T T
#    104           124                 1.1646E-01   1.130    1.191     -3.12E-05
#  ----------------------------------------------------------------------------------------
#             1    125  1.00E+00       1.1576E-01                      -1.61E-05   T T
#    105           125                 1.1576E-01   1.124    1.276     -4.08E-05
#  ----------------------------------------------------------------------------------------
#             1    126  1.00E+00       1.1513E-01                      -1.78E-05   T T
#    106           126                 1.1513E-01   1.117    1.175     -4.13E-05
#  ----------------------------------------------------------------------------------------
#             1    127  1.00E+00       1.1504E-01                      -1.81E-05   T T
#    107           127                 1.1504E-01   1.117    1.083     -4.79E-05
#  ----------------------------------------------------------------------------------------
#             1    128  1.00E+00       1.1443E-01                      -9.40E-06   T T
#    108           128                 1.1443E-01   1.111    1.087     -2.97E-05
#  ----------------------------------------------------------------------------------------
#             1    129  1.00E+00       1.1446E-01                      -1.02E-05   F T
#             2    130  5.00E-01       1.1440E-01                      -2.00E-05   T T
#    109           130                 1.1440E-01   1.110    0.989     -3.90E-05
#  ----------------------------------------------------------------------------------------
#             1    131  1.00E+00       1.1402E-01                      -1.08E-05   T T
#    110           131                 1.1402E-01   1.107    1.046     -2.20E-05
#  ----------------------------------------------------------------------------------------
#             1    132  1.00E+00       1.1352E-01                      -1.48E-05   T T
#    111           132                 1.1352E-01   1.102    0.994     -6.35E-05
#  ----------------------------------------------------------------------------------------
#             1    133  1.00E+00       1.1255E-01                      -1.76E-05   T T
#    112           133                 1.1255E-01   1.092    1.157     -5.16E-05
#  ----------------------------------------------------------------------------------------
#             1    134  1.00E+00       1.1201E-01                       1.42E-05   T T
#    113           134                 1.1201E-01   1.087    1.940     -2.15E-05
#  ----------------------------------------------------------------------------------------
#             1    135  1.00E+00       1.1193E-01                      -1.11E-05   T T
#    114           135                 1.1193E-01   1.086    1.182     -2.19E-05
#  ----------------------------------------------------------------------------------------
#             1    136  1.00E+00       1.1185E-01                      -6.18E-06   T T
#    115           136                 1.1185E-01   1.086    0.835     -9.42E-06
#  ----------------------------------------------------------------------------------------
#             1    137  1.00E+00       1.1183E-01                      -5.80E-06   T T
#    116           137                 1.1183E-01   1.085    0.872     -2.73E-05
#  ----------------------------------------------------------------------------------------
#             1    138  1.00E+00       1.1177E-01                      -1.48E-05   T T
#    117           138                 1.1177E-01   1.085    0.912     -4.52E-05
#  ----------------------------------------------------------------------------------------
#             1    139  1.00E+00       1.1194E-01                      -1.72E-05   F T
#             2    140  5.00E-01       1.1177E-01                      -3.13E-05   T T
#    118           140                 1.1177E-01   1.085    0.956     -7.32E-05
#  ----------------------------------------------------------------------------------------
#             1    141  1.00E+00       1.1121E-01                       2.35E-06   T T
#    119           141                 1.1121E-01   1.079    1.359     -3.22E-05
#  ----------------------------------------------------------------------------------------
#             1    142  1.00E+00       1.1125E-01                      -6.63E-06   F T
#             2    143  5.00E-01       1.1113E-01                      -1.94E-05   T T
#    120           143                 1.1113E-01   1.079    0.998     -2.85E-05
#  ----------------------------------------------------------------------------------------
#  **********************************************************************
#      FINALIZE
#  **********************************************************************

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('res_smthx0.2_zpow1/model_Iter1'))
plt.subplot(1,3,2); imshow(read('res_smthx0.2_zpow1/model_Iter4'))
plt.subplot(1,3,3); imshow(read('res_smthx0.2_zpow1/model_Iter7'))

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('res_smthx0.2_zpow1/model_Iter30'))
plt.subplot(1,3,2); imshow(read('res_smthx0.2_zpow1/model_final'))

# %%
iz=np.arange(nz)

fwi1=read('res_smthx0.2_zpow1/model_final')

plt.figure(figsize=(9,6))

plt.subplot(1,3,1); ix=200
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()

plt.subplot(1,3,2); ix=400
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()

plt.subplot(1,3,3); ix=600
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()

# %% [markdown]
# ## FWI noQ smthx0.2 zpow1

# %%
# !cp setup_default setup
# !echo "IS_Q_ATTENUATION   F" >> setup
# !echo "FILE_MODEL       init         " >> setup
# !echo "DIR_OUT          res_noQ_smthx0.2_zpow1 " >> setup
# !echo "SMTH             Laplacian "     >> setup
# !echo "LAP_FRAC        '0.1 0.2 0.2' "  >> setup
# !echo "PRECO            z^1          "  >> setup
# !echo "JOB              optimization " >> setup
run_remote(app='../../exe/FWI',np=36,nthreads=1,out='out')
# Out:
# bash ./run.sh > out

# %%
plt.figure(figsize=(12,3))
imshow(read('res_noQ_smthx0.2_zpow1/qp0%pg'),perc=98)

plt.figure(figsize=(12,3))
imshow(read('res_smthx0.2_zpow1/qp0%pg')-read('res_noQ_smthx0.2_zpow1/qp0%pg'),perc=98)

# %%
# !cat res_noQ_smthx0.2_zpow1/optimization.log
# Out:
#  **********************************************************************
#     LIMITED-MEMORY BFGS ALGORITHM
#  **********************************************************************
#      Min descent allowed      =1.0000E-08
#      Max iterates allowed     =  120
#      Max linesearches allowed =   12
#      Max gradients allowed    =  150
#      Linesearch scaler        =1.20795479E+04
#      Initial gradient L1norm (║g0║₁)  =3.1866E+01
#  **********************************************************************
#          LinS#  Grad#     α    pert%       f                            g·d   Wolfe_cond
#   Iter#         Grad#          curr%       f    f/f0(%) ║g║₁/║g0║₁(%)   g·d
#  ========================================================================================
#      0             1                 9.8336E+00 100.000  100.000     -1.96E-02
#             1      2  1.00E+00       9.4206E+00                      -2.02E-02   T F
#             2      3  1.00E+01       6.2189E+00                      -1.11E-02   T T
#      1             3                 6.2189E+00  63.242   71.093     -2.59E-01
#  ----------------------------------------------------------------------------------------
#             1      4  1.00E+00       8.2173E+00                       2.27E-01   F T
#             2      5  5.00E-01       5.9328E+00                       8.52E-02   T T
#      2             5                 5.9328E+00  60.332   84.228     -4.47E-02
#  ----------------------------------------------------------------------------------------
#             1      6  1.00E+00       5.3863E+00                      -3.24E-02   T T
#      3             6                 5.3863E+00  54.775   64.194     -1.40E-01
#  ----------------------------------------------------------------------------------------
#             1      7  1.00E+00       4.4602E+00                       2.35E-02   T T
#      4             7                 4.4602E+00  45.357   52.301     -2.10E-02
#  ----------------------------------------------------------------------------------------
#             1      8  1.00E+00       4.1781E+00                      -1.17E-02   T T
#      5             8                 4.1781E+00  42.488   40.121     -3.44E-02
#  ----------------------------------------------------------------------------------------
#             1      9  1.00E+00       3.9480E+00                      -1.37E-02   T T
#      6             9                 3.9480E+00  40.148   51.525     -3.77E-02
#  ----------------------------------------------------------------------------------------
#             1     10  1.00E+00       3.7176E+00                      -2.00E-02   T T
#      7            10                 3.7176E+00  37.805   62.113     -6.80E-02
#  ----------------------------------------------------------------------------------------
#             1     11  1.00E+00       3.0030E+00                      -1.99E-02   T T
#      8            11                 3.0030E+00  30.538   55.739     -4.59E-02
#  ----------------------------------------------------------------------------------------
#             1     12  1.00E+00       2.2730E+00                      -1.93E-02   T T
#      9            12                 2.2730E+00  23.114   30.843     -2.22E-02
#  ----------------------------------------------------------------------------------------
#             1     13  1.00E+00       2.0579E+00                      -3.42E-03   T T
#     10            13                 2.0579E+00  20.928   27.036     -4.79E-03
#  ----------------------------------------------------------------------------------------
#             1     14  1.00E+00       1.9815E+00                      -3.85E-03   T T
#     11            14                 1.9815E+00  20.150   29.012     -3.10E-02
#  ----------------------------------------------------------------------------------------
#             1     15  1.00E+00       1.5481E+00                      -8.05E-03   T T
#     12            15                 1.5481E+00  15.743   28.586     -1.84E-02
#  ----------------------------------------------------------------------------------------
#             1     16  1.00E+00       1.4185E+00                      -8.23E-03   T T
#     13            16                 1.4185E+00  14.426   26.765     -2.75E-02
#  ----------------------------------------------------------------------------------------
#             1     17  1.00E+00       1.3040E+00                       7.61E-03   T T
#     14            17                 1.3040E+00  13.261   32.064     -1.07E-02
#  ----------------------------------------------------------------------------------------
#             1     18  1.00E+00       1.2099E+00                      -2.93E-03   T T
#     15            18                 1.2099E+00  12.303   19.722     -4.94E-03
#  ----------------------------------------------------------------------------------------
#             1     19  1.00E+00       1.1442E+00                      -2.92E-03   T T
#     16            19                 1.1442E+00  11.636   17.400     -9.84E-03
#  ----------------------------------------------------------------------------------------
#             1     20  1.00E+00       1.0182E+00                      -3.55E-03   T T
#     17            20                 1.0182E+00  10.354   16.718     -6.53E-03
#  ----------------------------------------------------------------------------------------
#             1     21  1.00E+00       9.1735E-01                      -3.07E-03   T T
#     18            21                 9.1735E-01   9.329   15.804     -7.33E-03
#  ----------------------------------------------------------------------------------------
#             1     22  1.00E+00       8.0497E-01                      -2.75E-03   T T
#     19            22                 8.0497E-01   8.186   12.926     -5.16E-03
#  ----------------------------------------------------------------------------------------
#             1     23  1.00E+00       7.4249E-01                      -2.29E-03   T T
#     20            23                 7.4249E-01   7.551   11.290     -5.00E-03
#  ----------------------------------------------------------------------------------------
#             1     24  1.00E+00       7.1424E-01                      -2.25E-03   T T
#     21            24                 7.1424E-01   7.263   10.967     -4.80E-03
#  ----------------------------------------------------------------------------------------
#             1     25  1.00E+00       7.0217E-01                      -2.08E-03   T T
#     22            25                 7.0217E-01   7.141   10.725     -4.85E-03
#  ----------------------------------------------------------------------------------------
#             1     26  1.00E+00       6.7444E-01                      -1.62E-03   T T
#     23            26                 6.7444E-01   6.858   12.358     -4.35E-03
#  ----------------------------------------------------------------------------------------
#             1     27  1.00E+00       6.1828E-01                      -2.29E-04   T T
#     24            27                 6.1828E-01   6.287   11.201     -1.55E-03
#  ----------------------------------------------------------------------------------------
#             1     28  1.00E+00       5.8395E-01                      -7.17E-04   T T
#     25            28                 5.8395E-01   5.938    8.120     -1.49E-03
#  ----------------------------------------------------------------------------------------
#             1     29  1.00E+00       5.4851E-01                      -5.19E-04   T T
#     26            29                 5.4851E-01   5.578    8.562     -1.24E-03
#  ----------------------------------------------------------------------------------------
#             1     30  1.00E+00       5.2553E-01                      -7.88E-04   T T
#     27            30                 5.2553E-01   5.344    8.491     -3.13E-03
#  ----------------------------------------------------------------------------------------
#             1     31  1.00E+00       4.8505E-01                      -1.11E-03   T T
#     28            31                 4.8505E-01   4.933    7.662     -1.83E-03
#  ----------------------------------------------------------------------------------------
#             1     32  1.00E+00       4.5703E-01                      -6.99E-04   T T
#     29            32                 4.5703E-01   4.648    6.329     -1.45E-03
#  ----------------------------------------------------------------------------------------
#             1     33  1.00E+00       4.3085E-01                      -3.85E-04   T T
#     30            33                 4.3085E-01   4.381    5.589     -8.54E-04
#  ----------------------------------------------------------------------------------------
#             1     34  1.00E+00       4.1814E-01                      -4.37E-04   T T
#     31            34                 4.1814E-01   4.252    5.334     -1.28E-03
#  ----------------------------------------------------------------------------------------
#             1     35  1.00E+00       4.0123E-01                      -4.77E-04   T T
#     32            35                 4.0123E-01   4.080    5.418     -1.04E-03
#  ----------------------------------------------------------------------------------------
#             1     36  1.00E+00       3.8623E-01                      -1.26E-04   T T
#     33            36                 3.8623E-01   3.928    7.562     -6.51E-04
#  ----------------------------------------------------------------------------------------
#             1     37  1.00E+00       3.7075E-01                      -2.69E-04   T T
#     34            37                 3.7075E-01   3.770    5.308     -5.31E-04
#  ----------------------------------------------------------------------------------------
#             1     38  1.00E+00       3.5933E-01                      -2.35E-04   T T
#     35            38                 3.5933E-01   3.654    4.194     -4.60E-04
#  ----------------------------------------------------------------------------------------
#             1     39  1.00E+00       3.5058E-01                      -2.29E-04   T T
#     36            39                 3.5058E-01   3.565    4.501     -6.21E-04
#  ----------------------------------------------------------------------------------------
#             1     40  1.00E+00       3.3841E-01                      -3.20E-04   T T
#     37            40                 3.3841E-01   3.441    4.767     -8.53E-04
#  ----------------------------------------------------------------------------------------
#             1     41  1.00E+00       3.2111E-01                      -3.74E-04   T T
#     38            41                 3.2111E-01   3.265    4.230     -8.56E-04
#  ----------------------------------------------------------------------------------------
#             1     42  1.00E+00       3.0551E-01                      -2.90E-04   T T
#     39            42                 3.0551E-01   3.107    4.126     -8.98E-04
#  ----------------------------------------------------------------------------------------
#             1     43  1.00E+00       2.9189E-01                       2.75E-04   T T
#     40            43                 2.9189E-01   2.968    5.508     -4.16E-04
#  ----------------------------------------------------------------------------------------
#             1     44  1.00E+00       2.8929E-01                      -1.58E-04   T T
#     41            44                 2.8929E-01   2.942    3.296     -2.53E-04
#  ----------------------------------------------------------------------------------------
#             1     45  1.00E+00       2.8851E-01                      -1.07E-04   T T
#     42            45                 2.8851E-01   2.934    3.151     -2.54E-04
#  ----------------------------------------------------------------------------------------
#             1     46  1.00E+00       2.8501E-01                      -1.39E-04   T T
#     43            46                 2.8501E-01   2.898    3.317     -5.09E-04
#  ----------------------------------------------------------------------------------------
#             1     47  1.00E+00       2.7365E-01                      -1.02E-04   T T
#     44            47                 2.7365E-01   2.783    4.670     -3.44E-04
#  ----------------------------------------------------------------------------------------
#             1     48  1.00E+00       2.6620E-01                      -1.01E-04   T T
#     45            48                 2.6620E-01   2.707    2.941     -1.91E-04
#  ----------------------------------------------------------------------------------------
#             1     49  1.00E+00       2.6007E-01                      -8.31E-05   T T
#     46            49                 2.6007E-01   2.645    2.733     -1.84E-04
#  ----------------------------------------------------------------------------------------
#             1     50  1.00E+00       2.5474E-01                      -8.85E-05   T T
#     47            50                 2.5474E-01   2.591    2.604     -2.61E-04
#  ----------------------------------------------------------------------------------------
#             1     51  1.00E+00       2.4749E-01                      -1.30E-04   T T
#     48            51                 2.4749E-01   2.517    2.441     -3.82E-04
#  ----------------------------------------------------------------------------------------
#             1     52  1.00E+00       2.4120E-01                      -1.67E-05   T T
#     49            52                 2.4120E-01   2.453    3.723     -2.07E-04
#  ----------------------------------------------------------------------------------------
#             1     53  1.00E+00       2.3467E-01                      -9.14E-05   T T
#     50            53                 2.3467E-01   2.386    2.712     -1.91E-04
#  ----------------------------------------------------------------------------------------
#             1     54  1.00E+00       2.2983E-01                      -8.00E-05   T T
#     51            54                 2.2983E-01   2.337    2.778     -1.95E-04
#  ----------------------------------------------------------------------------------------
#             1     55  1.00E+00       2.2580E-01                      -1.06E-04   T T
#     52            55                 2.2580E-01   2.296    2.717     -3.21E-04
#  ----------------------------------------------------------------------------------------
#             1     56  1.00E+00       2.2147E-01                      -9.73E-05   T T
#     53            56                 2.2147E-01   2.252    2.968     -3.23E-04
#  ----------------------------------------------------------------------------------------
#             1     57  1.00E+00       2.1823E-01                       1.09E-04   T T
#     54            57                 2.1823E-01   2.219    5.075     -1.59E-04
#  ----------------------------------------------------------------------------------------
#             1     58  1.00E+00       2.1808E-01                      -7.89E-05   T T
#     55            58                 2.1808E-01   2.218    3.083     -1.42E-04
#  ----------------------------------------------------------------------------------------
#             1     59  1.00E+00       2.1764E-01                      -4.55E-05   T T
#     56            59                 2.1764E-01   2.213    2.078     -6.75E-05
#  ----------------------------------------------------------------------------------------
#             1     60  1.00E+00       2.1676E-01                      -3.88E-05   T T
#     57            60                 2.1676E-01   2.204    2.171     -1.45E-04
#  ----------------------------------------------------------------------------------------
#             1     61  1.00E+00       2.1425E-01                      -7.63E-05   T T
#     58            61                 2.1425E-01   2.179    2.251     -2.06E-04
#  ----------------------------------------------------------------------------------------
#             1     62  1.00E+00       2.1003E-01                      -8.95E-05   T T
#     59            62                 2.1003E-01   2.136    2.190     -1.90E-04
#  ----------------------------------------------------------------------------------------
#             1     63  1.00E+00       2.0729E-01                      -8.65E-05   T T
#     60            63                 2.0729E-01   2.108    2.188     -2.48E-04
#  ----------------------------------------------------------------------------------------
#             1     64  1.00E+00       2.0394E-01                       6.63E-05   T T
#     61            64                 2.0394E-01   2.074    3.563     -1.21E-04
#  ----------------------------------------------------------------------------------------
#             1     65  1.00E+00       2.0283E-01                      -4.66E-05   T T
#     62            65                 2.0283E-01   2.063    1.885     -7.26E-05
#  ----------------------------------------------------------------------------------------
#             1     66  1.00E+00       2.0283E-01                      -2.83E-05   T T
#     63            66                 2.0283E-01   2.063    1.941     -5.80E-05
#  ----------------------------------------------------------------------------------------
#             1     67  1.00E+00       2.0300E-01                      -3.12E-05   F T
#             2     68  5.00E-01       2.0284E-01                      -4.46E-05   F T
#             3     69  2.50E-01       2.0282E-01                      -5.13E-05   T T
#     64            69                 2.0282E-01   2.062    1.903     -1.65E-04
#  ----------------------------------------------------------------------------------------
#             1     70  1.00E+00       2.0265E-01                      -5.28E-05   T T
#     65            70                 2.0265E-01   2.061    1.895     -1.02E-04
#  ----------------------------------------------------------------------------------------
#             1     71  1.00E+00       2.0195E-01                      -5.48E-05   T T
#     66            71                 2.0195E-01   2.054    1.928     -1.55E-04
#  ----------------------------------------------------------------------------------------
#             1     72  1.00E+00       1.9952E-01                      -5.87E-05   T T
#     67            72                 1.9952E-01   2.029    1.879     -1.20E-04
#  ----------------------------------------------------------------------------------------
#             1     73  1.00E+00       1.9540E-01                      -6.06E-05   T T
#     68            73                 1.9540E-01   1.987    1.979     -1.67E-04
#  ----------------------------------------------------------------------------------------
#             1     74  1.00E+00       1.9137E-01                      -4.89E-06   T T
#     69            74                 1.9137E-01   1.946    2.572     -7.43E-05
#  ----------------------------------------------------------------------------------------
#             1     75  1.00E+00       1.8789E-01                      -2.93E-05   T T
#     70            75                 1.8789E-01   1.911    1.688     -5.22E-05
#  ----------------------------------------------------------------------------------------
#             1     76  1.00E+00       1.8633E-01                      -2.47E-05   T T
#     71            76                 1.8633E-01   1.895    1.510     -7.58E-05
#  ----------------------------------------------------------------------------------------
#             1     77  1.00E+00       1.8524E-01                      -4.31E-05   T T
#     72            77                 1.8524E-01   1.884    1.539     -1.28E-04
#  ----------------------------------------------------------------------------------------
#             1     78  1.00E+00       1.8506E-01                      -5.08E-05   T T
#     73            78                 1.8506E-01   1.882    1.627     -1.00E-04
#  ----------------------------------------------------------------------------------------
#             1     79  1.00E+00       1.8527E-01                      -4.21E-05   F T
#             2     80  5.00E-01       1.8501E-01                      -7.12E-05   T T
#     74            80                 1.8501E-01   1.881    1.584     -1.80E-04
#  ----------------------------------------------------------------------------------------
#             1     81  1.00E+00       1.8842E-01                      -3.24E-06   F T
#             2     82  5.00E-01       1.8601E-01                      -9.27E-05   F T
#             3     83  2.50E-01       1.8534E-01                      -1.37E-04   F T
#             4     84  1.25E-01       1.8513E-01                      -1.58E-04   F T
#             5     85  6.26E-02       1.8506E-01                      -1.69E-04   F F
#             6     86  3.13E-02       1.8503E-01                      -1.75E-04   F F
#             7     87  1.57E-02       1.8502E-01                      -1.77E-04   F F
#             8     88  7.91E-03       1.8502E-01                      -1.79E-04   F F
#             9     89  4.01E-03       1.8501E-01                      -1.79E-04   F F
#            10     90  2.05E-03       1.8501E-01                      -1.80E-04   F F
#            11     91  1.08E-03       1.8501E-01                      -1.80E-04   F F
#  **********************************************************************
#      STOP: LINE SEARCH FAILURE
#  **********************************************************************
#  **********************************************************************
#      FINALIZE
#  **********************************************************************

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('res_noQ_smthx0.2_zpow1/model_Iter1'))
plt.subplot(1,3,2); imshow(read('res_noQ_smthx0.2_zpow1/model_Iter4'))
plt.subplot(1,3,3); imshow(read('res_noQ_smthx0.2_zpow1/model_Iter6'))

plt.figure(figsize=(12,3))
plt.subplot(1,3,1); imshow(read('res_noQ_smthx0.2_zpow1/model_Iter30'))
plt.subplot(1,3,2); imshow(read('res_noQ_smthx0.2_zpow1/model_final'))
plt.subplot(1,3,3); imshow(read('res_smthx0.2_zpow1/model_final')-read('res_noQ_smthx0.2_zpow1/model_final'))

# %%
iz=np.arange(nz)

fwi1=read(    'res_smthx0.2_zpow1/model_final')
fwi2=read('res_noQ_smthx0.2_zpow1/model_final')

plt.figure(figsize=(9,6))

plt.subplot(1,3,1); ix=200
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi1')
plt.plot(fwi2[:,ix],iz,label='fwi2')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()

plt.subplot(1,3,2); ix=400
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi1')
plt.plot(fwi2[:,ix],iz,label='fwi2')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()

plt.subplot(1,3,3); ix=600
plt.plot(true[:,ix],iz,label='true',color='k')
plt.plot(init[:,ix],iz,label='init',color='gray')
plt.plot(fwi1[:,ix],iz,label='fwi1')
plt.plot(fwi2[:,ix],iz,label='fwi2')
plt.gca().invert_yaxis()
plt.grid(visible=True)
plt.legend()
